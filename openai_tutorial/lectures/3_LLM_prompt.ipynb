# %% [markdown]
# # 프롬프트 엔지니어링

# %%
# !pip install python-dotenv openai --q
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

def load_env_from_project_root():
    """
    현재 실행 중인 스크립트(LLM_basic.ipynb)에서
    step10_LLM 디렉토리의 .env 파일을 로드
    """
    # 현재 파일 위치
    current_path = Path.cwd()
    
    # step10_LLM 디렉토리로 이동 (../../)
    project_root = current_path.parent.parent
    
    # .env 파일 경로
    env_path = project_root / '.env'
    
    # .env 파일이 존재하는지 확인
    if env_path.exists():
        load_dotenv(env_path)
        print(f"Loaded .env from: {env_path}")
        return True
    else:
        raise FileNotFoundError(f".env file not found at: {env_path}")

# 실행
try:
    load_env_from_project_root()
    
    # 환경 변수 사용
    api_key = os.getenv('OPENAI_API_KEY')
    if api_key:
        print("API Key loaded successfully")
        # API 키 마스킹하여 출력
        masked_key = f"{api_key[:8]}...{api_key[-4:]}"
        print(f"API Key: {masked_key}")
    else:
        print("API Key not found in .env file")
except Exception as e:
    print(f"Error loading .env file: {e}")
# Out:
# Loaded .env from: c:\Users\campus3S043\Desktop\alpaco_lectures\step10_LLM\.env
# API Key loaded successfully
# API Key: sk-proj-...yTUA

# %%
from openai import OpenAI

client = OpenAI(
    # 시스템에 설정된 API 키를 사용합니다
    api_key=os.environ.get('OPENAI_API_KEY')
)

# OpenAI API를 활용하며, GPT-4o의 최신 모델을 호출합니다
response = client.chat.completions.create(model='gpt-4o',
messages=[
      {'role': 'user', 'content': '안녕!'}
  ])

# 응답을 추출합니다
print(response.choices[0].message.content)
# Out:
# 안녕하세요! 어떻게 도와드릴까요?

# %%
# 예시 4-1 API 호출 함수
def chat_completion(prompt, model="gpt-4o-mini", temperature=0, response_format=None):
    res = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=temperature,
        response_format=response_format 
    )

    return res.choices[0].message.content

# %%
# 예시 4-2 GPT API 호출 함수 테스트
print(chat_completion("데카르트가 말하길, 나는 생각한다 고로"))
# Out:
# "나는 생각한다, 고로 존재한다"라는 말은 프랑스의 철학자 르네 데카르트(René Descartes)의 유명한 명제입니다. 이 말은 그의 철학적 사유의 기초를 이루며, 존재의 확실성을 주장하는 데 사용됩니다. 데카르트는 의심할 수 있는 모든 것을 의심한 후에도, 자신의 생각이 존재한다는 사실만큼은 확실하다고 주장했습니다. 즉, 사고하는 주체로서의 자신이 존재한다는 것을 통해 존재의 근거를 찾으려 했습니다. 이 명제는 현대 철학의 중요한 출발점 중 하나로 여겨집니다.

# %%
# 예시 4-3 컨텍스트가 없는 프롬프트
print(chat_completion("오늘 점심에 먹을 메인 메뉴를 추천해 주세요."))
# Out:
# 오늘 점심에 먹을 메인 메뉴로는 다음과 같은 것들을 추천해 드립니다:
#
# 1. **비빔밥** - 다양한 채소와 고기를 넣고 고추장과 함께 비벼 먹는 건강한 한 그릇 요리입니다.
# 2. **김치찌개** - 뜨끈한 김치찌개에 밥을 곁들여 먹으면 든든한 한 끼가 됩니다.
# 3. **불고기** - 양념된 소고기를 볶아 밥과 함께 먹으면 맛있고 만족스러운 점심이 될 것입니다.
# 4. **닭갈비** - 매콤한 양념에 볶은 닭고기와 채소를 함께 먹는 요리로, 밥과 함께 즐기기 좋습니다.
# 5. **해물파전** - 바삭하게 구운 해물파전과 막걸리 한 잔도 좋은 조합입니다.
#
# 오늘의 기분이나 입맛에 따라 선택해 보세요!

# %%
# 예시 4-4 컨텍스트를 포함한 프롬프트
prompt = """
Context: 저는 하루에 2시간 운동을 합니다.
채식주의자이며, 녹색 채소를 싫어합니다.
건강식에 관심이 많아요.

Task: 오늘 점심에 먹을 메인 메뉴를 추천해 주세요.
"""
print(chat_completion(prompt))
# Out:
# 녹색 채소를 싫어하신다면, 다른 색상의 채소를 활용한 건강한 점심 메뉴를 추천해 드릴게요.
#
# **퀴노아와 구운 채소 볼**
# - **재료**: 퀴노아, 당근, 파프리카, 호박, 버섯, 병아리콩, 올리브유, 레몬즙, 허브(바질이나 오레가노), 소금, 후추
# - **조리법**:
#   1. 퀴노아를 물에 씻고, 물과 함께 끓여서 익힙니다.
#   2. 당근, 파프리카, 호박, 버섯을 먹기 좋은 크기로 자르고, 올리브유, 소금, 후추로 간을 한 후 오븐에서 구워줍니다.
#   3. 익힌 퀴노아에 구운 채소와 병아리콩을 섞고, 레몬즙과 허브로 간을 맞춥니다.
#   4. 그릇에 담아 맛있게 즐기세요!
#
# 이 메뉴는 단백질과 섬유질이 풍부하고, 다양한 색상의 채소로 영양을 고루 섭취할 수 있습니다. 맛있게 드세요!

# %%
# 예시 4-5 프롬프트를 보완할 정보 요청
prompt = """
Context: 저는 하루에 2시간 운동을 합니다.
채식주의자이며, 녹색 채소를 싫어합니다.
건강식에 관심이 많아요.
Task: 오늘 점심에 먹을 메인 메뉴를 추천해 주세요.
요청한 작업을 수행하지 마세요! 대신, 작업을 더 효과적으로 수행할 수 있도록 추가적인 정보를 물어보세요.
"""
print(chat_completion(prompt))
# Out:
# 좋습니다! 점심 메뉴를 추천하기 위해 몇 가지 추가 정보를 여쭤볼게요.
#
# 1. 어떤 종류의 단백질을 선호하시나요? (예: 두부, 콩, 견과류 등)
# 2. 어떤 탄수화물 원료를 좋아하시나요? (예: 쌀, 파스타, 감자 등)
# 3. 특별히 피하고 싶은 재료나 음식이 있나요?
# 4. 점심 메뉴의 조리 방법에 대한 선호가 있나요? (예: 구이, 찜, 볶음 등)
# 5. 혹시 드시고 싶은 특정한 요리 스타일이나 문화가 있나요? (예: 이탈리안, 아시안, 멕시칸 등)
#
# 이 정보를 주시면 더 맞춤형으로 추천해 드릴 수 있을 것 같아요!

# %%
# 예시 4-6 표 형식의 결과를 요청하는 프롬프트
prompt = """
Context: 저는 하루에 2시간 운동을 합니다.
채식주의자이며, 녹색 채소를 싫어합니다.
건강식에 관심이 많아요.
Task: 오늘 점심에 먹을 메인 메뉴를 추천해 주세요.
추천을 할때는 두 개의 열이 있는 표도 함께 제공해주세요.
각 행에는 주요 요리의 재료가 포함되어야 합니다.
첫 번째 열은 재료의 이름입니다.
두 번째 열은 1인분에 들어갈 그 재료의 무게(그램)입니다. 
요리를 준비하는 레시피는 제공하지 마십시오.
"""
res = chat_completion(prompt)
print(*res.split('\n'), sep='\n')
# Out:
# 오늘 점심에 드실 수 있는 건강한 채식 메뉴로 "퀴노아와 채소 볶음"을 추천드립니다. 아래는 주요 재료와 그 무게를 포함한 표입니다.
#
# | 재료 이름         | 1인분 무게 (그램) |
# |------------------|-------------------|
# | 퀴노아           | 100               |
# | 방울토마토       | 100               |
# | 파프리카         | 80                |
# | 양파             | 50                |
# | 마늘             | 10                |
# | 올리브유         | 10                |
# | 후추             | 2                 |
# | 소금             | 2                 |
#
# 이 메뉴는 건강하면서도 맛있게 즐길 수 있는 점심이 될 것입니다!

# %% [markdown]
# # 사용자 피드백을 통한 반복적 개선
# 이 섹션에서는 프롬프트 개선을 위한 반복적인 과정을 구현합니다:
# 1. 프롬프트 평가자(the_reviewer)가 현재 프롬프트를 평가하고 점수를 매깁니다
# 2. 질문자(the_questioner)가 프롬프트 개선을 위한 질문들을 생성합니다
# 3. 사용자의 답변을 받아 프롬프트를 개선합니다
# 4. 만족스러운 결과가 나올 때까지 이 과정을 반복합니다

# %%
import json
from openai import OpenAI

client = OpenAI(
    # 시스템에 설정된 API 키를 사용합니다
    api_key=os.environ.get('OPENAI_API_KEY')
)

def chat_completion(prompt, model="gpt-4o", temperature=0, response_format=None):
    res = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=temperature,
        response_format=response_format 
    )
    return(res.choices[0].message.content)

def the_reviewer(prompt_initialization, current_prompt):
    
    prompt_reviewer = prompt_initialization + "\n\n"
    prompt_reviewer += f"현재 프롬프트: {current_prompt}\n\n"
    prompt_reviewer += """작업: 현재 프롬프트를 상세하고 철저하게 평가하세요.
    먼저 현재 프롬프트에 0점에서 5점 사이의 점수를 매겨주세요(0은 매우 나쁨, 5는 매우 좋음).
    그 후, 프롬프트를 5점짜리 완벽한 프롬프트가 되기 위해 개선할 점들을 간략한 문단으로 설명하세요."""
    
    reviews= chat_completion(prompt_reviewer)

    print(reviews)
    
    return reviews

def the_questioner(prompt_initialization, current_prompt, reviews, questions_answers):
        
        prompt_questioner = prompt_initialization + "\n\n"
        prompt_questioner += f"현재 프롬프트: {current_prompt}\n\n"
        prompt_questioner += f"현재 프롬프트에 대한 평가:{reviews}\n\n"
        prompt_questioner += """
        작업: 프롬프트를 개선하기 위해 반드시 필요한 최대 4개의 질문 목록을 작성하세요(각 질문에 대한 예시 답변도 괄호 안에 제공하세요).
        출력 형식: JSON 형식으로 출력하세요. 
        출력은 json.loads로 읽을 수 있어야 합니다. JSON 형식은 다음과 같습니다.
        {'Questions': ['Question 1', 'Question 2', 'Question 3', 'Question 4']}
        """
        
        questions_json = chat_completion(prompt_questioner, model="gpt-4-1106-preview", response_format={"type": "json_object"})

        try:
            questions = json.loads(questions_json).get('Questions', [])
        except json.JSONDecodeError:
            print("모델에서 반환된 JSON 형식이 잘못되었습니다.")
            questions = []
        
        for i, question in enumerate(questions, start=1):
            answer = input(f"질문 {i}: {question} ")
            questions_answers = questions_answers + f"질문: {question}\n답변: {answer}\n\n"
        
        return questions_answers


def the_prompt_maker(prompt_initialization, current_prompt, reviews, questions_answers):
     
    prompt =  prompt_initialization + "\n\n"
    prompt += f"현재 프롬프트: {current_prompt}\n\n"
    prompt += f"해당 프롬프트에 대한 평가:{reviews}\n\n"
    prompt += f"현재 프롬프트를 개선하는 데 필요한 질문과 답변:{questions_answers}\n\n"
    prompt += """
    작업: 이 모든 정보와 프롬프트 엔지니어링 전문 지식을 최대한 활용하여
    현재 프롬프트를 최적의 방식으로 다시 작성해 주세요.
    GPT로 실행할 5점 만점의 완벽한 프롬프트를 생성하는 것이 목표입니다.
    질문과 답변에 포함된 모든 정보를 새 프롬프트에 반드시 포함시켜 주세요.
    프롬프트는 GPT에게 하나 이상의 역할을 부여하고, 컨텍스트와 작업을 정의하는 것으로 시작하세요.
    출력: 당신이 작성한 새로운 GPT용 프롬프트(한국어)만 반환하세요. 그 외의 것은 포함하지 마세요.
    """

    new_prompt = chat_completion(prompt)
    return(new_prompt)

def promptor(initial_prompt, max_nb_iter=3):

    print(f"기존 프롬프트: {initial_prompt}")

    prompt_initialization = """
    당신은 프롬프트 엔지니어링과 대형 언어 모델에 대한 전문가입니다.
    좋은 프롬프트는 GPT에게 하나 이상의 역할을 부여하고, 명확한 컨텍스트와 작업을 정의하며, 기대되는 출력을 명확히 해야 합니다.
    당신은 퓨샷 러닝, 프롬프트 체이닝, 섀도우 프롬프팅 등 다양한 프롬프트 기술을 알고 활용할 수 있습니다.
    저는 당신이 저의 개인 프롬프트 제작 전문가입니다.
    당신의 이름은 이제 '프롬프터'이며, 앞으로 당신을 그렇게 부를 것입니다.
    프롬프터와 GPT는 별개이자 독립된 존재입니다.
    프롬프터(당신)는 GPT에 적합한 프롬프트를 만들어야 합니다.
    """
    
    current_prompt = initial_prompt
    questions_answers = ""
    for i in range(max_nb_iter):

        print(f"{i+1}회차")
        reviews = the_reviewer(prompt_initialization, current_prompt)
        questions_answers = the_questioner(prompt_initialization, current_prompt, reviews, questions_answers)
        current_prompt = the_prompt_maker(prompt_initialization, current_prompt, reviews, questions_answers)
        
        print(f"\n새로운 프롬프트: {current_prompt}\n\n")
        keep = input(f"이 프롬프트를 유지할까요(y/n)?: ")
        if keep == 'y':
            break

    return current_prompt


prompt = promptor("오늘 점심으로 먹을 메인 코스를 제안해주세요.",  max_nb_iter=3)
res = chat_completion(prompt)
print(res)
# Out:
# 기존 프롬프트: 오늘 점심으로 먹을 메인 코스를 제안해주세요.
# 1회차
# 현재 프롬프트 평가: 3점
#
# 현재 프롬프트는 간단하고 명확하게 요청을 전달하고 있지만, 더 구체적인 정보를 제공하여 GPT가 더 적절하고 맞춤화된 응답을 생성할 수 있도록 개선할 여지가 있습니다. 예를 들어, 사용자의 식사 선호도(예: 채식, 비건, 특정 알레르기), 현재 위치(예: 집, 직장 근처), 또는 특정 요리 스타일(예: 이탈리안, 아시안)을 포함하면 더 맞춤화된 제안을 받을 수 있습니다. 또한, 기대하는 출력 형식(예: 간단한 요리 이름, 레시피 포함)을 명시하면 GPT가 더 유용한 응답을 제공할 수 있습니다. 이러한 추가 정보를 통해 프롬프트는 더 구체적이고 유용한 결과를 도출할 수 있을 것입니다.
#
# 새로운 프롬프트: 여행 중인 채식주의자를 위한 이탈리안 스타일의 점심 메인 코스를 제안해 주세요. 레시피를 포함하여 제공해 주시고, 특별히 피해야 할 재료는 없습니다.
#
#
# 여행 중인 채식주의자를 위한 이탈리안 스타일의 점심 메인 코스로 "가지 파르미지아나"를 제안합니다. 이 요리는 가지와 토마토 소스를 층층이 쌓아 오븐에 구워낸 이탈리아 전통 요리로, 풍부한 맛과 식감이 특징입니다. 다음은 가지 파르미지아나의 레시피입니다.
#
# ### 가지 파르미지아나 레시피
#
# #### 재료:
# - 큰 가지 2개
# - 올리브 오일 4큰술
# - 다진 마늘 2쪽
# - 토마토 소스 2컵 (또는 잘게 썬 토마토 1캔)
# - 신선한 바질 잎 한 줌
# - 소금과 후추 약간
# - 모차렐라 치즈 200g (슬라이스 또는 잘게 찢은 것)
# - 파르미지아노 레지아노 치즈 50g (갈아서 준비)
# - 빵가루 1/2컵
#
# #### 준비 과정:
# 1. **가지 준비**: 가지를 약 1cm 두께로 슬라이스합니다. 슬라이스한 가지에 소금을 약간 뿌려 20분 정도 두어 수분을 제거합니다. 그런 다음, 키친타월로 물기를 닦아냅니다.
#
# 2. **가지 굽기**: 큰 팬에 올리브 오일 2큰술을 두르고 중불로 가열합니다. 가지 슬라이스를 양쪽이 노릇해질 때까지 굽습니다. 필요에 따라 오일을 추가로 사용하세요. 구운 가지는 따로 둡니다.
#
# 3. **토마토 소스 만들기**: 같은 팬에 남은 올리브 오일 2큰술을 두르고 다진 마늘을 넣어 향이 날 때까지 볶습니다. 토마토 소스를 추가하고 소금, 후추로 간을 맞춥니다. 소스를 약 10분간 중약불에서 끓여 농도를 맞춥니다. 마지막에 신선한 바질 잎을 넣고 불을 끕니다.
#
# 4. **오븐 준비**: 오븐을 180도(섭씨)로 예열합니다.
#
# 5. **층 쌓기**: 오븐용 그라탱 접시에 토마토 소스를 얇게 깔고, 그 위에 구운 가지를 한 층 올립니다. 모차렐라 치즈와 파르미지아노 레지아노 치즈를 뿌립니다. 이 과정을 반복하여 모든 재료를 사용합니다. 마지막 층에는 빵가루와 파르미지아노 레지아노 치즈를 뿌려줍니다.
#
# 6. **굽기**: 예열된 오븐에 그라탱 접시를 넣고 약 25-30분간, 또는 치즈가 황금빛 갈색이 될 때까지 굽습니다.
#
# 7. **서빙**: 오븐에서 꺼내 약간 식힌 후, 신선한 바질 잎을 장식하여 따뜻하게 서빙합니다.
#
# 이 가지 파르미지아나는 풍부한 맛과 함께 채식주의자에게 훌륭한 이탈리안 스타일의 점심을 제공합니다. 즐거운 식사 되세요!

# %% [markdown]
# # 파인튜닝

# %%
from base64 import b64decode
import pandas as pd
import matplotlib.pyplot as plt
import io
import json

def chat_completion(prompt, model="gpt-4o-mini", temperature=0, response_format=None):
    res = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=temperature,
        response_format=response_format 
    )

    return res.choices[0].message.content

l_sector = [
   '식료품점', '레스토랑', '패스트푸드점', '약국',
   '주유소', '전자제품 매장', '택시 서비스'
]
l_city = ['브뤼셀', '파리', '부줌부라', '베를린', '산티아고'] 
l_size = ['소규모', '중규모', '대규모']

f_prompt = """
역할: 당신은 다이렉트 마케팅 분야에서 풍부한 경험을 가진 전문 콘텐츠 작성자입니다.
뛰어난 작문 능력, 창의성, 다양한 톤과 스타일에 대한 적응력,
효과적인 다이렉트 캠페인을 위한 고객 니즈와 선호도에 대한 깊은 이해를 보유하고 있습니다.

컨텍스트: 새로운 이커머스 결제 서비스를 상점에 판매하기 위한 
다이렉트 마케팅 캠페인용 짧은 메시지를 2문장 이내로 작성해야 합니다. 
대상 상점들은 다음 세 가지 특성을 가지고 있습니다.
- 업종: {sector}
- 상점 위치(도시): {city}
- 상점 규모: {size}

작업: 다이렉트 마케팅 캠페인을 위한 짧은 메시지를 작성하세요.
정의된 역할의 능력을 활용하여 이 메시지를 작성하세요!
판매하고자 하는 제품과 메시지를 받을 상점의 특성을 고려하여 메시지를 작성하는 것이 중요합니다.
"""

f_sub_prompt = "{sector}, {city}, {size}"

nb_rep = 3

res = []
for sector in l_sector:
    for city in l_city:
        for size in l_size:
            for i in range(nb_rep):  # 'nb_rep' times each example
                prompt = f_prompt.format(
                sector=sector, city=city, size=size)
                sub_prompt = f_sub_prompt.format(
                sector=sector, city=city, size=size)
                response_txt = chat_completion(
                    prompt, model='gpt-4o-mini', temperature=1
                )
                response_txt = response_txt.replace('"', '')
                print(response_txt)
                
                new_row = {
                    'prompt': sub_prompt,
                    'completion': response_txt
                }

                new_row = {
                    'messages':[
                        {
                            'role': 'user', 
                            'content': sub_prompt
                        },
                        {
                            'role': 'assistant', 
                            'content': response_txt
                        }
                    ]
                }
                
                res.append(new_row)
# Out:
# 브뤼셀의 소규모 식료품점에 최적화된 이커머스 결제 서비스로 손쉽고 빠르게 고객에게 다가가세요! 이제 더 많은 소비자를 유치하고 매출을 증가시킬 수 있는 기회를 놓치지 마세요!
# 브뤼셀의 소규모 식료품점에서 고객의 쇼핑 경험을 혁신하세요! 저희 이커머스 결제 서비스로 간편하고 안전한 결제 솔루션을 제공하여 매출을 높이고 고객만족도를 극대화해보세요.
# 브뤼셀의 소규모 식료품점에 최적화된 이커머스 결제 서비스를 도입해 보세요! 빠르고 안전한 결제 옵션으로 고객의 만족도를 높이고, 매출을 더불어 성장시킬 기회를 놓치지 마세요!
# 브뤼셀의 중규모 식료품점이시라면, 혁신적인 이커머스 결제 서비스로 고객의 쇼핑 경험을 한 단계 업그레이드하세요! 쉽고 안전한 결제로 매출을 높이고, 고객 만족을 극대화하는 기회를 놓치지 마세요!
# 브뤼셀 중소 식료품점의 매출을 극대화하세요! 간편하고 안전한 이커머스 결제 서비스로 고객의 쇼핑 경험을 혁신해보세요.
# 브뤼셀의 중규모 식료품점에 최적화된 새로운 결제 서비스를 도입하여 고객의 쇼핑 경험을 혁신하세요! 간편하고 안전한 결제 시스템으로 더 많은 손님을 유치하고, 매출을 증대시켜보세요.
# 브뤼셀 대형 식료품점에 최적화된 저희 이커머스 결제 서비스로 고객의 쇼핑 경험을 혁신하세요! 간편하고 안전한 결제로 매출을 극대화하고, 고객의 재방문율을 높이는 기회를 잡으세요.
# 브뤼셀의 대규모 식료품점에 최적화된 우리의 이커머스 결제 서비스로 고객의 쇼핑 경험을 혁신하세요! 간편하고 안전한 결제 시스템으로 매출을 극대화하고, 고객 충성도를 높여보세요!
# 브뤼셀 대규모 식료품점에 최적화된 새로운 이커머스 결제 서비스를 통해 고객의 쇼핑 경험을 한층 더 개선하세요. 안전하고 간편한 결제를 제공하여 매출을 높이고, 고객의 재방문을 유도할 수 있는 기회를 놓치지 마세요!
# 파리의 소규모 식료품점에 맞춘 혁신적인 이커머스 결제 서비스로 고객의 쇼핑 경험을 한층 향상시켜보세요! 손쉬운 결제와 빠른 정산으로 매출을 늘리고, 더 많은 고객을 유치하는 비결을 지금 바로 확인하세요!
# 파리의 소규모 식료품점, 고객의 행복을 실속 있게! 저희의 새로운 이커머스 결제 서비스로 간편함과 매출 성장을 동시에 누려보세요!
# 파리의 소규모 식료품점에 최적화된 새로운 결제 서비스로 고객 만족도를 높이세요! 간편한 결제로 쇼핑의 즐거움을 더하고, 매출 성장을 경험해보세요!
# “파리의 중규모 식료품점에 완벽한 결제 솔루션! 우리의 이커머스 결제 서비스로 고객의 쇼핑 경험을 쉽게 변화시키고, 매출을 높여보세요!”
# 파리의 중규모 식료품점이시라면, 저희의 혁신적인 결제 서비스로 고객의 쇼핑 경험을 한층 끌어올려 보세요! 빠르고 안전한 결제로 매출 증대와 고객 만족도 향상을 누리실 수 있습니다.
# 파리의 중규모 식료품점에 최적화된 혁신적인 결제 솔루션으로 고객의 쇼핑 경험을 한층 간편하게 만들어보세요! 이제 더 빠르고 안전한 결제로 매출 상승과 고객 만족도를 동시에 추구할 수 있습니다.
# 파리의 대규모 식료품점에 최적화된 이커머스 결제 서비스로 고객의 쇼핑 경험을 한 차원 높이세요—더 빠르고 편리한 결제로 매출을 증대시키는 기회를 놓치지 마십시오!
# “파리의 대규모 식료품점에 최적화된 차세대 결제 솔루션으로 매출을 극대화하세요! 고객의 쇼핑 경험을 혁신하고, 빠르고 안전한 결제로 재구매율을 높이는 기회를 놓치지 마세요!”
# 귀하의 대규모 식료품점에 혁신적인 결제 솔루션을 도입해보세요! 고객들은 더 빠르고 안전한 쇼핑 경험을 즐기며, 귀하는 매출 상승의 기회를 잡을 수 있습니다.
# 부줌부라의 소규모 식료품점에 최적화된 결제 서비스로 고객의 쇼핑을 간편하게 만들어보세요! 지금 가입하시면 매출 증대와 고객 만족도를 동시에 누릴 수 있는 기회를 놓치지 마세요!
# 부줌부라의 소규모 식료품점이 고객의 편의를 최우선으로 하세요! 저희 새로운 이커머스 결제 서비스로 빠르고 안전한 결제를 통해 매출을 극대화하세요.
# 부줌부라의 소규모 식료품점에 최적화된 새로운 이커머스 결제 서비스로 매출을 높여보세요. 간편하고 안전한 결제로 고객들의 쇼핑 경험을 혁신하고, 더 많은 단골을 만들어 보세요!
# 부줌부라의 중규모 식료품점에 최적화된 새로운 이커머스 결제 서비스로 고객의 쇼핑 경험을 한 단계 끌어올리세요! 간편하고 안전한 결제로 매출을 증대시키고, 고객의 충성도를 높이는 기회를 놓치지 마세요.
# 부줌부라의 중규모 식료품점, 이제 고객의 결제를 더 빠르고 쉽게! 최신 이커머스 결제 서비스로 매출을 높이고, 고객 만족도를 극대화해보세요!
# 부줌부라의 중규모 식료품점에 최적화된 이커머스 결제 서비스로, 고객의 쇼핑 경험을 한층 더 향상시켜 보세요! 손쉬운 결제 시스템으로 매출을 증가시키고, 고객의 충성도를 높일 수 있는 기회를 놓치지 마세요!
# 부줌부라의 대규모 식료품점에 적합한 혁신적인 이커머스 결제 서비스로 고객의 쇼핑 경험을 향상시켜 보세요! 간편한 결제 솔루션으로 매출을 늘리고, 고객의 재방문을 이끌어낼 기회를 놓치지 마세요!
# 부줌부라의 대규모 식료품점에 최적화된 새로운 이커머스 결제 서비스로, 고객의 구매 경험을 한층 더 매끄럽고 빠르게 만드세요! 지금 바로 도입하셔서 경쟁에서 앞서 나가고, 더 많은 고객의 마음을 사로잡으세요!
# 부줌부라의 대규모 식료품점, 고객의 편리함을 한층 더 높여보세요! 우리의 이커머스 결제 서비스로 빠르고 안전한 쇼핑 경험을 제공하며 매출 성장의 기회를 놓치지 마세요!
# 귀하의 소규모 식료품점에 최적화된 새로운 이커머스 결제 서비스로 고객의 쇼핑 경험을 향상시켜 보세요! 베를린의 소비자들에게 더 빠르고 간편한 결제 방법을 제공하여 매출을 극대화하세요!
# 베를린의 소규모 식료품점에 최적화된 이커머스 결제 서비스로 고객의 쇼핑 경험을 혁신하세요! 간편한 결제 시스템으로 매출을 높이고 고객의 만족도를 극대화해 보세요.
# 안녕하세요, 베를린의 소규모 식료품점 여러분! 저희 새로운 이커머스 결제 서비스로 손쉽고 빠른 결제 경험을 제공하여 고객의 재방문율을 높이고, 매출을 증대시켜 보세요!
# “베를린의 중소형 식료품점에 최적화된 우리의 이커머스 결제 서비스로 고객 경험을 혁신하세요! 더 빠르고 쉽게, 당신의 매장이 성장하는 모습을 직접 확인해 보세요.”
# 베를린의 중규모 식료품점에 맞춘 스마트한 결제 서비스를 도입해 보세요! 고객들이 더 빠르고 간편하게 쇼핑할 수 있도록 도와드리며, 매출 증대의 새로운 기회를 제공합니다!
# “베를린 중규모 식료품점의 성장을 가속화하세요! 저희의 혁신적인 이커머스 결제 서비스로 고객에게 더 빠르고 간편한 쇼핑 경험을 제공해보세요.”
# 베를린의 대규모 식료품점에 꼭 맞는 혁신적인 이커머스 결제 서비스로 고객의 쇼핑 경험을 한층 향상시켜 보세요. 저희 솔루션으로 간편하고 빠른 결제가 가능해져 매출 증대는 물론 고객 만족도도 높아질 것입니다!
# 베를린의 대규모 식료품점을 위한 혁신적인 이커머스 결제 서비스를 도입해 보세요! 고객의 편리함을 극대화하여 더 많은 구매를 유도하고, 매출을 한층 높여드립니다.
# 베를린의 대규모 식료품점을 위해 설계된 혁신적인 이커머스 결제 서비스로 고객의 쇼핑 경험을 한 단계 끌어올려 보세요! 원활한 결제 시스템으로 매출을 증대시키고, 손쉬운 관리로 더 많은 고객을 유치하세요!
# 작은 식료품점에도 큰 변화가! 우리의 최신 이커머스 결제 서비스로 고객의 쇼핑 경험을 혁신하고, 매출을 더 높여보세요. 간편한 결제로 산티아고 고객을 사로잡으세요!
# 당신의 작은 식료품점도 더 큰 매출을 올릴 수 있습니다! 우리 이커머스 결제 서비스로 고객의 구매 경험을 간편하게 바꿔보세요.
# 고객의 편리를 최우선으로 생각하는 작은 식료품점 여러분! 우리의 이커머스 결제 서비스로 더 많은 고객을 유치하고, 매출을 증대시키세요—지금 신청하시면 빠르고 안전한 결제를 경험하실 수 있습니다!
# 산티아고의 중소형 식료품점에 최적화된 이커머스 결제 서비스로 손쉽게 매출을 증가시키세요! 고객의 편리함을 더하고, 귀하의 비즈니스를 온라인에서도 더욱 빛나게 해줄 기회를 놓치지 마세요!
# 산티아고의 중소 식료품점을 위한 혁신적인 결제 솔루션으로 고객의 쇼핑 경험을 향상시키세요! 간편하고 안전한 결제로 매출을 극대화하고, 고객의 재방문을 더욱 쉽게 만들어 드립니다.
# 산티아고 중소 식료품점에 최적화된 결제 솔루션으로 손쉽고 빠르게 고객의 결제를 처리하세요! 비즈니스를 성장시키는 스마트한 선택, 지금 바로 시작해보세요!
# “산티아고의 대규모 식료품점에 최적화된 이커머스 결제 서비스로 고객의 쇼핑 경험을 혁신하세요! 안전하고 간편한 결제로 매출 증가의 기회를 놓치지 마십시오.”
# 산티아고의 대규모 식료품점에 최적화된 안전하고 신속한 결제 서비스로 고객 만족도를 높이세요! 손쉬운 결제로 매출을 극대화하고 고객 재방문율을 높일 수 있는 기회를 놓치지 마세요!
# 산티아고의 대규모 식료품점에 최적화된 결제 솔루션으로 고객의 쇼핑 경험을 혁신하세요! 간편한 결제 프로세스로 매출 증대와 고객 만족도를 동시에 높일 수 있습니다.
# 브뤼셀의 소규모 레스토랑, 고객의 결제 경험을 혁신하세요! 우리의 이커머스 결제 서비스로 편리함을 더하고, 매출을 극대화해보세요!
# 브뤼셀의 소규모 레스토랑이 더 많은 손님을 맞이할 수 있도록, 혁신적이고 간편한 이커머스 결제 서비스를 소개합니다! 고객의 결제가 쉬워지면, 매출도 향상됩니다!
# 브뤼셀의 소규모 레스토랑을 위해, 손쉬운 이커머스 결제 서비스를 도입해 보세요! 더 빠르고 안전한 결제로 고객 만족도를 높이고, 매출을 극대화해 보세요.
# 브뤼셀의 중규모 레스토랑을 위한 스마트 결제 솔루션! 고객의 주문을 더 쉽게 받고, 매출을 증대시킬 기회를 놓치지 마세요.
# 브뤼셀의 중규모 레스토랑을 위해, 고객의 편리함을 극대화하는 혁신적인 결제 서비스를 소개합니다! 지금 도입하시면, 고객 만족도를 높이고 매출을 증대시키는 기회를 놓치지 마세요!
# 브뤼셀의 중규모 레스토랑을 위한 강력한 결제 솔루션, 지금 도입하세요! 고객의 맛있는 경험을 한층 더 향상시키며, 결제 과정 또한 간편하게 만들어 드립니다.
# “브뤼셀의 대규모 레스토랑을 위해 설계된 혁신적인 이커머스 결제 서비스로 고객 경험을 한층 강화하세요! 빠르고 안전한 결제를 통해 더 많은 손님을 맞이하고 매출을 극대화하는 기회를 놓치지 마세요.”
# 브뤼셀의 대규모 레스토랑을 위해, 저희의 혁신적인 이커머스 결제 서비스로 고객의 결제 경험을 혁신하세요! 손쉬운 결제 솔루션으로 매출을 극대화하고, 손님들에게 보다 원활한 서비스를 제공해보세요!
# 브뤼셀의 대규모 레스토랑에 최적화된 우리 이커머스 결제 서비스로, 손쉬운 결제로 고객의 방문을 더욱 특별하게 만들어보세요! 소비자 경험을 혁신하고 수익을 극대화하는 기회를 놓치지 마십시오!
# 파리의 작은 레스토랑도 손쉬운 결제로 고객에게 특별한 경험을 선사하세요! 새로운 이커머스 결제 서비스로 빠르고 안전한 결제 시스템을 도입해 매출을 극대화하세요.
# 파리의 작은 레스토랑에 혁신을 더하세요! 우리의 이커머스 결제 서비스로 더 빠르고 안전한 결제를 경험해 보세요 - 손님들도, 당신도 더 만족할 것입니다!
# 당신의 파리 레스토랑에 혁신적인 결제 솔루션을 도입해 보세요! 간편한 결제로 고객을 더 빠르게 만족시키고, 매출을 극대화하는 기회를 놓치지 마세요!
# 파리의 중규모 레스토랑을 위해 설계된 우리의 이커머스 결제 서비스로 고객의 주문 경험을 혁신하세요. 쉽고 빠른 결제 솔루션이 매출을 극대화하고, 여러분의 맛있는 요리를 더욱 사랑받게 만들 것입니다!
# 파리의 중규모 레스토랑을 위한 스마트한 결제 솔루션! 고객의 편리함을 더하고, 매출을 높이는 완벽한 선택으로 바쁜 서비스 시간을 최적화하세요!
# 파리의 중규모 레스토랑을 위한 특별한 이커머스 결제 솔루션! 고객 편의성을 극대화하고 매출을 증가시키는 혁신적인 시스템으로, 지금 바로 업그레이드해보세요!
# 파리의 대형 레스토랑을 위해, 고객 안전과 편리함을 동시에 충족하는 혁신적인 이커머스 결제 서비스를 도입하세요. 매출을 극대화하고 손쉬운 결제 경험을 제공하여 고객의 리피트를 이끌어냅니다!
# 파리의 대규모 레스토랑에 맞춤형 이커머스 결제 솔루션을 도입해 매출을 크게 올려보세요! 빠르고 간편한 결제를 통해 고객의 만족도를 높이고, 경쟁에서 앞서 나가세요.
# 파리의 대규모 레스토랑을 위한 혁신적인 이커머스 결제 서비스로, 고객의 편리한 쇼핑 경험을 더해보세요! 손쉬운 결제 프로세스를 통해 매출을 극대화하고, 더 많은 손님을 맞이할 준비가 되어 있습니다.
# 부줌부라의 소규모 레스토랑을 위한 혁신적인 결제 솔루션! 고객의 쇼핑 경험을 향상시키고, 당신의 매출을 높여보세요!
# “부줌부라의 소규모 레스토랑을 위해 특별히 설계된 새로운 결제 서비스로 고객의 결제를 간편하게 만들어보세요! 매출이 증가하고, 고객 만족도가 높아지는 변화를 경험하세요.”
# 부줌부라의 소규모 레스토랑도 이제 쉽고 빠르게 결제하세요! 새로운 이커머스 결제 서비스로 고객의 만족도와 매출을 동시에 높여보세요!
# 부줌부라의 중규모 레스토랑을 위한 특별한 이커머스 결제 서비스로 손쉽게 매출을 올려보세요! 고객의 선택을 확대하고 결제 과정을 간소화하여, 만족도를 높이고 귀하의 사업을 성장시키는 기회를 놓치지 마세요!
# 부줌부라의 중규모 레스토랑을 위해, 우리 이커머스 결제 서비스로 고객의 결제 경험을 혁신해보세요! 빠르고 안전한 결제 시스템으로 손님을 사로잡고, 매출을 극대화하는 기회를 놓치지 마세요!
# 부줌부라의 중규모 레스토랑을 위한 완벽한 선택! 우리의 이커머스 결제 서비스로 고객의 결제를 더욱 간편하게 만들어 보세요.
# 부줌부라의 대규모 레스토랑을 위한 혁신적인 결제 서비스로, 고객의 결제를 더 빠르고 안전하게 처리하세요! 지금 도입하면 손쉬운 결제 시스템을 통해 매출을 극대화하고, 고객 만족도를 높일 수 있습니다!
# 부줌부라의 대규모 레스토랑을 위해 특별히 설계된 혁신적인 결제 서비스로 고객의 편리함을 극대화하세요! 매출을 증가시키고, 빠른 결제 경험으로 재방문 고객을 확보할 수 있는 기회를 놓치지 마세요!
# 고객의 결제가 더욱 간편해지는 새로운 결제 서비스를 통해 부줌부라의 당신의 레스토랑 매출을 극대화하세요! 대규모 상점에 적합한 최적화된 솔루션으로 고객 경험을 한 단계 업그레이드해 보세요.
# 베를린의 소규모 레스토랑을 위해 설계된 맞춤형 결제 서비스로, 고객의 소중한 순간을 더욱 특별하게 만들어보세요! 손쉬운 결제로 매출 증대와 고객 만족을 동시에 경험하세요.
# 베를린의 소규모 레스토랑을 위한 신속하고 안전한 결제 서비스로 고객의 만족도를 높여보세요! 간편한 결제 솔루션으로 매출을 늘리고, 고객님의 소중한 시간을 아껴보세요.
# 베를린의 소규모 레스토랑을 위해, 복잡한 결제 과정을 간편하게 만들어 줄 혁신적인 결제 서비스를 만나보세요! 고객이 더욱 쉽게 결제할 수 있어 반복 방문을 유도하고, 귀하의 매출도 높일 수 있습니다.
# 베를린의 중급 레스토랑을 위해 특별히 설계된 스마트한 결제 솔루션으로 고객의 불편함을 줄이고 매출을 늘려보세요. 간편한 사용과 빠른 정산으로 귀하의 서비스 품질을 한층 더 높여드립니다!
# 베를린의 중규모 레스토랑을 위한 혁신적인 결제 솔루션! 고객의 편리함을 더하고, 매출을 증가시키는 지능형 시스템으로 차별화하세요!
# 베를린 중규모 레스토랑을 위한 스마트한 결제 서비스로 고객 경험을 혁신하세요! 간편한 결제 시스템으로 매출을 높이고, 고객의 재방문율을 끌어올릴 수 있습니다.
# 베를린의 대규모 레스토랑을 위한 새로운 이커머스 결제 서비스로 손쉬운 결제 경험을 제공하여 고객 만족도를 극대화하세요. 안전하고 효율적인 솔루션으로 매출을 높이고, 더 많은 손님을 맞이할 준비를 시작하세요!
# 베를린 대형 레스토랑의 매출을 극대화하세요! 저희의 혁신적인 이커머스 결제 서비스로 고객의 주문 과정을 간편하게 만들어 고객 만족도를 높이고, 매장을 더욱 효율적으로 운영해 보세요!
# 베를린의 대규모 레스토랑을 위한 혁신적인 이커머스 결제 솔루션으로, 고객의 유입을 극대화하고 결제 과정을 간소화하세요. 빠르고 안전한 결제로 손님들의 만족도를 높여 수익을 증가시키는 기회를 놓치지 마세요!
# “산티아고의 소규모 레스토랑을 위한 새로운 결제 솔루션으로 손쉽고 빠르게 고객의 결제를 처리하세요! 지금 도입하시면, 매출을 높이고 고객 만족도를 극대화하는 기회를 놓치지 마세요!”
# 귀하의 레스토랑 고객이 더욱 빠르고 편리하게 결제할 수 있도록, 우리 새로운 이커머스 결제 서비스로 매출을 더 높여보세요! 산티아고의 소규모 상점에 최적화된 솔루션으로, 경쟁력 있는 경험을 선사합니다.
# 작은 레스토랑도 큰 혜택을 누릴 수 있습니다! 우리의 간편한 이커머스 결제 서비스로 손님이 쉽게 결제하고, 판매량은 늘려보세요—산티아고에서 여러분의 성공을 지원합니다!
# 산티아고의 중규모 레스토랑을 위한 맞춤형 결제 솔루션! 고객의 결제를 간편하게 만들어 매출을 최대화하세요!
# 산티아고의 중규모 레스토랑들을 위한 혁신적인 이커머스 결제 서비스로 고객 편의를 극대화하세요! 빠르고 안전한 결제 시스템으로 매출을 올리고, 매장 경험을 한층 향상시켜 보세요!
# 산티아고의 중규모 레스토랑을 위해 설계된 혁신적인 이커머스 결제 서비스로, 고객의 결제 경험을 간편하고 빠르게 만들어 보세요! 지금 도입하시면 매출 증가와 고객 만족도를 동시에 누릴 수 있습니다!
# 고객의 주문을 더 빠르고 쉽게 처리하세요! 산티아고의 대규모 레스토랑을 위해 설계된 우리의 이커머스 결제 서비스로 수익을 극대화하고 고객 만족도를 높여보세요.
# 산티아고의 대규모 레스토랑을 위한 최적의 결제 솔루션으로, 고객의 경험을 한층 향상시키세요! 이제 간편하고 안전한 결제로 빠른 속도와 효율성을 누리십시오.
# “산티아고의 대규모 레스토랑을 위해 설계된 혁신적인 결제 솔루션으로, 고객의 마음을 사로잡고 매출을 극대화하세요. 쉽고 빠른 결제 경험이 고객의 재방문을 이끌어냅니다!”
# 브뤼셀의 소규모 패스트푸드점에 최적화된 우리의 새로운 이커머스 결제 서비스로 매출을 증대해보세요! 손쉬운 결제 시스템이 고객의 만족도를 높여 빠른 서비스와 반복 방문을 유도합니다.
# “브뤼셀의 소규모 패스트푸드점인 당신에게, 고객의 결제를 더 빠르고 간편하게 만들어줄 이커머스 결제 서비스를 소개합니다! 매출 상승과 고객 만족도를 동시에 잡을 기회를 놓치지 마세요!”
# 브뤼셀의 소규모 패스트푸드점을 위해, 고객이 더 쉽게 결제할 수 있는 새로운 이커머스 결제 서비스를 도입해 보세요! 더 빠르고 간편한 결제로 매출을 높이고, 고객 만족도를 극대화하세요!
# 브뤼셀의 패스트푸드점을 위해 설계된 혁신적인 결제 서비스로 고객의 대기 시간을 줄이고 매출을 높여보세요! 간편한 결제로 맛있는 순간을 놓치지 않도록 도와드립니다!
# 브뤼셀의 중규모 패스트푸드점에 딱 맞는 새로운 이커머스 결제 서비스로 고객의 결제 경험을 혁신하세요! 더 빠르고 간편한 결제로 매출을 증가시키고, 고객 만족도를 높여보세요!
# 브뤼셀의 패스트푸드점에 최적화된 우리의 이커머스 결제 서비스로, 고객의 주문을 더욱 간편하게 처리해보세요! 매출 증대와 빠른 결제 처리로 경쟁력을 높이세요.
# 브뤼셀의 대규모 패스트푸드점에 최적화된 이커머스 결제 서비스로, 고객의 주문을 더 빠르고 효율적으로 처리하세요! 매출 증대와 고객 만족도를 동시에 높이는 스마트한 선택, 지금 바로 경험해보세요!
# 브뤼셀의 대규모 패스트푸드점을 위한 혁신적인 결제 솔루션으로 고객의 대기 시간을 단축하고, 매출을 극대화하세요! 간편하고 빠른 결제가 고객 만족도를 높이는 비결입니다!
# 브뤼셀의 대규모 패스트푸드점에 꼭 맞는 혁신적인 결제 서비스로 매출을 극대화하세요! 간편하고 안전한 결제 접근으로 고객 경험을 개선하고, 빠른 서비스로 더 많은 고객을 맞이해 보세요!
# 파리의 소규모 패스트푸드점, 손쉽고 빠른 결제 서비스로 고객 만족도를 높여보세요! 매출을 증가시키고, 대기 시간을 줄이는 저희 결제 솔루션을 지금 경험해보세요!
# 파리의 소규모 패스트푸드점을 위한 혁신적인 결제 솔루션! 고객의 결제를 간편하게 만들어 매출을 높이고, 대기 시간을 줄이세요!
# “파리의 소규모 패스트푸드점을 위해 최적화된 새로운 결제 서비스로 고객의 편리함을 더하세요! 간편한 결제로 대기 시간을 줄여 매출을 높이고, 고객 만족도를 극대화해보세요.”
# 파리의 중규모 패스트푸드점을 위한 최적의 결제 솔루션! 고객의 편리함을 더하고 매출을 skyrocketing 시켜줄 이커머스 결제 서비스를 지금 도입해보세요!
# 파리의 패스트푸드점이라면, 고객 만족을 높일 수 있는 혁신적인 이커머스 결제 서비스로 매출을 증가시켜보세요! 간편하고 빠른 결제가 고객을 매장으로 끌어들이는 비밀입니다.
# “패스트푸드의 세계를 더 빠르고 간편하게! 저희 이커머스 결제 서비스로 파리의 중소형 식당이 고객의 멋진 식사 경험을 혁신적으로 변화시킬 수 있습니다.”
# 파리의 대규모 패스트푸드점에게 맞춤형 이커머스 결제 시스템을 도입하여 결제를 더 빠르고 간편하게 만들어 보세요! 고객의 만족도를 높이고 매출을 극대화하는 기회를 놓치지 마세요!
# 파리의 대규모 패스트푸드점에 최적화된 새로운 결제 서비스를 도입하여 고객의 대기 시간을 줄이고 매출을 극대화하세요! 혁신적인 결제 솔루션으로 빠른 서비스와 높은 고객 만족을 동시에 실현해보세요!
# 파리의 대규모 패스트푸드점에 최적화된 우리의 이커머스 결제 서비스로 고객에게 빠르고 편리한 장바구니 경험을 제공하세요! 매출 증대를 위한 스마트한 선택, 지금 바로 시작해보세요!
# 부줌부라의 소규모 패스트푸드점, 이제 더욱 간편하게! 최신 이커머스 결제 서비스를 통해 고객의 주문을 신속하게 처리하고, 매출을 극대화하세요!
# 부줌부라의 소규모 패스트푸드점이신가요? 고객이 더 빠르고 간편하게 결제할 수 있는 혁신적인 이커머스 결제 서비스를 도입해 보세요, 매출을 높이고 고객 만족도를 극대화할 수 있습니다!
# 부줌부라의 소규모 패스트푸드점에서 고객의 결제 경험을 한층 향상하세요! 저희 새로운 이커머스 결제 서비스로 빠르고 간편한 결제를 제공해 더 많은 손님을 맞이해보세요!
# 부줌부라의 중규모 패스트푸드점에서 고객님들의 결제를 더욱 빠르고 원활하게 처리하세요! 저희의 혁신적인 이커머스 결제 서비스로 매출을 극대화하고 고객 만족도를 높여보세요!
# 부줌부라의 중규모 패스트푸드점에 최적화된 이커머스 결제 서비스로, 손쉬운 결제 프로세스와 매출 증대의 기회를 경험해보세요. 고객의 빠른 선택과 편리한 결제를 통해 더 많은 고객을 끌어들이세요!
# 부줌부라의 중규모 패스트푸드점에 최적화된 이커머스 결제 서비스로, 매장을 찾는 고객들에게 더 빠르고 간편한 결제 경험을 제공합니다. 지금 등록하시면 고객 유치와 매출 증대의 기회를 놓치지 마세요!
# 부줌부라의 대규모 패스트푸드점에 완벽한 이커머스 결제 서비스로 고객의 주문 경험을 혁신하세요! 간편하고 빠른 결제로 매출을 높여보세요!
# “부줌부라의 대규모 패스트푸드점도 쉽게 결제하세요! 우리 이커머스 결제 서비스로 고객의 대기 시간을 줄이고 매출을 늘리세요.”
# 부줌부라의 대규모 패스트푸드점을 위한 혁신적인 결제 솔루션으로 고객에게 더 빠르고 편리한 주문 경험을 제공하세요! 지금 도입하시면 매출 증대와 재방문율 향상을 동시에 누리실 수 있습니다.
# “베를린의 소규모 패스트푸드점 고객을 사로잡으세요! 최신 이커머스 결제 서비스로 간편하고 빠른 결제를 제공하여 매출을 늘리고, 방문객들을 다시 찾아오게 만드세요!”
# “베를린의 소규모 패스트푸드점에서 손쉽고 빠른 결제를 통해 고객 만족도를 높여보세요! 새로운 이커머스 결제 서비스로 매출을 극대화하고, 대기 시간을 줄여 여러분의 맛있는 음식을 더 많은 고객에게 전하세요!”
# 귀하의 소규모 패스트푸드점을 위해 더 빠르고 간편한 결제 솔루션을 제공합니다! 고객 경험을 향상시키고 베를린의 경쟁에서 앞서 나가세요!
# “베를린의 중규모 패스트푸드점 고객을 위해 설계된 혁신적인 결제 서비스를 통해 주문과 결제의 속도를 극대화하세요! 고객의 만족을 높이고, 매출을 끌어올리는 스마트한 선택을 지금 바로 만나보세요!”
# “베를린의 중규모 패스트푸드점을 위한 혁신적인 결제 솔루션으로 고객 대기 시간을 단축하고 매출을 증대시켜 보세요! 간편하고 안전한 결제 경험을 통해 경쟁력을 높이고 더 많은 고객을 맞이하세요.”
# 베를린의 중규모 패스트푸드점에 최적화된 이커머스 결제 서비스로, 고객의 주문을 더욱 간편하고 빠르게 처리하세요! 지금 도입하면 매출 상승의 기회를 놓치지 않을 것입니다.
# 베를린의 대규모 패스트푸드점에 꼭 필요한 혁신! 손쉬운 결제로 고객의 방문을 늘리고, 빠른 서비스로 매출을 극대화하세요!
# 베를린의 대규모 패스트푸드점에게 최적화된 결제 서비스를 제공하여 고객의 대기 시간을 단축하고 매출을 극대화하세요! 우리의 혁신적인 결제 솔루션으로 빠르고 간편한 결제 경험을 선사하며, 고객의 만족도를 높여드립니다.
# 베를린의 대규모 패스트푸드점을 위한 최적의 결제 솔루션! 빠르고 간편한 결제로 고객 만족도를 높이고, 매출 상승의 기회를 놓치지 마세요!
# “귀하의 패스트푸드점에 번개 같은 결제 속도를 더해보세요! 새로운 이커머스 결제 서비스로 고객의 대기 시간을 줄이고 매출을 높여보세요!”
# 빠르고 간편한 결제 서비스로 고객 대기 시간을 단축하세요! 산티아고의 소규모 패스트푸드점에 최적화된 솔루션으로 매출을 높여보세요!
# 산티아고의 소규모 패스트푸드점에 최적화된 결제 솔루션으로 고객의 주문을 빠르게 받아보세요! 지금 가입하시면 고객 만족도와 매출 상승을 동시에 경험하실 수 있습니다.
# 산티아고의 중규모 패스트푸드점에서 더 빠르고 효율적인 결제를 경험하세요! 우리의 새로운 이커머스 결제 서비스가 고객 대기를 줄여주고 매출을 올리는 데 도움을 드립니다.
# “산티아고의 중규모 패스트푸드점에 최적화된 새로운 결제 서비스를 도입하여 고객 대기 시간을 획기적으로 줄이고, 매출 증대의 기회를 놓치지 마세요! 지금 바로 시작하여 더 많은 고객을 맞이하는 스마트한 선택을 하세요!”
# 산티아고의 중소 패스트푸드점에 최적화된 결제 서비스를 도입해보세요! 고객들이 더욱 빠르고 간편하게 결제할 수 있어 매출이 향상됩니다.
# 산티아고의 대규모 패스트푸드점을 위한 혁신적인 결제 서비스, 고객 경험을 한층 더 향상시키고 매출 증대에 기여합니다! 지금 바로 도입하여 빠르고 쉽고 안전한 결제를 경험해 보세요!
# 산티아고의 대규모 패스트푸드점에 최적화된 결제 서비스로 고객의 대기 시간을 줄이고, 매출을 극대화하세요! 지금 바로 함께 성장하는 기회를 잡아보세요.
# 산티아고의 대규모 패스트푸드점에 최적화된 결제 솔루션으로 고객의 주문을 빠르고 쉽게 처리하세요! 신속한 결제 시스템이 고객 만족도를 높이고 매출을 증대시킬 것입니다.
# 브뤼셀 소규모 약국을 위해 특별히 설계된 이커머스 결제 서비스로, 환자분들에게 더 빠르고 안전한 결제를 제공하세요. 손쉬운 통합과 비용 절감으로 매출을 높이고 고객 만족도를 극대화하세요!
# 브뤼셀의 소규모 약국을 위해 설계된 새로운 이커머스 결제 서비스로 고객의 구매 경험을 혁신하세요. 간편한 결제 시스템으로 매출을 증대시키고, 고객 충성도를 높이는 기회를 놓치지 마세요!
# 브뤼셀의 소규모 약국을 위해 특별히 설계된 저희 이커머스 결제 서비스로, 고객의 쇼핑 경험을 한층 개선하세요. 간편한 결제 시스템으로 매출을 올리고 서비스 만족도를 높여보세요!
# 브뤼셀의 중규모 약국을 위해 설계된 우리의 이커머스 결제 서비스로 고객 편의를 극대화하세요! 손쉬운 결제 시스템으로 매출을 높이고, 고객의 재방문을 유도해 보세요!
# 브뤼셀의 중규모 약국을 위한 필수 선택! 간편하고 안전한 결제 서비스로 고객에게 더 나은 쇼핑 경험을 제공하세요!
# 브뤼셀의 중규모 약국에 최적화된 이커머스 결제 서비스로, 고객의 편리함을 극대화하세요! 간편한 결제 솔루션이 매출을 높이고 고객 만족도를 한층 향상시킵니다.
# 브뤼셀의 대규모 약국을 위해 최적화된 이커머스 결제 서비스를 도입하여 고객의 편리함을 증대시키고 판매를 극대화하세요. 지금 바로 새로운 결제 솔루션으로 변화의 물결을 경험해 보세요!
# 브뤼셀 대규모 약국에 최적화된 이커머스 결제 서비스로, 고객의 편리한 쇼핑 경험을 제공하세요! 간편한 결제 시스템으로 매출을 증대시키고, 고객의 신뢰를 더욱 강화해보세요.
# 브뤼셀의 대규모 약국을 위해 특별히 설계된 이커머스 결제 서비스로, 고객의 편리한 쇼핑을 지원하세요! 우리의 솔루션은 거래 효율성을 높여 매출 증가에 기여하며, 고객 만족도를 극대화할 수 있습니다.
# 파리의 소규모 약국을 위해 설계된 혁신적인 이커머스 결제 솔루션으로 고객의 편리함을 극대화하세요. 쉽고 빠른 결제로 매출을 높이고, 고객 만족도를 한층 업그레이드해 보세요!
# 파리의 소규모 약국을 위해 특별히 설계된 새로운 이커머스 결제 서비스를 통해 손쉽게 고객의 마음을 사로잡으세요! 더 빠르고 안전한 결제로 매출을 늘리는 기회를 놓치지 마세요!
# 파리의 소규모 약국을 위한 혁신적인 결제 솔루션! 고객의 편리함을 높이고, 결제 속도를 혁신적으로 개선하여 매출을 증가시키세요!
# 파리의 중규모 약국을 위해 설계된 혁신적인 이커머스 결제 서비스로 고객의 쇼핑 경험을 한층 향상시키세요! 간편하고 안전한 결제로, 고객의 재방문율도 높아질 것입니다.
# 파리의 중규모 약국을 위한 최신 이커머스 결제 서비스! 고객의 편리함을 극대화하고 판매를 증대시켜보세요—간편하고 안전한 결제로 고객의 재방문율이 높아집니다!
# 파리의 중규모 약국을 위한 혁신적인 결제 솔루션, 고객의 편안함을 더하세요! 빠르고 안전한 결제로 매출을 증대시키고, 환자의 만족도를 높이는 기회를 놓치지 마세요!
# 파리의 대규모 약국에 혁신적인 결제 시스템을 도입해 보세요! 고객 경험을 한층 향상시키고, 결제 속도를 높여 매출을 극대화하는 기회를 놓치지 마세요!
# 파리의 대규모 약국에 최적화된 이커머스 결제 솔루션으로 고객에게 더욱 편리한 쇼핑 경험을 제공하세요. 매출 증대와 고객 재방문율을 높이는 스마트한 선택, 지금 문의해 보세요!
# 당신의 대규모 약국에 최적화된 이커머스 결제 서비스를 도입하여 고객의 편리함을 극대화하세요! 파리의 고객들이 보다 쉽게 건강을 챙길 수 있도록 혁신적인 결제 솔루션을 통해 귀하의 판매를 성장시키십시오.
# 부줌부라의 소규모 약국을 위한 새로운 이커머스 결제 서비스로 고객의 편리함을 극대화하세요! 간단한 절차로 고객이 언제 어디서나 쉽게 주문하고 결제할 수 있어, 매출 증가와 고객 만족을 이끌어낼 수 있습니다.
# 부줌부라의 소규모 약국도 최신 이커머스 결제 솔루션으로 고객의 편리함을 더하세요! 쉽고 안전한 결제 시스템으로 판매를 늘리고, 고객의 신뢰를 구축하세요!
# 부줌부라 소규모 약국에게 최적화된 결제 서비스를 통해 고객의 편리를 높여보세요! 더 간편한 결제 시스템으로 매출을 증대시키고, 고객 만족도를 한층 높여드릴 수 있습니다!
# 부줌부라 중규모 약국의 성장을 도와줄 혁신적인 이커머스 결제 서비스로 고객 서비스를 향상시켜보세요! 간편하고 안전한 결제 시스템으로 고객의 만족도를 높이고, 매출을 증대시키는 최적의 솔루션입니다.
# 부줌부라의 중규모 약국에 새로운 이커머스 결제 서비스를 도입하여 고객의 편리함을 극대화하세요! 더 쉽고 빠른 결제로 매출을 높이고, 믿을 수 있는 파트너와 함께 성장해 나갑니다.
# 부줌부라의 중규모 약국을 위한 맞춤형 결제 솔루션으로 고객의 편리함을 더하세요! 간편한 결제 시스템으로 재방문 고객을 늘리고, 약국 매출을 극대화하세요!
# 부줌부라의 대규모 약국을 위한 혁신적인 이커머스 결제 서비스로 고객의 소중한 시간을 절약하세요! 더 빠르고 안전한 결제 시스템으로 약국의 매출을 증가시키고, 고객 만족도를 극대화해보세요!
# 부줌부라 대규모 약국에 최적화된 이커머스 결제 서비스로 고객의 쇼핑 경험을 혁신하세요! 간편하고 안전한 결제 시스템으로 더 많은 고객을 유치하고 매출을 최대화할 수 있습니다.
# 부줌부라의 대규모 약국을 위한 최첨단 이커머스 결제 서비스를 도입해 보세요! 고객의 편리함을 높이며, 매출 성장의 새로운 기회를 창출할 수 있습니다.
# 귀하의 약국이 더 빠르고 안전한 결제를 통해 고객의 신뢰를 얻을 수 있습니다! 우리의 이커머스 결제 서비스로 베를린의 소규모 상점에 적합한 솔루션을 만나보세요.
# 베를린의 소규모 약국을 위한 스마트한 결제 솔루션! 고객의 편리함을 더하고, 매출을 높이는 기회를 놓치지 마세요!
# 베를린의 소규모 약국을 위해, 더 빠르고 간편한 결제를 제공하는 새로운 이커머스 솔루션으로 고객의 만족도를 높여보세요! 설치는 간편하고, 고객들은 더욱 편리하게 약을 구매할 수 있습니다.
# 베를린의 중규모 약국을 위한 혁신적인 이커머스 결제 서비스로, 고객 경험을 극대화하고 매출을 상승시키세요. 간편한 결제로 당신의 약국이 더 많은 고객을 유치하고, 성장을 이뤄낼 수 있습니다!
# 베를린의 중규모 약국을 위해 설계된 새로운 이커머스 결제 서비스로, 고객의 편리함을 더하고 매출을 높여보세요! 쉽고 빠른 결제 솔루션으로, 약국 운영에 혁신을 가져오는 기회를 놓치지 마세요!
# 베를린의 중규모 약국을 위해 설계된 새로운 이커머스 결제 서비스로 고객의 편리함을 더하세요! 안전하고 효율적인 결제로 매출을 높이고, 환자들에게는 더 나은 쇼핑 경험을 제공하세요.
# 베를린의 대규모 약국을 위한 특별한 기회! 간편하고 안전한 결제 서비스로 고객 만족도를 높이고, 매출을 극대화하세요!
# 베를린의 대규모 약국을 위한 최적의 해결책! 우리의 이커머스 결제 서비스로 고객의 편의를 높이고, 매출을 극대화하세요!
# 베를린의 대규모 약국을 위해 설계된 우리의 혁신적인 이커머스 결제 서비스로 고객의 편리한 쇼핑 경험을 선사하세요. 빠르고 안전한 결제 시스템으로 매출을 증대시키고, 고객 만족도를 높이는 기회를 놓치지 마세요!
# “산티아고의 소규모 약국을 위해 설계된 혁신적인 이커머스 결제 서비스로 고객의 쇼핑 경험을 한층 향상시켜 보세요! 손쉬운 결제와 안전한 거래로 매출을 증대시키고, 고객의 신뢰를 더하세요.”
# 산티아고의 소규모 약국을 위한 결제 혁신! 간편한 이커머스 결제 서비스로 고객의 쇼핑 경험을 더 편리하게 만들어보세요, 판매 증진을 경험할 수 있습니다!
# 당신의 약국에 맞춤형 결제 솔루션을 도입하여 고객의 수월한 쇼핑 경험을 선사하세요! 작은 변화로 고객 만족도를 높이고, 매출 상승을 경험해보세요.
# 산티아고의 중규모 약국을 위한 혁신적인 이커머스 결제 서비스! 고객의 편리함을 더하고, 매출을 극대화하세요—지금 바로 무료 체험을 신청해 보세요!
# 귀하의 약국에 새로운 이커머스 결제 서비스를 도입하여 고객의 편의를 극대화하세요! 간편하고 안전한 결제로 매출을 높이고, 산티아고에서 더 많은 고객을 만나보세요!
# 산티아고의 중규모 약국을 위해 설계된 새로운 이커머스 결제 서비스로 고객의 편리함을 더욱 높여보세요! 안전하고 빠른 결제로 매출을 증대시키고, 고객 만족도를 극대화하는 기회를 놓치지 마세요!
# “산티아고 대규모 약국을 위한 혁신적인 이커머스 결제 서비스로 고객의 쇼핑 경험을 한 단계 끌어올리세요! 안전하고 빠른 결제로 매출을 증가시키고, 고객 만족도를 높여보세요.”
# 산티아고의 대규모 약국을 위한 혁신적인 이커머스 결제 서비스로, 고객의 쇼핑 경험을 한층 향상시키세요. 더 쉽고 빠른 결제 시스템으로 매출을 증대시키고, 새로운 고객을 유치하는 기회를 놓치지 마세요!
# “산티아고의 대규모 약국을 위해 설계된 최신 이커머스 결제 서비스로, 고객에게 안전하고 빠른 쇼핑 경험을 제공하세요! 지금 도입하시면 매출 증가와 고객 만족도가 한층 올라갑니다.”
# “브뤼셀의 소규모 주유소를 위해 맞춤 설계된 혁신적인 결제 시스템으로 고객 편의를 높이고 매출을 증대하세요! 간편한 결제로 고객을 끌어들이고, 경쟁력을 키우는 기회를 놓치지 마세요!”
# 브뤼셀의 소규모 주유소를 위해 특별히 설계된 우리의 새로운 이커머스 결제 서비스로 고객의 편리함을 혁신하세요! 간편 결제 시스템으로 판매를 높이고, 고객 경험을 개선하는 데 지금 바로 참여해보세요.
# 브뤼셀의 소규모 주유소를 위한 혁신적인 결제 솔루션! 고객의 편리함을 더하고 매출을 올릴 기회를 놓치지 마세요!
# 브뤼셀 중규모 주유소 고객을 위한 새로운 결제 서비스로 대기 시간을 줄이고, 매출을 증가시켜보세요! 지금 도입하면 원활한 결제 경험과 고객 만족도를 동시에 높일 수 있습니다.
# 브뤼셀의 중규모 주유소에서 고객 결제 경험을 혁신하세요! 우리의 새로운 이커머스 결제 서비스로 간편하고 빠른 결제를 제공해 고객을 더 끌어당기세요.
# 주유소의 수익을 극대화하세요! 저희의 새로운 이커머스 결제 서비스로 고객의 편리함을 더하고, 매출도 함께 성장시켜 보세요!
# 브뤼셀의 대규모 주유소에 혁신적인 이커머스 결제 서비스를 도입해 고객의 구매 경험을 극대화하세요! 간편하고 빠른 결제 시스템으로 효율성을 높이고, 매출 상승의 기회를 놓치지 마세요!
# 브뤼셀의 대규모 주유소를 위한 혁신적인 이커머스 결제 서비스로 고객의 편리함을 높여보세요! 빠르고 안전한 결제로 고객 유치와 매출 증가를 이끌어내는 기회를 놓치지 마세요!
# 브뤼셀의 대규모 주유소를 위한 혁신적인 결제 서비스로 고객의 편리를 극대화하세요! 손쉬운 결제 경험으로 재방문율을 높이고, 매출 상승을 체감해 보세요!
# 파리의 소규모 주유소를 위해, 손쉽고 안전한 결제 솔루션으로 고객의 발길을 사로잡아 보세요! 더 빠른 결제, 더 많은 고객, 더 큰 수익을 경험할 준비가 되셨나요?
# 파리의 소규모 주유소를 위해 맞춤 설계된 간편한 이커머스 결제 서비스로 고객의 편리함을 업그레이드하세요! 혁신적인 기술로 매출 상승과 고객 만족을 동시에 이끌어냅니다.
# 파리의 소규모 주유소를 위한 맞춤형 결제 솔루션! 간편하고 안전한 결제로 고객의 경험을 향상시키고, 매출을 높여보세요!
# 모던한 결제 솔루션으로 고객의 주유 경험을 더욱 향상시켜 보세요! 파리의 중규모 주유소에 최적화된 저희 이커머스 결제 서비스가 매출 증대와 고객 만족을 한 번에 잡아드립니다.
# 파리의 중규모 주유소를 위한 새로운 이커머스 결제 서비스로 고객의 편리함을 극대화하세요! 간편한 결제를 통해 매출을 높이고, 경쟁력을 강화하는 기회를 놓치지 마세요!
# 파리의 중규모 주유소를 위해 특별히 설계된 우리의 새로운 결제 서비스로 고객의 결제를 더욱 간편하게 만들어 보세요! 경쟁력을 높이고, 매출을 증가시키는 혁신적인 솔루션이 여러분을 기다리고 있습니다.
# 파리의 대규모 주유소에 최적화된 이커머스 결제 서비스로 고객의 결제를 더욱 간편하게! 현대적이고 안전한 결제로 매출을 증가시키세요!
# 파리의 대규모 주유소를 위해 설계된 우리의 혁신적인 이커머스 결제 서비스로 고객의 쇼핑 경험을 한층 더 향상시키세요! 더 빠르고 안전한 결제로 매출을 증가시키고, 고객 만족도를 높일 수 있는 기회를 놓치지 마세요!
# “파리의 대규모 주유소를 위한 혁신적인 결제 솔루션으로 고객의 대기 시간을 줄여보세요! 간편하고 안전한 결제 시스템으로 매출 상승을 경험해보세요.”
# 🚀 작은 주유소도 큰 혜택을! 부줌부라에서 새로운 이커머스 결제 서비스로 고객 만족도를 높이고 매출을 키우세요! 💡✋
# 부줌부라의 소규모 주유소를 위한 신속하고 안전한 이커머스 결제 서비스로 고객 만족도를 높여보세요! 간편한 결제로 매출을 늘리고, 여러분의 비즈니스를 혁신하세요!
# 부줌부라의 소규모 주유소에 특화된 이커머스 결제 서비스로 고객님께 더 빠르고 간편한 결제를 제공합니다. 지금 도입하셔서 판매를 늘리고 고객 만족도를 높이세요!
# 부줌부라의 중규모 주유소에 완벽한 이커머스 결제 솔루션으로 고객의 결제를 간편하게! 더 많은 고객을 유치하고 판매를 증대시키는 기회를 놓치지 마세요!
# 부줌부라의 중규모 주유소를 위한 새로운 이커머스 결제 서비스로 고객의 편리함을 더하세요! 간편한 결제 시스템이 매출 상승을 이끌어 드립니다.
# 부줌부라의 중규모 주유소에서 이커머스 결제 서비스를 도입하면 고객의 편의성을 극대화하고 매출을 증가시킬 수 있습니다. 혁신적인 결제 솔루션으로 경쟁력을 높이며, 고객의 사랑을 한층 더 받으세요!
# 부줌부라의 대규모 주유소에 최적화된 이커머스 결제 서비스로 고객의 온라인 쇼핑 경험을 혁신하세요! 손쉬운 결제 시스템으로 매출을 증가시키고, 고객 만족도를 높여보세요.
# “부줌부라의 대규모 주유소에서 고객의 결제를 간편하게! 우리의 새로운 이커머스 결제 서비스로 매출을 증가시키고, 고객 만족도를 높여보세요!”
# 부줌부라의 대규모 주유소를 위한 혁신적인 이커머스 결제 서비스로 고객의 대기 시간을 줄이고 매출을 극대화하세요! 우리의 간편하고 안전한 결제 솔루션이 당신의 주유소를 다음 단계로 발전시켜 드립니다.
# 베를린의 소규모 주유소에 최적화된 새로운 이커머스 결제 서비스로 고객의 결제 경험을 혁신하세요! 쉽고 빠른 결제 솔루션으로 매출을 올리고, 고객 만족도를 높이는 기회를 놓치지 마세요!
# 베를린의 소규모 주유소를 위해, 간편하고 안전한 이커머스 결제 서비스를 도입하세요! 고객의 편리함을 더하고 매출은 UP, 비즈니스를 새롭게 성장시킬 기회를 놓치지 마세요!
# 베를린의 소규모 주유소를 위해 설계된 새로운 결제 서비스로 손쉽게 고객의 결제를 개선하세요! 빠르고 안전한 결제로 고객 만족도를 높이고, 번거로운 절차는 저희가 처리합니다.
# 베를린의 중규모 주유소를 위한 혁신적인 결제 솔루션! 고객의 편리한 결제를 통해 매출을 증대시키고, 차별화된 서비스를 제공해 보세요!
# 베를린의 중규모 주유소를 위한 혁신적 결제 솔루션으로 고객의 결제를 더 간편하게! 스마트한 결제 서비스로 매출을 높이고 고객 경험을 극대화하세요!
# 베를린의 중규모 주유소를 위해 설계된 혁신적인 이커머스 결제 서비스를 도입해 보세요! 고객의 편의를 극대화하고 매출을 증대시킬 기회를 지금 잡아보세요!
# 베를린의 대규모 주유소를 위한 혁신적인 결제 솔루션으로 고객의 구매 경험을 혁신하세요! 빠르고 안전한 결제 시스템으로 매출을 극대화하며, 고객의 재방문을 유도하는 스마트한 선택입니다.
# 베를린의 대규모 주유소를 위한 혁신적인 결제 솔루션으로 고객 선호도를 극대화하세요! 간편한 결제 프로세스로 매출을 증대시키고, 고객 만족을 향상시킬 기회를 놓치지 마세요!
# 베를린의 대규모 주유소를 위한 스마트한 결제 솔루션! 고객의 편리함을 극대화하고, 매출 상승을 경험하세요!
# 산티아고의 소규모 주유소를 위해 특별히 설계된 우리의 이커머스 결제 서비스로 고객의 결제 경험을 혁신하세요! 빠르고 간편한 결제로 매출을 증가시키고 고객 충성도를 높여보세요.
# 귀하의 주유소에 혁신적인 결제 서비스를 도입해 보세요! 산티아고의 소규모 상점으로서 고객 편의성을 극대화하고 판매를 증가시킬 기회를 놓치지 마십시오.
# 산티아고의 소규모 주유소를 위해 맞춤 설계된 최첨단 결제 솔루션으로 고객의 편리함을 높이세요! 매출 증가와 고객 만족을 동시에 이끄는 기회를 놓치지 마세요!
# “산티아고의 중규모 주유소를 위한 완벽한 결제 솔루션! 고객의 편리한 결제를 통해 매출을 증가시키고, 주유소 운영의 효율성을 극대화하세요!”
# 산티아고의 중규모 주유소를 위한 혁신적인 결제 솔루션으로 고객에게 더 빠르고 편리한 서비스를 제공하세요! 오늘 가입하시면 특별 할인 혜택까지 경험하실 수 있습니다.
# 산티아고의 중규모 주유소를 위한 혁신적인 결제 시스템으로 고객의 편리함을 극대화하세요! 빠르고 안전한 결제가 매출을 높이고 고객 만족도를 높이는 비결이 됩니다!
# 산티아고의 대규모 주유소에 최적화된 우리의 새로운 이커머스 결제 서비스로 고객의 편리함을 극대화하세요! 빠르고 안전한 결제 시스템을 도입하여 더 많은 고객을 유치하고 매출을 증대시킬 수 있는 기회를 놓치지 마세요.
# “산티아고의 대규모 주유소를 위한 최고의 해결책! 우리의 이커머스 결제 서비스로 고객의 결제 경험을 한층 간편하고 신속하게 만들어보세요!”
# “산티아고의 대규모 주유소에 최적화된 이커머스 결제 서비스로 고객 경험을 혁신하세요! 간편하고 안전한 결제를 통해 매출을 극대화하고 경쟁력을 강화해보세요.”
# 브뤼셀의 소규모 전자제품 매장을 위한 혁신적인 결제 솔루션! 고객의 쇼핑 경험을 향상시키고, 매출을 늘리는 기회를 놓치지 마세요!
# 브뤼셀의 소규모 전자제품 매장을 위한 혁신적인 결제 서비스를 통해 고객 경험을 한층 더 향상시켜 보세요! 매장에서의 빠르고 안전한 결제는 고객의 만족도와 재방문율을 높이는 열쇠입니다.
# 브뤼셀의 소규모 전자제품 매장을 위해 설계된 간편하고 안전한 결제 솔루션으로 고객의 쇼핑 경험을 한층 개선하세요! 우리 서비스로 매출을 높이고 스트레스를 줄여보세요!
# 브뤼셀의 중규모 전자제품 매장을 위한 혁신적인 결제 서비스로 고객의 쇼핑 경험을 한 단계 향상시켜 보세요! 이제 더 빠르고 안전한 결제로 매출 상승을 경험하세요!
# 브뤼셀의 중규모 전자제품 매장을 위해 맞춤 설계된 혁신적인 결제 서비스로 고객의 쇼핑 경험을 한층 향상하세요! 간편한 결제로 매출을 높이고, 재구매율을 끌어올릴 기회를 놓치지 마세요!
# “브뤼셀의 전자제품 매장에 최적화된 결제 솔루션으로, 고객의 쇼핑 경험을 혁신하세요! 간편한 결제 시스템으로 매출을 증가시키고, 고객의 사랑받는 상점으로 성장할 수 있습니다.”
# 브뤼셀의 대규모 전자제품 매장에 최적화된 새로운 이커머스 결제 서비스로 고객의 쇼핑 경험을 혁신해 보세요! 간편하고 안전한 결제로 매출을 극대화하고, 고객 충성도를 높이세요.
# 브뤼셀의 대규모 전자제품 매장에 최적화된 혁신적인 이커머스 결제 솔루션으로 고객의 쇼핑 경험을 한 단계 업그레이드하세요! 효율적인 결제 시스템으로 매출을 극대화하고, 고객의 만족도를 높여보세요!
# 브뤼셀의 대규모 전자제품 매장에서 고객에게 더욱 편리한 쇼핑 경험을 제공하세요! 저희 이커머스 결제 서비스로 결제를 간소화하고, 판매량을 극대화할 수 있는 새로운 기회를 잡으세요!
# 파리의 소규모 전자제품 매장을 운영하시나요? 최신 이커머스 결제 서비스로 고객의 쇼핑 경험을 혁신하고, 매출을 폭발적으로 성장시켜 보세요!
# 파리의 소규모 전자제품 매장을 위해 맞춤 설계된 새로운 결제 서비스로 고객의 쇼핑 경험을 한층 향상시켜보세요! 간편하고 안전한 결제로 매출 증대와 함께 고객 충성도를 높이는 기회를 놓치지 마세요!
# 파리의 소규모 전자제품 매장에 최적화된 결제 서비스를 통해 고객의 비즈니스를 혁신하세요. 빠르고 안전한 결제 시스템으로 매출을 높이고 고객 만족도를 극대화하세요!
# 파리의 중규모 전자제품 매장에 최적화된 결제 서비스를 도입해 보세요! 고객의 다양한 결제 방식으로 편리함을 더하고, 매출 상승을 경험하세요!
# 파리의 중소 전자제품 매장에 최적화된 이커머스 결제 서비스로 고객의 쇼핑 경험을 혁신하세요! 쉽고 빠른 결제로 매출을 증대시키고, 고객 만족도를 높여보세요!
# 파리의 중소 전자제품 매장이 더 스마트하게 결제하는 방법! 혁신적인 이커머스 결제 서비스를 통해 고객 경험을 한 단계 업그레이드하세요.
# 파리의 대규모 전자제품 매장을 위한 혁신적인 결제 서비스로, 고객의 쇼핑 경험을 더욱 간편하고 빠르게 만들어 보세요! 지금 도입하면 매출 증가 및 고객 만족도를 높일 수 있는 기회를 놓치지 마세요!
# 파리의 대규모 전자제품 매장에 최적화된 우리의 이커머스 결제 서비스를 통해 고객의 구매 경험을 혁신하세요. 더 간편하고 안전한 결제 솔루션으로 매출을 극대화하며 경쟁력을 한층 강화해 보세요!
# 파리의 대규모 전자제품 매장에서 고객의 결제 경험을 혁신하세요! 우리의 최신 이커머스 결제 서비스로 더 빠르고 편리한 쇼핑을 제공해 매출을 극대화해보세요!
# 부줌부라의 소규모 전자제품 매장을 위한 최적의 결제 솔루션을 소개합니다! 고객의 편리함을 고려한 이커머스 결제 서비스를 통해 매출을 늘리고, 더 많은 구매를 유도해보세요!
# 부줌부라의 소규모 전자제품 매장을 위해 특별히 설계된 우리 이커머스 결제 서비스로 매출을 높여보세요! 간편하고 안전한 결제 시스템으로 고객의 구매 경험을 혁신하세요!
# 부줌부라의 소규모 전자제품 매장을 위한 특별한 결제 서비스, 이제 고객의 편리함을 한층 더 높여보세요! 우리 서비스를 통해 결제 과정에서의 복잡함을 없애고, 매출을 증가시키는 기회를 잡으세요.
# 부줌부라의 전자제품 매장에 최적화된 결제 서비스를 도입해 보세요! 손쉬운 결제 프로세스로 고객의 만족도를 높이고, 매출을 증대시킬 기회를 놓치지 마세요!
# 부줌부라의 중규모 전자제품 매장에 최적화된 혁신적인 이커머스 결제 서비스를 도입해 보세요! 더 간편한 결제 과정으로 고객의 만족도를 높이고 판매를 증대시킬 기회를 놓치지 마세요!
# 부줌부라의 중규모 전자제품 매장에 번거로움 없는 결제를 제안합니다! 저희의 새로운 이커머스 결제 서비스로 고객 경험을 혁신하고, 판매를 촉진하세요!
# 부줌부라의 대규모 전자제품 매장을 위한 혁신적인 결제 솔루션을 도입해 보세요! 고객의 쇼핑 경험을 개선하고, 빠르고 안전한 결제로 매출을 극대화하세요!
# “부줌부라의 대규모 전자제품 매장을 위해 특별히 설계된 우리의 새로운 이커머스 결제 서비스로, 고객들에게 신속하고 안전한 쇼핑 경험을 제공하세요. 매출 증가와 고객 만족을 동시에 잡을 수 있는 기회를 놓치지 마세요!”
# 부줌부라의 대규모 전자제품 매장을 위해 혁신적인 이커머스 결제 서비스를 도입하세요! 고객 만족도를 높이고, 구매 전환율을 극대화하여 판매 성과를 한층 끌어올릴 기회를 놓치지 마세요.
# “베를린의 소규모 전자제품 매장을 위해 설계된 혁신적인 결제 서비스로 고객의 편리한 쇼핑 경험을 제공합니다. 지금 이 서비스와 함께 매출을 높이고 고객 만족을 극대화하세요!”
# 베를린의 소규모 전자제품 매장에서 고객의 결제를 간편하게 만들어보세요! 저희 혁신적인 이커머스 결제 서비스로 매출 증대를 경험하고, 손쉽게 고객의 신뢰를 얻으세요!
# 베를린의 소규모 전자제품 매장에서 결제의 모험을 시작하세요! 우리 이커머스 결제 서비스로 고객의 쇼핑 경험을 혁신하고, 매출을 높이세요!
# 베를린의 중규모 전자제품 매장에 혁신을 가져오세요! 우리의 간편한 이커머스 결제 서비스로 고객의 쇼핑 경험을 향상시키고 판매를 극대화하세요.
# 베를린의 중규모 전자제품 매장을 위한 혁신적인 결제 서비스로 고객의 쇼핑 경험을 혁신하세요! 간편한 결제 과정으로 매출을 증가시키고, 고객의 재방문을 유도하는 기회를 놓치지 마세요.
# 베를린의 중소 전자제품 매장에 최적화된 새로운 이커머스 결제 서비스를 통해 매출을 극대화하세요! 고객의 손쉽고 빠른 결제를 위해, 지금 바로 우리와 함께 혁신적인 쇼핑 경험을 제공하세요.
# 베를린의 대규모 전자제품 매장을 위한 최적의 결제 솔루션! 고객 체험을 혁신하고 판매를 극대화하는 기회를 놓치지 마세요!
# 베를린 대형 전자제품 매장에 최적화된 새로운 결제 솔루션으로 고객의 쇼핑 경험을 혁신하세요! 간편함과 안전함을 동시에 제공하여 매출 상승을 이끌어낼 것입니다.
# 베를린의 대규모 전자제품 매장을 위한 혁신적인 이커머스 결제 서비스로 고객의 쇼핑 경험을 최적화하세요! 손쉬운 결제 시스템으로 매출을 증대시키고, 경쟁에서 앞서 나가세요.
# 산티아고의 소규모 전자제품 매장 여러분, 더 간편하게 결제하고 고객의 만족도를 높이세요! 우리의 혁신적인 이커머스 결제 서비스로 판매를 늘리고, 고객과의 신뢰를 쌓아보세요!
# 산티아고의 소규모 전자제품 매장을 위한 혁신적인 결제 서비스를 소개합니다! 고객의 편리함을 높여 매출을 증가시키세요—당신의 상점에 더 많은 판매 기회를 제공합니다!
# “산티아고의 소규모 전자제품 매장을 위해 설계된 혁신적인 이커머스 결제 서비스로, 고객의 쇼핑 경험을 간소화하세요! 지금 도입하시고 매출 증대의 기회를 놓치지 마세요!”
# 업계 최고 이커머스 결제 서비스로 고객의 쇼핑 경험을 향상시키세요! 산티아고의 중규모 전자제품 매장에 적합한 쉽게 통합 가능한 솔루션으로 비즈니스를 성장시켜 보세요.
# 산티아고의 중규모 전자제품 매장에 맞춤 설계된 최신 이커머스 결제 서비스로 고객의 쇼핑 경험을 혁신하세요! 간편한 결제 시스템을 도입해 매출을 증가시키고, 더 많은 고객을 유치하는 기회를 놓치지 마세요!
# 산티아고의 중규모 전자제품 매장을 위해 최적화된 혁신적인 결제 솔루션을 만나보세요! 간편한 결제 경험이 고객 만족도를 높이고, 매출 상승으로 이어집니다.
# 산티아고의 대규모 전자제품 매장을 위한 혁신적인 결제 서비스로, 고객의 쇼핑 경험을 한층 더 강화하세요! 빠르고 안전한 결제 솔루션이 매출 신장을 이끌어 드립니다.
# 산티아고의 대규모 전자제품 매장에 최적화된 최신 이커머스 결제 솔루션을 도입해 보세요! 빠르고 안전한 결제로 고객 만족도를 높이고, 판매를 극대화할 기회를 놓치지 마세요!
# 산티아고의 대규모 전자제품 매장에서 최신 이커머스 결제 서비스로 고객의 쇼핑 경험을 혁신해 보세요! 간편한 결제 솔루션이 매출을 증가시키고, 고객 만족도를 극대화합니다.
# 브뤼셀의 소규모 택시 서비스에 적합한 혁신적인 결제 솔루션으로 고객의 편리함을 더해보세요! 간편하고 빠른 결제로 고객 만족을 높이고, 매출을 증대시키세요!
# 브뤼셀에서 택시 서비스를 제공하신다면, 고객의 편의성을 높여줄 새로운 결제 서비스를 도입해 보세요! 쉽고 빠른 결제를 통해 승객을 더 많이 확보하고, 매출을 증가시킬 기회를 놓치지 마세요!
# 브뤼셀의 소규모 택시 서비스를 위해, 손쉽고 빠른 결제 경험을 제공하세요! 우리의 이커머스 결제 서비스로 고객 만족도를 높이고 매출을 극대화해 보세요.
# 브뤼셀의 중규모 택시 서비스에 최적화된 결제 솔루션으로 고객의 편의를 높여보세요! 간편한 결제 경험이 매출을 증대시키고, 택시 서비스를 더욱 매력적으로 만들어 드립니다.
# 브뤼셀 중규모 택시 서비스에 최적화된 이커머스 결제 서비스를 통해 고객의 편리한 결제를 지원하세요! 지금 도입하여 경쟁력을 강화하고, 고객 만족도를 높여보세요!
# 브뤼셀의 택시 서비스가 더 간편해집니다! 저희 이커머스 결제 서비스로 고객의 결제를 빠르고 안전하게 처리하여 매출을 극대화하세요!
# 브뤼셀의 대규모 택시 서비스에 최적화된 이커머스 결제 솔루션으로, 고객님들의 결제를 더욱 빠르고 편리하게 처리하세요! 지체 없이 신청하고, 경쟁력을 높여 수익을 극대화하세요!
# 브뤼셀 대규모 택시 서비스에 최적화된 우리의 이커머스 결제 솔루션으로 고객의 결제를 간편하게 처리하고, 매출을 증대시켜보세요! 지금 도입하시면 고객의 만족도를 높이고 운영 효율성을 극대화할 수 있습니다.
# 브뤼셀의 택시 서비스가 더 빠르고 안전하게 결제하세요! 우리의 혁신적인 이커머스 결제 서비스로 고객의 만족도를 높이고, 운영 효율성을 극대화하세요!
# 파리의 소규모 택시 서비스에 최적화된 이커머스 결제 시스템으로 손쉽고 빠른 결제를 경험하세요! 고객의 편의를 더하여 매출을 극대화할 기회를 놓치지 마세요!
# 파리의 소규모 택시 서비스에 딱 맞는 혁신적인 이커머스 결제 솔루션으로 고객을 더 쉽게 모으세요! 간편한 결제로 매출을 증대시키고, 경쟁력을 강화해보세요.
# 파리의 소규모 택시 서비스에 최적화된 새로운 결제 솔루션으로 고객의 편리한 탑승 경험을 선사하세요! 지금 도입하시면, 신속하고 간편한 결제로 매출도 상승시킬 수 있습니다!
# 파리의 중소 택시 서비스, 고객의 결제를 더욱 간편하게! 우리 이커머스 결제 서비스로 빠르고 안전한 거래를 경험하세요!
# 파리의 중규모 택시 서비스에 최적화된 이커머스 결제 솔루션으로 고객의 편리함을 한층 높여보세요! 손쉬운 결제 시스템으로 더 많은 승객을 유치하고, 운영의 효율성을 극대화하세요.
# 파리의 택시 서비스에 혁신을 더하세요! 우리의 새로운 이커머스 결제 서비스로 고객 경험을 향상시키고 수익을 극대화해 보세요.
# 파리의 택시 서비스에서 고객 경험을 혁신하세요! 우리 이커머스 결제 서비스를 통해 간편하고 빠른 결제를 제공하여 소중한 시간을 절약하고, 매출을 극대화해보세요!
# 파리의 대규모 택시 서비스에 최적화된 우리의 이커머스 결제 서비스로, 승객의 결제가 더 쉬워지고 당신의 수익은 향상됩니다! 빠르고 안전한 결제 솔루션으로 고객 만족도를 높이고, 경쟁에서 앞서 나가세요!
# 파리의 택시 서비스에 최적화된 새로운 이커머스 결제 솔루션으로 고객의 편리함을 선사하세요! 쉽고 빠른 결제로 수익을 극대화하고, 경쟁력을 더욱 강화해보세요!
# 부줌부라의 택시 서비스, 이제 간편하게 결제하세요! 우리의 새로운 이커머스 결제 서비스로 고객의 편의를 높이고 매출을 늘려보세요!
# 부줌부라에서 택시 서비스를 운영하신다면, 새로운 이커머스 결제 서비스로 고객 유치의 기회를 놓치지 마세요! 간편하고 안전한 결제 솔루션으로 손님들에게 더 나은 경험을 제공하고, 매출을 증대시키는 지금이 최고의 시점입니다.
# 부줌부라의 택시 서비스도 이제 결제의 혁신을 경험하세요! 저희의 새로운 이커머스 결제 서비스로 고객의 편리함을 높이고, 매출을 극대화하세요!
# 부줌부라에서 택시 서비스를 혁신하세요! 우리의 새로운 이커머스 결제 서비스로 고객의 결제를 더 빠르고 간편하게 처리하여 매출을 끌어올려 보세요!
# 부줌부라의 택시 서비스에 혁신을 더하세요! 우리 이커머스 결제 서비스로 고객의 결제를 간편하게 만들어 매출을 극대화해보세요!
# 부줌부라의 택시 서비스에 최적화된 우리의 새로운 이커머스 결제 서비스로 고객의 편리를 한층 더 높여보세요! 신속하고 안전한 결제로 승차 경험을 혁신하고, 매출 증가의 기회를 놓치지 마세요!
# “부줌부라의 택시 서비스, 이제 결제의 번거로움 없이 고객님의 편리함을 높이세요! 우리의 이커머스 결제 서비스로 더 빠르고 안전한 결제를 경험하며, 대규모 운영의 효율성을 극대화하세요!”
# 부줌부라의 대규모 택시 서비스에 특화된 이커머스 결제 솔루션으로, 결제 속도를 높여 고객 만족도를 극대화하세요! 지금 도입하면 더 많은 승객을 유치하고 매출을 증대시킬 수 있는 기회를 선사합니다.
# 부줌부라의 대규모 택시 서비스가 더욱 쉬워집니다! 우리의 혁신적인 이커머스 결제 서비스를 통해 고객들에게 빠르고 안전한 결제를 제공하고, 운영 효율성을 극대화하세요.
# 베를린의 소규모 택시 서비스에 최적화된 새로운 결제 솔루션으로 고객 만족도를 높이세요! 쉽고 빠른 결제 경험이 당신의 비즈니스를 한 단계 업그레이드합니다.
# 베를린의 소규모 택시 서비스를 위한 혁신적인 결제 솔루션을 만나보세요! 고객들이 더 빠르고 간편하게 결제할 수 있어, 귀사의 서비스에 대한 만족도를 더욱 높여드립니다.
# 베를린의 소규모 택시 서비스에 최적화된 새로운 결제 시스템으로 고객의 편리함을 더하세요! 간편하고 빠른 결제로 귀하의 승차 경험을 혁신하고, 매출을 높이는 기회를 놓치지 마세요!
# 베를린 중소 택시 서비스의 새로운 차원을 경험하세요! 저희 이커머스 결제 서비스로 손쉬운 결제 환경을 제공하여 고객의 만족도를 높이고, 매출을 극대화하세요!
# 베를린의 중규모 택시 서비스에 딱 맞는 혁신적인 결제 솔루션으로 고객의 편리함을 더하세요! 빠르고 안전한 결제로 승객의 만족도를 높이고, 매출을 극대화하는 기회를 놓치지 마세요!
# 베를린의 택시 서비스에 혁신을 더하세요! 우리의 새로운 이커머스 결제 서비스로 승객이 더 빠르고 쉽게 결제할 수 있도록 도와드리겠습니다.
# 베를린의 택시 서비스에 최적화된 이커머스 결제 솔루션으로 고객의 편리함을 극대화하세요! 더욱 빠르고 안전한 결제로 승객 만족도를 높이고, 매출 성장의 기회를 놓치지 마세요!
# 베를린의 대규모 택시 서비스에 필수! 고객이 더 쉽게 결제하고, 당신의 비즈니스도 더 빠르게 성장하는 새로운 이커머스 결제 서비스를 도입해 보세요.
# 베를린의 대규모 택시 서비스에 최적화된 우리의 이커머스 결제 시스템으로 고객의 결제를 더 간편하고 빠르게 처리하세요! 지금 도입하면 매출 증대와 고객 만족도를 동시에 경험하실 수 있습니다.
# 산티아고의 소규모 택시 서비스에 최적화된 이커머스 결제 솔루션으로 고객의 빠르고 안전한 결제를 경험해보세요! 더 많은 승객을 유치하고, 매출을 증대시킬 기회를 놓치지 마세요!
# 산티아고의 소규모 택시 서비스에 최적화된 새로운 결제 솔루션으로 고객의 편리함을 더하세요! 간편한 결제 시스템으로 매출을 극대화하고, 고객의 재방문율을 높이는 기회를 놓치지 마세요!
# 산티아고의 소규모 택시 서비스에 최적화된 새로운 이커머스 결제 솔루션으로 고객의 예약과 결제를 간편하게 처리하세요! 더 많은 고객을 유치하고, 매출을 증가시키는 기회를 놓치지 마세요!
# 산티아고의 중규모 택시 서비스에 최적화된 결제 솔루션으로 고객의 편리한 결제 경험을 선사하세요! 쉽고 빠른 결제로 승차감이 한층 향상되며, 매출도 덩달아 증가합니다.
# “산티아고의 택시 서비스에 최적화된 새로운 결제 솔루션으로 운전과 고객 만족을 동시에 향상시켜 보세요! 간편하고 안전한 결제를 통해 더 많은 승객을 유치하고 수익을 증가시킬 기회를 놓치지 마세요.”
# 고객의 편리함을 더하세요! 우리 이커머스 결제 서비스로 산티아고의 택시 서비스를 혁신하여 거래를 간편하게 만들고 매출을 증가시켜보세요!
# 산티아고의 대규모 택시 서비스에 최적화된 이커머스 결제 시스템으로 고객의 편리함을 보장하세요! 수수료를 절감하고, 예약과 결제를 더 빠르고 효율적으로 관리하여 택시 운영의 새로운 시대를 여십시오.
# 빠르고 간편한 결제 시스템으로 고객의 택시 이용 경험을 혁신하세요! 당신의 대규모 서비스에 맞는 맞춤형 이커머스 결제 솔루션으로 산티아고에서의 경쟁력을 높이세요.
# 산티아고의 대규모 택시 서비스에 최적화된 이커머스 결제 솔루션으로 고객의 편리함을 한층 더 높여보세요! 빠르고 안전한 결제로 승객 만족도를 극대화하고, 매출 증대를 경험하세요!

# %%
with open('training.jsonl', 'w', encoding='utf-8') as file:
    for entry in res:
        json_str = json.dumps(entry, ensure_ascii=False)
        file.write(json_str + '\n')

l_sector = ['꽃집', '장난감 가게', '피자 레스토랑']
l_city = ['로마', '뉴욕', '리우데자네이루'] 
l_size = ['소규모', '중규모', '대규모']

nb_rep = 1

res = []
for sector in l_sector:
    for city in l_city:
        for size in l_size:
            for i in range(nb_rep):  # 'nb_rep' times each example
                prompt = f_prompt.format(
                sector=sector, city=city, size=size)
                sub_prompt = f_sub_prompt.format(
                sector=sector, city=city, size=size)
                response_txt = chat_completion(
                    prompt, model='gpt-4o-mini', temperature=1
                )
                response_txt = response_txt.replace('"', '')
                print(response_txt)
                
                new_row = {
                    'prompt': sub_prompt,
                    'completion': response_txt
                }

                new_row = {
                    'messages':[
                        {
                            'role': 'user', 
                            'content': sub_prompt
                        },
                        {
                            'role': 'assistant', 
                            'content': response_txt
                        }
                    ]
                }
                
                res.append(new_row)
# Out:
# 로마의 아늑한 꽃집에 완벽한 결제 솔루션을 제공하세요! 우리의 이커머스 결제 서비스로 고객의 꽃 구매를 쉽게 하고, 매출을 극대화해 보세요.
# 로마의 아름다운 꽃을 더 많은 고객에게 손쉽게 전달하세요! 새로운 이커머스 결제 서비스로 꽃집의 매출을 극대화하고, 고객의 편리함을 더해 보세요!
# 로마의 대규모 꽃집을 위해 특별히 설계된 이커머스 결제 서비스로, 고객이 꽃을 구매하는 순간부터 배송까지의 모든 과정을 간편하게 관리하세요. 더 많은 고객을 유치하고 매출을 증대시키는 기회를 놓치지 마세요!
# 뉴욕의 꽃집을 위해 특별히 설계된 우리의 간편 결제 서비스로, 고객의 소중한 순간을 더욱 풍성하게 만들어보세요. 손쉬운 결제와 빠른 거래로 꽃다발 하나하나에 마음을 담아 전하세요!
# 뉴욕의 꽃집을 더 빛나게 할 이커머스 결제 서비스로 고객의 구매 경험을 한 차원 높여보세요! 쉽게 설치하고 즉시 결제를 받아볼 수 있는 혁신적인 솔루션으로 꽃의 아름다움을 직접 전달하세요!
# 뉴욕의 대규모 꽃집을 위해 설계된 최신 이커머스 결제 서비스로, 고객의 설렘을 더해보세요. 쉽고 빠른 결제로 매출을 극대화하고, 꽃다발 하나하나에 특별한 가치를 담아내세요!
# 당신의 꽃집에 더 많은 고객을 불러들일 준비가 되었나요? 우리의 이커머스 결제 서비스로 간편하고 안전한 결제를 제공해보세요, 리우데자네이루의 꽃향기를 더욱 널리 퍼뜨릴 수 있습니다!
# 리우데자네이루의 꽃집을 위해 특별히 설계된 이커머스 결제 서비스로, 고객의 소중한 순간을 더욱 쉽게 만드세요! 간편한 결제 시스템으로 꽃을 구매하는 즐거움을 더하고, 매출 상승의 기회를 잡아보세요.
# 리우데자네이루의 대규모 꽃집에 최적화된 새로운 이커머스 결제 서비스를 통해 고객의 쇼핑 경험을 혁신하세요! 매출 증가와 고객 만족을 동시에 이루는 기회를 놓치지 마세요!
# 로마의 소규모 장난감 가게를 위한 완벽한 결제 솔루션! 이제 고객의 즐거운 쇼핑 경험을 한층 더 향상시키세요—간편한 결제로 매출을 극대화하고, 장난감의 마법을 더 많은 아이들에게 전달하세요!
# 로마의 중규모 장난감 가게에 최적화된 결제 솔루션으로 고객의 쇼핑 경험을 혁신하세요! 빠르고 안전한 결제 시스템으로 매출을 높이고, 아이들의 웃음을 더하는 장난감 세상을 만드는 데 집중하십시오!
# 로마의 대규모 장난감 가게를 위한 혁신적인 결제 서비스로 고객 경험을 한층 더 향상시켜보세요! 손쉬운 결제 과정으로 매출을 증대시키고, 아이들에겐 더 많은 즐거움을 선사하세요!
# 뉴욕의 소규모 장난감 가게를 위한 혁신적인 결제 솔루션으로 고객의 쇼핑 경험을 한층 즐겁게 만들어보세요! 더 빠르고 안전한 결제로 장난감 판매의 재미를 더할 기회를 놓치지 마세요!
# 뉴욕의 중소 장난감 가게를 위한 최적의 결제 솔루션! 우리 이커머스 결제 서비스를 통해 고객에게 더 빠르고 간편한 쇼핑 경험을 제공하세요.
# 뉴욕의 대규모 장난감 가게를 위한 혁신적인 결제 솔루션으로 고객의 쇼핑 경험을 한층 더 즐겁게 만들어 보세요! 간편하고 안전한 결제만으로도 매출 증가를 실현하고, 고객들의 재방문을 유도할 수 있습니다.
# 리우데자네이루의 소규모 장난감 가게를 위한 특별한 기회! 간편한 결제 시스템으로 고객의 쇼핑을 더 즐겁게 만들어 보세요 – 더 많은 판매와 행복한 순간을 선사합니다!
# 리우데자네이루의 중규모 장난감 가게를 위한 특별한 결제 솔루션! 더 많은 고객을 끌어들이고, 간편한 결제로 매출을 높이는 기회를 놓치지 마세요!
# 리우데자네이루의 대규모 장난감 가게를 위해, 고객의 결제를 더욱 간편하게 만들어주는 혁신적인 이커머스 결제 서비스를 도입하세요! 더 많은 판매와 고객 만족을 위한 첫걸음을 지금 바로 시작해보세요!
# 로마의 소규모 피자 레스토랑을 위한 완벽한 결제 솔루션! 고객의 편의를 극대화하여 주문을 쉽게 만들어 보세요.
# 로마의 피자 레스토랑을 위한 새로운 결제 서비스로 손쉽고 빠르게 고객을 유치하세요! 간편한 주문 결제 시스템으로 매출을 증가시키고 고객 만족도를 높이는 기회를 잡으세요!
# 로마의 대규모 피자 레스토랑을 위한 최첨단 결제 서비스로 매출을 극대화하세요! 고객의 편리함을 더해주고, 주문을 잊지 않도록 언제 어디서나 쉽고 빠른 결제를 경험하세요!
# 뉴욕의 작은 피자 가게를 위한 최적의 결제 솔루션! 손쉬운 결제로 고객 만족도를 높이고 판매를 증대시켜 보세요.
# 뉴욕의 중규모 피자 레스토랑을 위해 설계된 혁신적인 이커머스 결제 서비스로 고객의 주문을 간편하게 관리하고 수익을 극대화하세요. 더 많은 고객이 당신의 맛있는 피자를 선택하도록 유도하고, 판매 속도를 높이세요!
# “뉴욕의 대규모 피자 레스토랑에 최적화된 혁신적인 결제 솔루션으로 고객의 주문 경험을 향상시켜보세요! 간편하고 빠른 결제를 통해 매출을 극대화하며, 고객 충성도를 높이는 기회를 놓치지 마세요.”
# 리우의 소규모 피자 레스토랑에 특별한 결제 솔루션을 도입해 보세요! 손쉬운 결제로 고객의 편의를 높이고, 매출을 늘리는 기회를 놓치지 마세요!
# 리우의 피자를 더 맛있게, 결제는 더 간편하게! 새로운 이커머스 결제 서비스로 고객의 주문 경험을 혁신하세요!
# 리우의 피자 레스토랑을 위한 혁신적인 결제 서비스로 고객의 만족도를 극대화하세요! 대규모 상점에 최적화된 솔루션으로, 더 빠르고 편리한 결제를 경험해 보세요!

# %%
with open('validation.jsonl', 'w', encoding='utf-8') as file:
    for entry in res:
        json_str = json.dumps(entry, ensure_ascii=False)
        file.write(json_str + '\n')

# %%
client = OpenAI(
    # 시스템에 설정된 API 키를 사용합니다
    api_key=os.environ.get('OPENAI_API_KEY')
)

tr_file = client.files.create(
    file=open('training.jsonl', 'rb'),
    purpose='fine-tune'
)

vl_file = client.files.create(
    file=open('validation.jsonl', 'rb'),
    purpose='fine-tune'
)

fine_tuning_job = client.fine_tuning.jobs.create(
    training_file=tr_file.id,
    validation_file=vl_file.id,
    model='gpt-3.5-turbo-0125', 
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[37], line 16
#       6 tr_file = client.files.create(
#       7     file=open('training.jsonl', 'rb'),
#       8     purpose='fine-tune'
#       9 )
#      11 vl_file = client.files.create(
#      12     file=open('validation.jsonl', 'rb'),
#      13     purpose='fine-tune'
#      14 )
# ---> 16 fine_tuning_job = client.fine_tuning.jobs.create(
#      17     training_file=tr_file.id,
#      18     validation_file=vl_file.id,
#      19     model='gpt-3.5-turbo-0125',
#      20 )
#
# File c:\Users\campus3S043\Desktop\alpaco_lectures\venv\Lib\site-packages\openai\resources\fine_tuning\jobs\jobs.py:150, in Jobs.create(self, model, training_file, hyperparameters, integrations, method, seed, suffix, validation_file, extra_headers, extra_query, extra_body, timeout)
#      63 def create(
#      64     self,
#      65     *,
#    (...)
#      79     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#      80 ) -> FineTuningJob:
#      81     """
#      82     Creates a fine-tuning job which begins the process of creating a new model from
#      83     a given dataset.
#    (...)
#     148       timeout: Override the client-level default timeout for this request, in seconds
#     149     """
# --> 150     return self._post(
#     151         "/fine_tuning/jobs",
#     152         body=maybe_transform(
#     153             {
#     154                 "model": model,
#     155                 "training_file": training_file,
#     156                 "hyperparameters": hyperparameters,
#     157                 "integrations": integrations,
#     158                 "method": method,
#     159                 "seed": seed,
#     160                 "suffix": suffix,
#     161                 "validation_file": validation_file,
#     162             },
#     163             job_create_params.JobCreateParams,
#     164         ),
#     165         options=make_request_options(
#     166             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     167         ),
#     168         cast_to=FineTuningJob,
#     169     )
#
# File c:\Users\campus3S043\Desktop\alpaco_lectures\venv\Lib\site-packages\openai\_base_client.py:1283, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1269 def post(
#    1270     self,
#    1271     path: str,
#    (...)
#    1278     stream_cls: type[_StreamT] | None = None,
#    1279 ) -> ResponseT | _StreamT:
#    1280     opts = FinalRequestOptions.construct(
#    1281         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1282     )
# -> 1283     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\campus3S043\Desktop\alpaco_lectures\venv\Lib\site-packages\openai\_base_client.py:960, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     957 else:
#     958     retries_taken = 0
# --> 960 return self._request(
#     961     cast_to=cast_to,
#     962     options=options,
#     963     stream=stream,
#     964     stream_cls=stream_cls,
#     965     retries_taken=retries_taken,
#     966 )
#
# File c:\Users\campus3S043\Desktop\alpaco_lectures\venv\Lib\site-packages\openai\_base_client.py:1049, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1047 if remaining_retries > 0 and self._should_retry(err.response):
#    1048     err.response.close()
# -> 1049     return self._retry_request(
#    1050         input_options,
#    1051         cast_to,
#    1052         retries_taken=retries_taken,
#    1053         response_headers=err.response.headers,
#    1054         stream=stream,
#    1055         stream_cls=stream_cls,
#    1056     )
#    1058 # If the response is streamed then we need to explicitly read the response
#    1059 # to completion before attempting to access the response text.
#    1060 if not err.response.is_closed:
#
# File c:\Users\campus3S043\Desktop\alpaco_lectures\venv\Lib\site-packages\openai\_base_client.py:1098, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1094 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1095 # different thread if necessary.
#    1096 time.sleep(timeout)
# -> 1098 return self._request(
#    1099     options=options,
#    1100     cast_to=cast_to,
#    1101     retries_taken=retries_taken + 1,
#    1102     stream=stream,
#    1103     stream_cls=stream_cls,
#    1104 )
#
# File c:\Users\campus3S043\Desktop\alpaco_lectures\venv\Lib\site-packages\openai\_base_client.py:1049, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1047 if remaining_retries > 0 and self._should_retry(err.response):
#    1048     err.response.close()
# -> 1049     return self._retry_request(
#    1050         input_options,
#    1051         cast_to,
#    1052         retries_taken=retries_taken,
#    1053         response_headers=err.response.headers,
#    1054         stream=stream,
#    1055         stream_cls=stream_cls,
#    1056     )
#    1058 # If the response is streamed then we need to explicitly read the response
#    1059 # to completion before attempting to access the response text.
#    1060 if not err.response.is_closed:
#
# File c:\Users\campus3S043\Desktop\alpaco_lectures\venv\Lib\site-packages\openai\_base_client.py:1098, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1094 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1095 # different thread if necessary.
#    1096 time.sleep(timeout)
# -> 1098 return self._request(
#    1099     options=options,
#    1100     cast_to=cast_to,
#    1101     retries_taken=retries_taken + 1,
#    1102     stream=stream,
#    1103     stream_cls=stream_cls,
#    1104 )
#
# File c:\Users\campus3S043\Desktop\alpaco_lectures\venv\Lib\site-packages\openai\_base_client.py:1064, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1061         err.response.read()
#    1063     log.debug("Re-raising status error")
# -> 1064     raise self._make_status_error_from_response(err.response) from None
#    1066 return self._process_response(
#    1067     cast_to=cast_to,
#    1068     options=options,
#    (...)
#    1072     retries_taken=retries_taken,
#    1073 )
#
# RateLimitError: Error code: 429 - {'error': {'message': "This fine-tune request has been rate-limited. Your organization has reached the maximum of 3 active requests (2 running, 1 pending) for the model 'gpt-3.5-turbo-0125'.", 'type': 'invalid_request_error', 'param': None, 'code': 'rate_limit_exceeded'}}

# %%
client.fine_tuning.jobs.list_events(fine_tuning_job_id=fine_tuning_job.id)
# Out:
# SyncCursorPage[FineTuningJobEvent](data=[FineTuningJobEvent(id='ftevent-CM0k10FCi4LsEHUVjObg6yWG', created_at=1738895670, level='info', message='Validating training file: file-Y2otwjcJMWkc44pc7uAtDm and validation file: file-83ZbVtG6DFhB5ZVTYX38K3', object='fine_tuning.job.event', data={}, type='message'), FineTuningJobEvent(id='ftevent-gpLAKprdqLJQQImPfs3Pn1G0', created_at=1738895670, level='info', message='Created fine-tuning job: ftjob-edRyXKJlvdgsi0XrwtcnlxmR', object='fine_tuning.job.event', data={}, type='message')], object='list', has_more=False)

# %%
client.fine_tuning.jobs.list_events(fine_tuning_job_id=fine_tuning_job.id)
job = client.fine_tuning.jobs.retrieve(fine_tuning_job.id)

# Add error handling for result files
if not job.result_files:
    print("No result files available yet")
else:
    result_file = job.result_files[0]
    content = client.files.content(result_file)
    content_str = b64decode(content.read().decode('utf-8')).decode()
    df = pd.read_csv(io.StringIO(content_str))

    # For the NaN is 'valid_loss'
    df['valid_loss_interpolated'] = df['valid_loss'].interpolate()
    plt.figure(figsize=(10, 6))
    plt.plot(df['step'], df['train_loss'], label='Train Loss', marker='o')
    plt.plot(df['step'], df['valid_loss_interpolated'],
    label='Valid Loss', marker='o', markersize=2)
    plt.xlabel('Step')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss per Step')
    plt.legend()
# Out:
# No result files available yet

# %%
completion = client.chat.completions.create(
    model='ft:gpt-4o-mini-2024-07-18:************',
    messages=[
        {'role': 'user', 'content': '동물병원, 라바트, 소규모'}
    ]
)

print(completion)
print(completion.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 completion = client.chat.completions.create(
#       2     model='ft:gpt-4o-mini-2024-07-18:************',
#       3     messages=[
#       4         {'role': 'user', 'content': '동물병원, 라바트, 소규모'}
#       5     ]
#       6 )
#       8 print(completion)
#       9 print(completion.choices[0].message.content)
#
# File c:\Users\campus3S043\Desktop\alpaco_lectures\venv\Lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File c:\Users\campus3S043\Desktop\alpaco_lectures\venv\Lib\site-packages\openai\resources\chat\completions.py:863, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     821 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     822 def create(
#     823     self,
#    (...)
#     860     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     861 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     862     validate_response_format(response_format)
# --> 863     return self._post(
#     864         "/chat/completions",
#     865         body=maybe_transform(
#     866             {
#     867                 "messages": messages,
#     868                 "model": model,
#     869                 "audio": audio,
#     870                 "frequency_penalty": frequency_penalty,
#     871                 "function_call": function_call,
#     872                 "functions": functions,
#     873                 "logit_bias": logit_bias,
#     874                 "logprobs": logprobs,
#     875                 "max_completion_tokens": max_completion_tokens,
#     876                 "max_tokens": max_tokens,
#     877                 "metadata": metadata,
#     878                 "modalities": modalities,
#     879                 "n": n,
#     880                 "parallel_tool_calls": parallel_tool_calls,
#     881                 "prediction": prediction,
#     882                 "presence_penalty": presence_penalty,
#     883                 "reasoning_effort": reasoning_effort,
#     884                 "response_format": response_format,
#     885                 "seed": seed,
#     886                 "service_tier": service_tier,
#     887                 "stop": stop,
#     888                 "store": store,
#     889                 "stream": stream,
#     890                 "stream_options": stream_options,
#     891                 "temperature": temperature,
#     892                 "tool_choice": tool_choice,
#     893                 "tools": tools,
#     894                 "top_logprobs": top_logprobs,
#     895                 "top_p": top_p,
#     896                 "user": user,
#     897             },
#     898             completion_create_params.CompletionCreateParams,
#     899         ),
#     900         options=make_request_options(
#     901             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     902         ),
#     903         cast_to=ChatCompletion,
#     904         stream=stream or False,
#     905         stream_cls=Stream[ChatCompletionChunk],
#     906     )
#
# File c:\Users\campus3S043\Desktop\alpaco_lectures\venv\Lib\site-packages\openai\_base_client.py:1283, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1269 def post(
#    1270     self,
#    1271     path: str,
#    (...)
#    1278     stream_cls: type[_StreamT] | None = None,
#    1279 ) -> ResponseT | _StreamT:
#    1280     opts = FinalRequestOptions.construct(
#    1281         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1282     )
# -> 1283     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\campus3S043\Desktop\alpaco_lectures\venv\Lib\site-packages\openai\_base_client.py:960, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     957 else:
#     958     retries_taken = 0
# --> 960 return self._request(
#     961     cast_to=cast_to,
#     962     options=options,
#     963     stream=stream,
#     964     stream_cls=stream_cls,
#     965     retries_taken=retries_taken,
#     966 )
#
# File c:\Users\campus3S043\Desktop\alpaco_lectures\venv\Lib\site-packages\openai\_base_client.py:1064, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1061         err.response.read()
#    1063     log.debug("Re-raising status error")
# -> 1064     raise self._make_status_error_from_response(err.response) from None
#    1066 return self._process_response(
#    1067     cast_to=cast_to,
#    1068     options=options,
#    (...)
#    1072     retries_taken=retries_taken,
#    1073 )
#
# BadRequestError: Error code: 400 - {'error': {'message': 'invalid model ID', 'type': 'invalid_request_error', 'param': None, 'code': None}}
