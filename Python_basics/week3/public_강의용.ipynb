# %%
# !pip install xmltodict
# Out:
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.10/dist-packages (0.14.1)

# %%
import requests
import json
import xmltodict
import pandas as pd
serviceKey = 'SDEjyCFJI1ki5hZaMAvBGUsre6U38rZKkVug%2BDGju9aAUp9G7%2B1tQagaeWcG2trJmx1%2BXe0JANCSgpGnLFuOPA%3D%3D'
pageNo = 1 # 페이지 번호
numOfRows = 500 # 한 페이지 결과수
LAWD_CD = 11500 # 지역코드
DEAL_YMD = 202101 # 계약월
url = f'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?serviceKey={serviceKey}&pageNo={pageNo}&numOfRows={numOfRows}&LAWD_CD={LAWD_CD}&DEAL_YMD={DEAL_YMD}'
req = requests.get(url)
req
# Out:
# <Response [200]>

# %%
req.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>    70,000</거래금액><거래유형> </거래유형><건축년도>1996</건축년도><년>2021</년><도로명>양천로75길</도로명><도로명건물본번호코드>00060</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11500</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4145429</도로명코드><동> </동><등기일자> </등기일자><매도자> </매도자><매수자> </매수자><법정동> 염창동</법정동><법정동본번코드>0291</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11500</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>현대3</아파트><월>1</월><일>3</일><일련번호>11500-30</일련번호><전용면적>59.92</전용면적><중개사소재지> </중개사소재지><지번>291</지번><지역코드>11500</지역코드><층>12</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    85,500</거래금액><거래유형> </거래유형><건축년도>1992</건축년도><년>2021</년><도로명>양천로67길</도로명><도로명건물본번호코드>00054</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11500</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4145422</도로명코드><동> </동><등기일자> </등기일자><매도자> </매도자><매수자> </매수자><법정동> 염창동</법정동><법정동본번코드>0287</법정동본번코드><법정동부번코드>0001</법정동부번코드><법정동시군구코드>11500</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>우성2</아파트><월>1</월><일>5</일><일련번호>11500-23</일련번호><전용면적>84.7</전용면적><중개사소재지> </중개사소재지><지번>287-1</지번><지역코드>11500</지역코드><층>12</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    98,000</거래금액><거래유형> </거래유형><건축년도>2005</건축년도><년>2021</년><도로명>공항대로</도로명><도로명건물본번호코드>00637</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11500</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>2005007</도로명코드><동> </동><등기일자> </등기일자><매도자> </매도자><매수자> </매수자><법정동> 염창동</법정동><법정동본번코드>0282</법정동본번코드><법정동부번코드>0019</법정동부번코드><법정동시군구코드>11500</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>현대아이파크</아파트><월>1</월><일>5</일><일련번호>11500-5104</일련번호><전용면적>84.84</전용면적><중개사소재지> </중개사소재지><지번>282-19</지번><지역코드>11500</지역코드><층>4</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    80,300</거래금액><거래유형> </거래유형><건축년도>1994</건축년도><년>2021</년><도로명>양천로75길</도로명><도로명건물본번호코드>00057</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11500</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4145429</도로명코드><동> </동><등기일자> </등기일자><매도자> </매도자><매수자> </매수자><법정동> 염창동</법정동><법정동본번코드>0288</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11500</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>현대1</아파트><월>1</월><일>5</일><일련번호>11500-28</일련번호><전용면적>84.34</전용면적><중개사소재지> </중개사소재지><지번>288</지번><지역코드>11500</지역코드><층>2</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    74,800</거래금액><거래유형> </거래유형><건축년도>1995</건축년도><년>2021</년><도로명>양천로</도로명><도로명건물본번호코드>00637</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11500</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>3115008</도로명코드><동> </동><등기일자> </등기일자><매도자> </매도자><매수자> </매수자><법정동> 염창동</법정동><법정동본번코드>0244</법정동본번코드><법정동부번코드>0002</법정동부번코드><법정동시군구코드>11500</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>삼성한마음</아파트><월>1</월><일>6</일><일련번호>11500-16</일련번호><전용면적>59.94</전용면적><중개사소재지> </중개사소재지><지번>244-2</지번><지역코드>11500</지역코드><층>7</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    64,000</거래금액><거래유형> </거래유형><건축년도>1992</건축년도><년>2021</년><도로명>양천로67길</도로명><도로명건물본번호코드>00054</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11500</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4145422</도로명코드><동> </동><등기일자> </등기일자><매도자> </매도자><매수자> </매수자><법정동> 염창동</법정동><법정동본번코드>0287</법정동본번코드><법정동부번코드>0001</법정동부번코드><법정동시군구코드>11500</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>우성2</아파트><월>1</월><일>6</일><일련번호>11500-23</일련번호><전용면적>65.88</전용면적><중개사소재지> </중개사소재지><지번>287-1</지번><지역코드>11500</지역코드><층>7</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>   124,500</거래금액><거래유형> </거래유형><건축년도>2001</건축년도><년>2021</년><도로명>양천로69길</도로명><도로명건물본번호코드>00065</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11500</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4145423</도로명코드><동> </동><등기일자> </등기일자><매도자> </매도자><매수자> </ ...

# %%
contents = xmltodict.parse(req.text) # XML을 dictionary로 변환
contents
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'items': {'item': [{'거래금액': '    70,000',
#       '거래유형': ' ',
#       '건축년도': '1996',
#       '년': '2021',
#       '도로명': '양천로75길',
#       '도로명건물본번호코드': '00060',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145429',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0291',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '현대3',
#       '월': '1',
#       '일': '3',
#       '일련번호': '11500-30',
#       '전용면적': '59.92',
#       '중개사소재지': ' ',
#       '지번': '291',
#       '지역코드': '11500',
#       '층': '12',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    85,500',
#       '거래유형': ' ',
#       '건축년도': '1992',
#       '년': '2021',
#       '도로명': '양천로67길',
#       '도로명건물본번호코드': '00054',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145422',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0287',
#       '법정동부번코드': '0001',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '우성2',
#       '월': '1',
#       '일': '5',
#       '일련번호': '11500-23',
#       '전용면적': '84.7',
#       '중개사소재지': ' ',
#       '지번': '287-1',
#       '지역코드': '11500',
#       '층': '12',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    98,000',
#       '거래유형': ' ',
#       '건축년도': '2005',
#       '년': '2021',
#       '도로명': '공항대로',
#       '도로명건물본번호코드': '00637',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '2005007',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0282',
#       '법정동부번코드': '0019',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '현대아이파크',
#       '월': '1',
#       '일': '5',
#       '일련번호': '11500-5104',
#       '전용면적': '84.84',
#       '중개사소재지': ' ',
#       '지번': '282-19',
#       '지역코드': '11500',
#       '층': '4',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    80,300',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '양천로75길',
#       '도로명건물본번호코드': '00057',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145429',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0288',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '현대1',
#       '월': '1',
#       '일': '5',
#       '일련번호': '11500-28',
#       '전용면적': '84.34',
#       '중개사소재지': ' ',
#       '지번': '288',
#       '지역코드': '11500',
#       '층': '2',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    74,800',
#       '거래유형': ' ',
#       '건축년도': '1995',
#       '년': '2021',
#       '도로명': '양천로',
#       '도로명건물본번호코드': '00637',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3115008',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0244',
#       '법정동부번코드': '0002',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '삼성한마음',
#       '월': '1',
#       '일': '6',
#       '일련번호': '11500-16',
#       '전용면적': '59.94',
#       '중개사소재지': ' ',
#       '지번': '244-2',
#       '지역코드': '11500',
#       '층': '7',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    64,000',
#       '거래유형': ' ',
#       '건축년도': '1992',
#       '년': '2021',
#       '도로명': '양천로67길',
#       '도로명건물본번호코드': '00054',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145422',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0287',
#       '법정동부번코드': '0001',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '우성2',
#       '월': '1',
#       '일': '6',
#       '일련번호': '11500-23',
#       '전용면적': '65.88',
#       '중개사소재지': ' ',
#       '지번': '287-1',
#       '지역코드': '11500',
#       '층': '7',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '   124,500',
#       '거래유형': ' ',
#       '건축년도': '2001',
#       '년': '2021',
#       '도로명': '양천로69길',
#       '도로명건물본번호코드': '00065',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145423',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0295',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '성원',
#       '월': '1',
#       '일': '8',
#       '일련번호': '11500-20',
#       '전용면적': '114.12',
#       '중개사소재지': ' ',
#       '지번': '295',
#       '지역코드': '11500',
#       '층': '16',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    79,000',
#       '거래유형': ' ',
#       '건축년도': '1999',
#       '년': '2021',
#       '도로명': '공항대로71길',
#       '도로명건물본번호코드': '00031',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145216',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0280',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '극동상록수',
#       '월': '1',
#       '일': '9',
#       '일련번호': '11500-2',
#       '전용면적': '59.91',
#       '중개사소재지': ' ',
#       '지번': '280',
#       '지역코드': '11500',
#       '층': '16',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    91,900',
#       '거래유형': ' ',
#       '건축년도': '2004',
#       '년': '2021',
#       '도로명': '양천로71가길',
#       '도로명건물본번호코드': '00022',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145425',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0298',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '일신건영휴먼빌',
#       '월': '1',
#       '일': '9',
#       '일련번호': '11500-299',
#       '전용면적': '84.93',
#       '중개사소재지': ' ',
#       '지번': '298',
#       '지역코드': '11500',
#       '층': '4',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    89,800',
#       '거래유형': ' ',
#       '건축년도': '1995',
#       '년': '2021',
#       '도로명': '양천로',
#       '도로명건물본번호코드': '00637',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3115008',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0244',
#       '법정동부번코드': '0002',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '삼성한마음',
#       '월': '1',
#       '일': '9',
#       '일련번호': '11500-16',
#       '전용면적': '84.87',
#       '중개사소재지': ' ',
#       '지번': '244-2',
#       '지역코드': '11500',
#       '층': '11',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    60,000',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '양천로73길',
#       '도로명건물본번호코드': '00005',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145428',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0248',
#       '법정동부번코드': '0003',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '삼성하나로',
#       '월': '1',
#       '일': '9',
#       '일련번호': '11500-15',
#       '전용면적': '59.26',
#       '중개사소재지': ' ',
#       '지번': '248-3',
#       '지역코드': '11500',
#       '층': '1',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    79,500',
#       '거래유형': ' ',
#       '건축년도': '1999',
#       '년': '2021',
#       '도로명': '양천로',
#       '도로명건물본번호코드': '00731',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3115008',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0258',
#       '법정동부번코드': '0001',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '동아3',
#       '월': '1',
#       '일': '9',
#       '일련번호': '11500-7',
#       '전용면적': '59.7',
#       '중개사소재지': ' ',
#       '지번': '258-1',
#       '지역코드': '11500',
#       '층': '16',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    68,000',
#       '거래유형': ' ',
#       '건축년도': '1990',
#       '년': '2021',
#       '도로명': '양천로67길',
#       '도로명건물본번호코드': '00077',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145422',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0066',
#       '법정동부번코드': '0009',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '염창동한강우성',
#       '월': '1',
#       '일': '11',
#       '일련번호': '11500-495',
#       '전용면적': '65.88',
#       '중개사소재지': ' ',
#       '지번': '66-9',
#       '지역코드': '11500',
#       '층': '14',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    69,000',
#       '거래유형': ' ',
#       '건축년도': '1998',
#       '년': '2021',
#       '도로명': '양천로69길',
#       '도로명건물본번호코드': '00058',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145423',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0292',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '동아',
#       '월': '1',
#       '일': '12',
#       '일련번호': '11500-6',
#       '전용면적': '59.97',
#       '중개사소재지': ' ',
#       '지번': '292',
#       '지역코드': '11500',
#       '층': '2',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '   124,500',
#       '거래유형': ' ',
#       '건축년도': '2010',
#       '년': '2021',
#       '도로명': '양천로63길',
#       '도로명건물본번호코드': '00051',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145418',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0240',
#       '법정동부번코드': '0001',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '강변월드메르디앙',
#       '월': '1',
#       '일': '12',
#       '일련번호': '11500-5966',
#       '전용면적': '122.1243',
#       '중개사소재지': ' ',
#       '지번': '240-1',
#       '지역코드': '11500',
#       '층': '5',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    98,000',
#       '거래유형': ' ',
#       '건축년도': '2001',
#       '년': '2021',
#       '도로명': '공항대로75길',
#       '도로명건물본번호코드': '00030',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145217',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0282',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '삼정그린코아',
#       '월': '1',
#       '일': '12',
#       '일련번호': '11500-18',
#       '전용면적': '84.358',
#       '중개사소재지': ' ',
#       '지번': '282',
#       '지역코드': '11500',
#       '층': '1',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    84,500',
#       '거래유형': ' ',
#       '건축년도': '1990',
#       '년': '2021',
#       '도로명': '양천로67길',
#       '도로명건물본번호코드': '00077',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145422',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0066',
#       '법정동부번코드': '0009',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '염창동한강우성',
#       '월': '1',
#       '일': '13',
#       '일련번호': '11500-495',
#       '전용면적': '84.68',
#       '중개사소재지': ' ',
#       '지번': '66-9',
#       '지역코드': '11500',
#       '층': '3',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    87,000',
#       '거래유형': ' ',
#       '건축년도': '1999',
#       '년': '2021',
#       '도로명': '양천로',
#       '도로명건물본번호코드': '00731',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3115008',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0258',
#       '법정동부번코드': '0001',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '동아3',
#       '월': '1',
#       '일': '16',
#       '일련번호': '11500-7',
#       '전용면적': '59.83',
#       '중개사소재지': ' ',
#       '지번': '258-1',
#       '지역코드': '11500',
#       '층': '8',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    65,000',
#       '거래유형': ' ',
#       '건축년도': '1990',
#       '년': '2021',
#       '도로명': '양천로67길',
#       '도로명건물본번호코드': '00077',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145422',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0066',
#       '법정동부번코드': '0009',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '염창동한강우성',
#       '월': '1',
#       '일': '16',
#       '일련번호': '11500-495',
#       '전용면적': '65.88',
#       '중개사소재지': ' ',
#       '지번': '66-9',
#       '지역코드': '11500',
#       '층': '1',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    91,000',
#       '거래유형': ' ',
#       '건축년도': '2005',
#       '년': '2021',
#       '도로명': '양천로75길',
#       '도로명건물본번호코드': '00019',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145429',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0299',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '강변힐스테이트',
#       '월': '1',
#       '일': '16',
#       '일련번호': '11500-466',
#       '전용면적': '59.9',
#       '중개사소재지': ' ',
#       '지번': '299',
#       '지역코드': '11500',
#       '층': '1',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    79,000',
#       '거래유형': ' ',
#       '건축년도': '1998',
#       '년': '2021',
#       '도로명': '양천로73길',
#       '도로명건물본번호코드': '00080',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145428',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0293',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '한강동아',
#       '월': '1',
#       '일': '16',
#       '일련번호': '11500-27',
#       '전용면적': '59.97',
#       '중개사소재지': ' ',
#       '지번': '293',
#       '지역코드': '11500',
#       '층': '13',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    62,000',
#       '거래유형': ' ',
#       '건축년도': '1995',
#       '년': '2021',
#       '도로명': '양천로67길',
#       '도로명건물본번호코드': '00032',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145422',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0289',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '신동아',
#       '월': '1',
#       '일': '16',
#       '일련번호': '11500-21',
#       '전용면적': '59.82',
#       '중개사소재지': ' ',
#       '지번': '289',
#       '지역코드': '11500',
#       '층': '14',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    68,000',
#       '거래유형': ' ',
#       '건축년도': '1998',
#       '년': '2021',
#       '도로명': '양천로63길',
#       '도로명건물본번호코드': '00052',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145418',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0290',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '벽산늘푸른',
#       '월': '1',
#       '일': '16',
#       '일련번호': '11500-14',
#       '전용면적': '59.97',
#       '중개사소재지': ' ',
#       '지번': '290',
#       '지역코드': '11500',
#       '층': '13',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '   123,000',
#       '거래유형': ' ',
#       '건축년도': '2009',
#       '년': '2021',
#       '도로명': '양천로73길',
#       '도로명건물본번호코드': '00024',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145428',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0306',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '염창힐스테이트',
#       '월': '1',
#       '일': '17',
#       '일련번호': '11500-5933',
#       '전용면적': '84.551',
#       '중개사소재지': ' ',
#       '지번': '306',
#       '지역코드': '11500',
#       '층': '7',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    66,000',
#       '거래유형': ' ',
#       '건축년도': '1995',
#       '년': '2021',
#       '도로명': '양천로67길',
#       '도로명건물본번호코드': '00032',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145422',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0289',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '신동아',
#       '월': '1',
#       '일': '18',
#       '일련번호': '11500-21',
#       '전용면적': '59.82',
#       '중개사소재지': ' ',
#       '지번': '289',
#       '지역코드': '11500',
#       '층': '13',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    89,000',
#       '거래유형': ' ',
#       '건축년도': '1990',
#       '년': '2021',
#       '도로명': '양천로67길',
#       '도로명건물본번호코드': '00077',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145422',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0066',
#       '법정동부번코드': '0009',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '염창동한강우성',
#       '월': '1',
#       '일': '19',
#       '일련번호': '11500-495',
#       '전용면적': '84.7',
#       '중개사소재지': ' ',
#       '지번': '66-9',
#       '지역코드': '11500',
#       '층': '1',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    90,000',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '양천로75길',
#       '도로명건물본번호코드': '00057',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145429',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0288',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '현대1',
#       '월': '1',
#       '일': '20',
#       '일련번호': '11500-28',
#       '전용면적': '84.34',
#       '중개사소재지': ' ',
#       '지번': '288',
#       '지역코드': '11500',
#       '층': '8',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '   108,000',
#       '거래유형': ' ',
#       '건축년도': '2010',
#       '년': '2021',
#       '도로명': '양천로63길',
#       '도로명건물본번호코드': '00051',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145418',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0240',
#       '법정동부번코드': '0001',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '강변월드메르디앙',
#       '월': '1',
#       '일': '20',
#       '일련번호': '11500-5966',
#       '전용면적': '84.9341',
#       '중개사소재지': ' ',
#       '지번': '240-1',
#       '지역코드': '11500',
#       '층': '8',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    75,000',
#       '거래유형': ' ',
#       '건축년도': '2005',
#       '년': '2021',
#       '도로명': '공항대로59다길',
#       '도로명건물본번호코드': '00061',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145208',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0271',
#       '법정동부번코드': '0004',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '염창2차보람',
#       '월': '1',
#       '일': '20',
#       '일련번호': '11500-5181',
#       '전용면적': '59.87',
#       '중개사소재지': ' ',
#       '지번': '271-4',
#       '지역코드': '11500',
#       '층': '4',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '   102,800',
#       '거래유형': ' ',
#       '건축년도': '2005',
#       '년': '2021',
#       '도로명': '양천로75길',
#       '도로명건물본번호코드': '00019',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145429',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0299',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '강변힐스테이트',
#       '월': '1',
#       '일': '23',
#       '일련번호': '11500-466',
#       '전용면적': '84.99',
#       '중개사소재지': ' ',
#       '지번': '299',
#       '지역코드': '11500',
#       '층': '3',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    88,400',
#       '거래유형': ' ',
#       '건축년도': '1995',
#       '년': '2021',
#       '도로명': '양천로67길',
#       '도로명건물본번호코드': '00032',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145422',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0289',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '신동아',
#       '월': '1',
#       '일': '25',
#       '일련번호': '11500-21',
#       '전용면적': '84.7',
#       '중개사소재지': ' ',
#       '지번': '289',
#       '지역코드': '11500',
#       '층': '8',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    46,500',
#       '거래유형': ' ',
#       '건축년도': '1995',
#       '년': '2021',
#       '도로명': '양천로',
#       '도로명건물본번호코드': '00706',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3115008',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0263',
#       '법정동부번코드': '0002',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '주상복합태진가람',
#       '월': '1',
#       '일': '25',
#       '일련번호': '11500-24',
#       '전용면적': '58.86',
#       '중개사소재지': ' ',
#       '지번': '263-2',
#       '지역코드': '11500',
#       '층': '7',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    90,000',
#       '거래유형': ' ',
#       '건축년도': '1992',
#       '년': '2021',
#       '도로명': '양천로67길',
#       '도로명건물본번호코드': '00054',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145422',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0287',
#       '법정동부번코드': '0001',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '우성2',
#       '월': '1',
#       '일': '25',
#       '일련번호': '11500-23',
#       '전용면적': '84.7',
#       '중개사소재지': ' ',
#       '지번': '287-1',
#       '지역코드': '11500',
#       '층': '3',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    95,000',
#       '거래유형': ' ',
#       '건축년도': '1999',
#       '년': '2021',
#       '도로명': '공항대로71길',
#       '도로명건물본번호코드': '00031',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145216',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0280',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '극동상록수',
#       '월': '1',
#       '일': '28',
#       '일련번호': '11500-2',
#       '전용면적': '84.96',
#       '중개사소재지': ' ',
#       '지번': '280',
#       '지역코드': '11500',
#       '층': '10',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '   101,000',
#       '거래유형': ' ',
#       '건축년도': '2005',
#       '년': '2021',
#       '도로명': '공항대로',
#       '도로명건물본번호코드': '00637',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '2005007',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0282',
#       '법정동부번코드': '0019',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '현대아이파크',
#       '월': '1',
#       '일': '29',
#       '일련번호': '11500-5104',
#       '전용면적': '84.84',
#       '중개사소재지': ' ',
#       '지번': '282-19',
#       '지역코드': '11500',
#       '층': '7',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    81,800',
#       '거래유형': ' ',
#       '건축년도': '1999',
#       '년': '2021',
#       '도로명': '양천로',
#       '도로명건물본번호코드': '00731',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3115008',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0258',
#       '법정동부번코드': '0001',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '동아3',
#       '월': '1',
#       '일': '30',
#       '일련번호': '11500-7',
#       '전용면적': '59.83',
#       '중개사소재지': ' ',
#       '지번': '258-1',
#       '지역코드': '11500',
#       '층': '2',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '   130,000',
#       '거래유형': ' ',
#       '건축년도': '2005',
#       '년': '2021',
#       '도로명': '공항대로75길',
#       '도로명건물본번호코드': '00017',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145217',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0281',
#       '법정동부번코드': '0022',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '염창1차한화꿈에그린',
#       '월': '1',
#       '일': '30',
#       '일련번호': '11500-465',
#       '전용면적': '84.93',
#       '중개사소재지': ' ',
#       '지번': '281-22',
#       '지역코드': '11500',
#       '층': '19',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '   104,000',
#       '거래유형': ' ',
#       '건축년도': '1998',
#       '년': '2021',
#       '도로명': '양천로69길',
#       '도로명건물본번호코드': '00058',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145423',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0292',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '동아',
#       '월': '1',
#       '일': '31',
#       '일련번호': '11500-6',
#       '전용면적': '84.95',
#       '중개사소재지': ' ',
#       '지번': '292',
#       '지역코드': '11500',
#       '층': '13',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '   129,500',
#       '거래유형': ' ',
#       '건축년도': '2019',
#       '년': '2021',
#       '도로명': '공항대로',
#       '도로명건물본번호코드': '00583',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '2005007',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0309',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': 'e편한세상염창',
#       '월': '1',
#       '일': '31',
#       '일련번호': '11500-7907',
#       '전용면적': '74.2998',
#       '중개사소재지': ' ',
#       '지번': '309',
#       '지역코드': '11500',
#       '층': '3',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    77,000',
#       '거래유형': ' ',
#       '건축년도': '1998',
#       '년': '2021',
#       '도로명': '양천로73길',
#       '도로명건물본번호코드': '00080',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145428',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 염창동',
#       '법정동본번코드': '0293',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '한강동아',
#       '월': '1',
#       '일': '31',
#       '일련번호': '11500-27',
#       '전용면적': '59.97',
#       '중개사소재지': ' ',
#       '지번': '293',
#       '지역코드': '11500',
#       '층': '9',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    73,600',
#       '거래유형': ' ',
#       '건축년도': '1999',
#       '년': '2021',
#       '도로명': '공항대로59길',
#       '도로명건물본번호코드': '00064',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145206',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0634',
#       '법정동부번코드': '0002',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '한사랑2삼성',
#       '월': '1',
#       '일': '1',
#       '일련번호': '11500-61',
#       '전용면적': '59.37',
#       '중개사소재지': ' ',
#       '지번': '634-2',
#       '지역코드': '11500',
#       '층': '3',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    88,500',
#       '거래유형': ' ',
#       '건축년도': '1999',
#       '년': '2021',
#       '도로명': '공항대로59길',
#       '도로명건물본번호코드': '00064',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145206',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0634',
#       '법정동부번코드': '0002',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '한사랑2삼성',
#       '월': '1',
#       '일': '3',
#       '일련번호': '11500-61',
#       '전용면적': '84.96',
#       '중개사소재지': ' ',
#       '지번': '634-2',
#       '지역코드': '11500',
#       '층': '14',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    85,300',
#       '거래유형': ' ',
#       '건축년도': '1997',
#       '년': '2021',
#       '도로명': '양천로66길',
#       '도로명건물본번호코드': '00006',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145420',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0632',
#       '법정동부번코드': '0004',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '삼성한사랑1',
#       '월': '1',
#       '일': '4',
#       '일련번호': '11500-42',
#       '전용면적': '84.99',
#       '중개사소재지': ' ',
#       '지번': '632-4',
#       '지역코드': '11500',
#       '층': '6',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    75,800',
#       '거래유형': ' ',
#       '건축년도': '1995',
#       '년': '2021',
#       '도로명': '공항대로39길',
#       '도로명건물본번호코드': '00074',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145179',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0695',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '주공5',
#       '월': '1',
#       '일': '4',
#       '일련번호': '11500-56',
#       '전용면적': '58.14',
#       '중개사소재지': ' ',
#       '지번': '695',
#       '지역코드': '11500',
#       '층': '6',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    82,500',
#       '거래유형': ' ',
#       '건축년도': '1995',
#       '년': '2021',
#       '도로명': '강서로56나길',
#       '도로명건물본번호코드': '00037',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145070',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0688',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '주공3',
#       '월': '1',
#       '일': '5',
#       '일련번호': '11500-55',
#       '전용면적': '58.14',
#       '중개사소재지': ' ',
#       '지번': '688',
#       '지역코드': '11500',
#       '층': '7',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    81,500',
#       '거래유형': ' ',
#       '건축년도': '1995',
#       '년': '2021',
#       '도로명': '강서로56나길',
#       '도로명건물본번호코드': '00037',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145070',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0688',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '주공3',
#       '월': '1',
#       '일': '7',
#       '일련번호': '11500-55',
#       '전용면적': '58.14',
#       '중개사소재지': ' ',
#       '지번': '688',
#       '지역코드': '11500',
#       '층': '12',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    28,200',
#       '거래유형': ' ',
#       '건축년도': '2019',
#       '년': '2021',
#       '도로명': '화곡로',
#       '도로명건물본번호코드': '00374',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3005069',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0656',
#       '법정동부번코드': '0017',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '지엠벨리',
#       '월': '1',
#       '일': '7',
#       '일련번호': '11500-7919',
#       '전용면적': '27.57',
#       '중개사소재지': ' ',
#       '지번': '656-17',
#       '지역코드': '11500',
#       '층': '5',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    80,000',
#       '거래유형': ' ',
#       '건축년도': '2002',
#       '년': '2021',
#       '도로명': '화곡로',
#       '도로명건물본번호코드': '00390',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3005069',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0640',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '보람(640)',
#       '월': '1',
#       '일': '7',
#       '일련번호': '11500-64',
#       '전용면적': '83.07',
#       '중개사소재지': ' ',
#       '지번': '640',
#       '지역코드': '11500',
#       '층': '8',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    75,000',
#       '거래유형': ' ',
#       '건축년도': '1995',
#       '년': '2021',
#       '도로명': '강서로56나길',
#       '도로명건물본번호코드': '00037',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145070',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0688',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '주공3',
#       '월': '1',
#       '일': '7',
#       '일련번호': '11500-55',
#       '전용면적': '58.14',
#       '중개사소재지': ' ',
#       '지번': '688',
#       '지역코드': '11500',
#       '층': '10',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    69,700',
#       '거래유형': ' ',
#       '건축년도': '1995',
#       '년': '2021',
#       '도로명': '강서로56나길',
#       '도로명건물본번호코드': '00037',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145070',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0688',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '주공3',
#       '월': '1',
#       '일': '8',
#       '일련번호': '11500-55',
#       '전용면적': '58.14',
#       '중개사소재지': ' ',
#       '지번': '688',
#       '지역코드': '11500',
#       '층': '1',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '   110,000',
#       '거래유형': ' ',
#       '건축년도': '2003',
#       '년': '2021',
#       '도로명': '공항대로55길',
#       '도로명건물본번호코드': '00050',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145199',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0713',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '대동황토방2',
#       '월': '1',
#       '일': '8',
#       '일련번호': '11500-229',
#       '전용면적': '114.99',
#       '중개사소재지': ' ',
#       '지번': '713',
#       '지역코드': '11500',
#       '층': '8',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    95,000',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '강서로56나길',
#       '도로명건물본번호코드': '00110',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145070',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0691',
#       '법정동부번코드': '0003',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '부영',
#       '월': '1',
#       '일': '9',
#       '일련번호': '11500-41',
#       '전용면적': '80.64',
#       '중개사소재지': ' ',
#       '지번': '691-3',
#       '지역코드': '11500',
#       '층': '13',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    74,300',
#       '거래유형': ' ',
#       '건축년도': '1999',
#       '년': '2021',
#       '도로명': '공항대로59길',
#       '도로명건물본번호코드': '00064',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145206',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0634',
#       '법정동부번코드': '0002',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '한사랑2삼성',
#       '월': '1',
#       '일': '9',
#       '일련번호': '11500-61',
#       '전용면적': '59.73',
#       '중개사소재지': ' ',
#       '지번': '634-2',
#       '지역코드': '11500',
#       '층': '5',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    83,000',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '공항대로',
#       '도로명건물본번호코드': '00351',
#       '도로명건물부번호코드': '00021',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '02',
#       '도로명지상지하코드': '0',
#       '도로명코드': '2005007',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0701',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '진로,미주아파트',
#       '월': '1',
#       '일': '9',
#       '일련번호': '11500-58',
#       '전용면적': '84.96',
#       '중개사소재지': ' ',
#       '지번': '701',
#       '지역코드': '11500',
#       '층': '2',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    46,300',
#       '거래유형': ' ',
#       '건축년도': '2009',
#       '년': '2021',
#       '도로명': '화곡로66길',
#       '도로명건물본번호코드': '00093',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145549',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0637',
#       '법정동부번코드': '0015',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '예지펠리스아파트',
#       '월': '1',
#       '일': '11',
#       '일련번호': '11500-5918',
#       '전용면적': '74.86',
#       '중개사소재지': ' ',
#       '지번': '637-15',
#       '지역코드': '11500',
#       '층': '8',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '   104,000',
#       '거래유형': ' ',
#       '건축년도': '1995',
#       '년': '2021',
#       '도로명': '강서로68길',
#       '도로명건물본번호코드': '00108',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145077',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0691',
#       '법정동부번코드': '0001',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '동성',
#       '월': '1',
#       '일': '12',
#       '일련번호': '11500-36',
#       '전용면적': '150.05',
#       '중개사소재지': ' ',
#       '지번': '691-1',
#       '지역코드': '11500',
#       '층': '12',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    79,000',
#       '거래유형': ' ',
#       '건축년도': '1995',
#       '년': '2021',
#       '도로명': '강서로56나길',
#       '도로명건물본번호코드': '00037',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145070',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0688',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '주공3',
#       '월': '1',
#       '일': '13',
#       '일련번호': '11500-55',
#       '전용면적': '58.14',
#       '중개사소재지': ' ',
#       '지번': '688',
#       '지역코드': '11500',
#       '층': '14',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    65,000',
#       '거래유형': ' ',
#       '건축년도': '2020',
#       '년': '2021',
#       '도로명': '공항대로53가길',
#       '도로명건물본번호코드': '00022',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145196',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0722',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '등촌파밀리에더클래식101동',
#       '월': '1',
#       '일': '13',
#       '일련번호': '11500-8050',
#       '전용면적': '48.39',
#       '중개사소재지': ' ',
#       '지번': '722',
#       '지역코드': '11500',
#       '층': '7',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    59,800',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '공항대로43길',
#       '도로명건물본번호코드': '00104',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145185',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0707',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '등촌7,8단지주공아파트',
#       '월': '1',
#       '일': '14',
#       '일련번호': '11500-57',
#       '전용면적': '41.85',
#       '중개사소재지': ' ',
#       '지번': '707',
#       '지역코드': '11500',
#       '층': '15',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '   104,000',
#       '거래유형': ' ',
#       '건축년도': '1995',
#       '년': '2021',
#       '도로명': '강서로68길',
#       '도로명건물본번호코드': '00108',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145077',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0691',
#       '법정동부번코드': '0001',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '동성',
#       '월': '1',
#       '일': '15',
#       '일련번호': '11500-36',
#       '전용면적': '134.94',
#       '중개사소재지': ' ',
#       '지번': '691-1',
#       '지역코드': '11500',
#       '층': '11',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    75,000',
#       '거래유형': ' ',
#       '건축년도': '1995',
#       '년': '2021',
#       '도로명': '공항대로39길',
#       '도로명건물본번호코드': '00074',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145179',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0695',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '주공5',
#       '월': '1',
#       '일': '15',
#       '일련번호': '11500-56',
#       '전용면적': '58.14',
#       '중개사소재지': ' ',
#       '지번': '695',
#       '지역코드': '11500',
#       '층': '9',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    60,000',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '강서로68길',
#       '도로명건물본번호코드': '00036',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145077',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0687',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '등촌1,2단지주공아파트',
#       '월': '1',
#       '일': '15',
#       '일련번호': '11500-54',
#       '전용면적': '41.85',
#       '중개사소재지': ' ',
#       '지번': '687',
#       '지역코드': '11500',
#       '층': '6',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    78,300',
#       '거래유형': ' ',
#       '건축년도': '1995',
#       '년': '2021',
#       '도로명': '화곡로63가길',
#       '도로명건물본번호코드': '00071',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145545',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0702',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '주공10',
#       '월': '1',
#       '일': '16',
#       '일련번호': '11500-53',
#       '전용면적': '58.14',
#       '중개사소재지': ' ',
#       '지번': '702',
#       '지역코드': '11500',
#       '층': '11',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    58,000',
#       '거래유형': ' ',
#       '건축년도': '2003',
#       '년': '2021',
#       '도로명': '화곡로66길',
#       '도로명건물본번호코드': '00173',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145549',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0635',
#       '법정동부번코드': '0006',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '나성',
#       '월': '1',
#       '일': '17',
#       '일련번호': '11500-230',
#       '전용면적': '59.826',
#       '중개사소재지': ' ',
#       '지번': '635-6',
#       '지역코드': '11500',
#       '층': '4',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    84,500',
#       '거래유형': ' ',
#       '건축년도': '1999',
#       '년': '2021',
#       '도로명': '공항대로45길',
#       '도로명건물본번호코드': '00068',
#       '도로명건물부번호코드': '00006',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145188',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0638',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '서광등촌마을아파트',
#       '월': '1',
#       '일': '18',
#       '일련번호': '11500-44',
#       '전용면적': '84.93',
#       '중개사소재지': ' ',
#       '지번': '638',
#       '지역코드': '11500',
#       '층': '5',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '   107,000',
#       '거래유형': ' ',
#       '건축년도': '2004',
#       '년': '2021',
#       '도로명': '등촌로',
#       '도로명건물본번호코드': '00163',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3005064',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0715',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '등촌동아이파크',
#       '월': '1',
#       '일': '19',
#       '일련번호': '11500-263',
#       '전용면적': '84.7556',
#       '중개사소재지': ' ',
#       '지번': '715',
#       '지역코드': '11500',
#       '층': '13',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    73,000',
#       '거래유형': ' ',
#       '건축년도': '1997',
#       '년': '2021',
#       '도로명': '화곡로68길',
#       '도로명건물본번호코드': '00033',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145550',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 등촌동',
#       '법정동본번코드': '0628',
#       '법정동부번코드': '0015',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '등촌라인(조합)',
#       '월': '1',
#       '일': '21',
#       '일련번호': '11500-39',
#       '전용면적': '59.91',
#       '중개사소재지': ' ',
#       '지번': '628-15',
#       '지역코드': '11500',
# ...
#       '월': '1',
#       '일': '17',
#       '일련번호': '11500-196',
#       '전용면적': '39.36',
#       '중개사소재지': ' ',
#       '지번': '832',
#       '지역코드': '11500',
#       '층': '10',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    61,500',
#       '거래유형': ' ',
#       '건축년도': '2002',
#       '년': '2021',
#       '도로명': '양천로14길',
#       '도로명건물본번호코드': '00037',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145388',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0868',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '신안네트빌1단지',
#       '월': '1',
#       '일': '18',
#       '일련번호': '11500-222',
#       '전용면적': '84.0164',
#       '중개사소재지': ' ',
#       '지번': '868',
#       '지역코드': '11500',
#       '층': '1',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    59,500',
#       '거래유형': ' ',
#       '건축년도': '2005',
#       '년': '2021',
#       '도로명': '양천로14길',
#       '도로명건물본번호코드': '00118',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145388',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0546',
#       '법정동부번코드': '0001',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '방화3차우림필유',
#       '월': '1',
#       '일': '18',
#       '일련번호': '11500-5164',
#       '전용면적': '74.8',
#       '중개사소재지': ' ',
#       '지번': '546-1',
#       '지역코드': '11500',
#       '층': '14',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    65,400',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '금낭화로',
#       '도로명건물본번호코드': '00287',
#       '도로명건물부번호코드': '00019',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3115002',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0814',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '방화5',
#       '월': '1',
#       '일': '19',
#       '일련번호': '11500-197',
#       '전용면적': '49.77',
#       '중개사소재지': ' ',
#       '지번': '814',
#       '지역코드': '11500',
#       '층': '12',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    59,900',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '양천로',
#       '도로명건물본번호코드': '00125',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '05',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3115008',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0841',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '장미',
#       '월': '1',
#       '일': '19',
#       '일련번호': '11500-209',
#       '전용면적': '59.04',
#       '중개사소재지': ' ',
#       '지번': '841',
#       '지역코드': '11500',
#       '층': '7',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    85,000',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '방화대로47가길',
#       '도로명건물본번호코드': '00022',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145340',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0831',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '방화4단지',
#       '월': '1',
#       '일': '21',
#       '일련번호': '11500-195',
#       '전용면적': '100.35',
#       '중개사소재지': ' ',
#       '지번': '831',
#       '지역코드': '11500',
#       '층': '15',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    99,000',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '방화대로47가길',
#       '도로명건물본번호코드': '00022',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145340',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0831',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '방화4단지',
#       '월': '1',
#       '일': '21',
#       '일련번호': '11500-195',
#       '전용면적': '134.65',
#       '중개사소재지': ' ',
#       '지번': '831',
#       '지역코드': '11500',
#       '층': '5',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    22,600',
#       '거래유형': ' ',
#       '건축년도': '1988',
#       '년': '2021',
#       '도로명': '양천로14길',
#       '도로명건물본번호코드': '00086',
#       '도로명건물부번호코드': '00005',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145388',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0547',
#       '법정동부번코드': '0011',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '한오',
#       '월': '1',
#       '일': '22',
#       '일련번호': '11500-216',
#       '전용면적': '47.06',
#       '중개사소재지': ' ',
#       '지번': '547-11',
#       '지역코드': '11500',
#       '층': '6',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    47,000',
#       '거래유형': ' ',
#       '건축년도': '1993',
#       '년': '2021',
#       '도로명': '방화대로48길',
#       '도로명건물본번호코드': '00040',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145342',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0839',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '방화그린',
#       '월': '1',
#       '일': '23',
#       '일련번호': '11500-193',
#       '전용면적': '39.76',
#       '중개사소재지': ' ',
#       '지번': '839',
#       '지역코드': '11500',
#       '층': '14',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    99,000',
#       '거래유형': ' ',
#       '건축년도': '2009',
#       '년': '2021',
#       '도로명': '방화대로41길',
#       '도로명건물본번호코드': '00009',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145336',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0894',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '강서센트레빌3차(894-0)',
#       '월': '1',
#       '일': '23',
#       '일련번호': '11500-5853',
#       '전용면적': '84.4',
#       '중개사소재지': ' ',
#       '지번': '894',
#       '지역코드': '11500',
#       '층': '6',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    35,800',
#       '거래유형': ' ',
#       '건축년도': '1999',
#       '년': '2021',
#       '도로명': '양천로7길',
#       '도로명건물본번호코드': '00008',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145431',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0861',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '홍익아파트',
#       '월': '1',
#       '일': '23',
#       '일련번호': '11500-219',
#       '전용면적': '64.44',
#       '중개사소재지': ' ',
#       '지번': '861',
#       '지역코드': '11500',
#       '층': '6',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    64,600',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '금낭화로',
#       '도로명건물본번호코드': '00287',
#       '도로명건물부번호코드': '00019',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3115002',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0814',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '방화5',
#       '월': '1',
#       '일': '23',
#       '일련번호': '11500-197',
#       '전용면적': '49.77',
#       '중개사소재지': ' ',
#       '지번': '814',
#       '지역코드': '11500',
#       '층': '10',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    46,000',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '금낭화로',
#       '도로명건물본번호코드': '00287',
#       '도로명건물부번호코드': '00019',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3115002',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0814',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '방화5',
#       '월': '1',
#       '일': '23',
#       '일련번호': '11500-197',
#       '전용면적': '33.18',
#       '중개사소재지': ' ',
#       '지번': '814',
#       '지역코드': '11500',
#       '층': '11',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    48,000',
#       '거래유형': ' ',
#       '건축년도': '1993',
#       '년': '2021',
#       '도로명': '방화대로48길',
#       '도로명건물본번호코드': '00040',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145342',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0839',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '방화그린',
#       '월': '1',
#       '일': '23',
#       '일련번호': '11500-193',
#       '전용면적': '49.77',
#       '중개사소재지': ' ',
#       '지번': '839',
#       '지역코드': '11500',
#       '층': '1',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    46,000',
#       '거래유형': ' ',
#       '건축년도': '2018',
#       '년': '2021',
#       '도로명': '양천로10길',
#       '도로명건물본번호코드': '00037',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명코드': '4145384',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0903',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '신세계아파트',
#       '월': '1',
#       '일': '24',
#       '일련번호': '11500-7784',
#       '전용면적': '63.28',
#       '중개사소재지': ' ',
#       '지번': '903',
#       '지역코드': '11500',
#       '층': '7',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    44,900',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '방화대로47길',
#       '도로명건물본번호코드': '00055',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145341',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0832',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '청솔',
#       '월': '1',
#       '일': '26',
#       '일련번호': '11500-196',
#       '전용면적': '39.36',
#       '중개사소재지': ' ',
#       '지번': '832',
#       '지역코드': '11500',
#       '층': '4',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    59,990',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '금낭화로',
#       '도로명건물본번호코드': '00287',
#       '도로명건물부번호코드': '00019',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3115002',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0814',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '방화5',
#       '월': '1',
#       '일': '26',
#       '일련번호': '11500-197',
#       '전용면적': '49.77',
#       '중개사소재지': ' ',
#       '지번': '814',
#       '지역코드': '11500',
#       '층': '2',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    47,000',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '금낭화로',
#       '도로명건물본번호코드': '00287',
#       '도로명건물부번호코드': '00019',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3115002',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0814',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '방화5',
#       '월': '1',
#       '일': '26',
#       '일련번호': '11500-197',
#       '전용면적': '33.18',
#       '중개사소재지': ' ',
#       '지번': '814',
#       '지역코드': '11500',
#       '층': '9',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    50,000',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '양천로6길',
#       '도로명건물본번호코드': '00028',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145424',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0852',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '마곡중앙하이츠아파트',
#       '월': '1',
#       '일': '28',
#       '일련번호': '11500-192',
#       '전용면적': '59.34',
#       '중개사소재지': ' ',
#       '지번': '852',
#       '지역코드': '11500',
#       '층': '6',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    53,700',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '금낭화로',
#       '도로명건물본번호코드': '00287',
#       '도로명건물부번호코드': '00019',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3115002',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0814',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '방화5',
#       '월': '1',
#       '일': '28',
#       '일련번호': '11500-197',
#       '전용면적': '39.6',
#       '중개사소재지': ' ',
#       '지번': '814',
#       '지역코드': '11500',
#       '층': '11',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    52,500',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '금낭화로',
#       '도로명건물본번호코드': '00287',
#       '도로명건물부번호코드': '00019',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3115002',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0814',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '방화5',
#       '월': '1',
#       '일': '29',
#       '일련번호': '11500-197',
#       '전용면적': '39.6',
#       '중개사소재지': ' ',
#       '지번': '814',
#       '지역코드': '11500',
#       '층': '5',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    55,000',
#       '거래유형': ' ',
#       '건축년도': '1994',
#       '년': '2021',
#       '도로명': '양천로6길',
#       '도로명건물본번호코드': '00028',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145424',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0852',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '마곡중앙하이츠아파트',
#       '월': '1',
#       '일': '30',
#       '일련번호': '11500-192',
#       '전용면적': '51.03',
#       '중개사소재지': ' ',
#       '지번': '852',
#       '지역코드': '11500',
#       '층': '5',
#       '해제사유발생일': ' ',
#       '해제여부': ' '},
#      {'거래금액': '    64,000',
#       '거래유형': ' ',
#       '건축년도': '2003',
#       '년': '2021',
#       '도로명': '양천로6길',
#       '도로명건물본번호코드': '00057',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11500',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4145424',
#       '동': ' ',
#       '등기일자': ' ',
#       '매도자': ' ',
#       '매수자': ' ',
#       '법정동': ' 방화동',
#       '법정동본번코드': '0874',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11500',
#       '법정동읍면동코드': '10900',
#       '법정동지번코드': '1',
#       '아파트': '대림e-편한세상',
#       '월': '1',
#       '일': '31',
#       '일련번호': '11500-238',
#       '전용면적': '67.68',
#       '중개사소재지': ' ',
#       '지번': '874',
#       '지역코드': '11500',
#       '층': '1',
#       '해제사유발생일': ' ',
#       '해제여부': ' '}]},
#    'numOfRows': '500',
#    'pageNo': '1',
#    'totalCount': '328'}}}

# %%
print(type(contents))
# Out:
# <class 'dict'>

# %%
data = pd.DataFrame(contents['response']['body']['items']['item'])
data.head()
# Out:
#          거래금액 거래유형  건축년도     년     도로명 도로명건물본번호코드 도로명건물부번호코드 도로명시군구코드  \
# 0      70,000       1996  2021  양천로75길      00060      00000    11500
# 1      85,500       1992  2021  양천로67길      00054      00000    11500
# 2      98,000       2005  2021    공항대로      00637      00000    11500
# 3      80,300       1994  2021  양천로75길      00057      00000    11500
# 4      74,800       1995  2021     양천로      00637      00000    11500
#
#   도로명일련번호코드 도로명지상지하코드  ...  월  일        일련번호   전용면적 중개사소재지      지번   지역코드   층  \
# 0        01         0  ...  1  3    11500-30  59.92            291  11500  12
# 1        01         0  ...  1  5    11500-23   84.7          287-1  11500  12
# 2        01         0  ...  1  5  11500-5104  84.84         282-19  11500   4
# 3        01         0  ...  1  5    11500-28  84.34            288  11500   2
# 4        01         0  ...  1  6    11500-16  59.94          244-2  11500   7
#
#   해제사유발생일 해제여부
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 32 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328 entries, 0 to 327
# Data columns (total 32 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   거래금액        328 non-null    object
#  1   거래유형        328 non-null    object
#  2   건축년도        328 non-null    object
#  3   년           328 non-null    object
#  4   도로명         328 non-null    object
#  5   도로명건물본번호코드  328 non-null    object
#  6   도로명건물부번호코드  328 non-null    object
#  7   도로명시군구코드    328 non-null    object
#  8   도로명일련번호코드   328 non-null    object
#  9   도로명지상지하코드   326 non-null    object
#  10  도로명코드       328 non-null    object
#  11  동           328 non-null    object
#  12  등기일자        328 non-null    object
#  13  매도자         328 non-null    object
#  14  매수자         328 non-null    object
#  15  법정동         328 non-null    object
#  16  법정동본번코드     328 non-null    object
#  17  법정동부번코드     328 non-null    object
#  18  법정동시군구코드    328 non-null    object
#  19  법정동읍면동코드    328 non-null    object
#  20  법정동지번코드     328 non-null    object
#  21  아파트         328 non-null    object
#  22  월           328 non-null    object
#  23  일           328 non-null    object
#  24  일련번호        328 non-null    object
#  25  전용면적        328 non-null    object
#  26  중개사소재지      328 non-null    object
#  27  지번          328 non-null    object
#  28  지역코드        328 non-null    object
#  29  층           328 non-null    object
#  30  해제사유발생일     328 non-null    object
#  31  해제여부        328 non-null    object
# dtypes: object(32)
# memory usage: 82.1+ KB
