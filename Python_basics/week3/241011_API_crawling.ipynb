# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 데이터 크롤링(API)

# %% [markdown]
# ## pandas 기초문법 - 시계열 데이터
# - 일정 시간 간격으로 배치된 데이터 셋
# - 시간 안의 패턴과 반복을 찾은 후 분석해야 한다.
#
# - 시간을 다룰려면 **Timestamp**클래스를 사용하면 된다.
#   + https://pandas.pydata.org/docs/reference/api/pandas.Timestamp.html

# %%
import pandas as pd

timestamp = pd.Timestamp('2023-11-10 12:30:00')
print(timestamp, '\t' ,type(timestamp))
# Out:
# 2023-11-10 12:30:00 	 <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# ### 나라마다 다른 날짜 표기법
# - format 활용 https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior

# %%
# 미국식

timestamp = pd.Timestamp('06/07/20 12:30:00') # 월/일/년, 20년 6월 7일
print(timestamp, '\t' ,type(timestamp))
# Out:
# 2020-06-07 12:30:00 	 <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
# 영국식
timestamp = pd.to_datetime('07/06/20', format = '%d/%m/%y') #20년 6월 7일
print(timestamp, '\t' ,type(timestamp))
print(timestamp.year)
# Out:
# 2020-06-07 00:00:00 	 <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 2020

# %%
# 영국식
timestamp = pd.to_datetime('07/06/20', format = '%d/%m/%y') #20년 6월 7일
print(timestamp, '\t' ,type(timestamp))
# Out:
# 2020-06-07 00:00:00 	 <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# - 활용해보기

# %%
ts = pd.to_datetime("2024-10-11 09:45:38")
print(ts)
print(ts.year)
# Out:
# 2024-10-11 09:45:38
# 2024

# %% [markdown]
# ## Timedelta
# - 시계열을 계산할 수 있도록 만든 메서드
# - 시간 연산을 가능하게 해 준다.

# %%
tmp = pd.Timedelta(days = 100, hours = 2, minutes = 30, seconds = 17)
print(type(tmp), tmp)
# Out:
# <class 'pandas._libs.tslibs.timedeltas.Timedelta'> 100 days 02:30:17

# %%
ts - tmp # ts에서 100일이 빠진다!
# Out:
# Timestamp('2024-07-03 07:15:21')

# %%
dates = ['2024-10-09', '2024-10-10', '2024-10-18']

idx = pd.to_datetime(dates)
idx
# Out:
# DatetimeIndex(['2024-10-09', '2024-10-10', '2024-10-18'], dtype='datetime64[ns]', freq=None)

# %%
idx[2:3]
# Out:
# DatetimeIndex(['2024-10-18'], dtype='datetime64[ns]', freq=None)

# %%
idx.year
# Out:
# Index([2024, 2024, 2024], dtype='int32')

# %% [markdown]
# ## Unix Time

# %%
day = 1628899200 /60 /60 /24
year = day/365
month = day/30

# %%
print(year, month, day)
# Out:
# 51.652054794520545 628.4333333333333 18853.0

# %%
dt = pd.to_datetime(1628899200, unit = 's')
print(dt)
# Out:
# 2021-08-14 00:00:00

# %% [markdown]
# ## 날짜 변환

# %%
data = [
    {'시가': 100, '고가': 110, '저가': 90, '종가': 105},
    {'시가': 100, '고가': 112, '저가': 80, '종가':  95},
    {'시가':  99, '고가': 115, '저가': 70, '종가':  85},
    {'시가':  70, '고가':  80, '저가': 60, '종가':  75},
]

df = pd.DataFrame(data, index=['20200615', '20200616', '20200717', '20200718'])
df
# Out:
#            시가   고가  저가   종가
# 20200615  100  110  90  105
# 20200616  100  112  80   95
# 20200717   99  115  70   85
# 20200718   70   80  60   75

# %%
cond = df.index.str[:6] == "202006"
df.loc[cond]
# Out:
#            시가   고가  저가   종가
# 20200615  100  110  90  105
# 20200616  100  112  80   95

# %%
df.index = pd.to_datetime(df.index)
df.loc['2020-06']
# Out:
#              시가   고가  저가   종가
# 2020-06-15  100  110  90  105
# 2020-06-16  100  112  80   95

# %% [markdown]
# # KRX API 크롤링

# %%
! pip install pykrx -q

# %%
import pykrx
print(pykrx.__version__)
# Out:
# 1.0.48

# %%
from pykrx import stock

tickers = pykrx.stock.get_market_ticker_list(market = 'KOSDAQ')
print(len(tickers), tickers)
# Out:
# 1754 ['060310', '054620', '265520', '211270', '109960', '139050', '126600', '013720', '083790', '035760', '311690', '051500', '058820', '023460', '056730', '065770', '083660', '456440', '477760', '099520', '060900', '290120', '025440', '068790', '241520', '180400', '245620', '037370', '050120', '214270', '130500', '900290', '083450', '297890', '440290', '078150', '195940', '028300', '278650', '067630', '024850', '047920', '115450', '046210', '403870', '036640', '439730', '442770', '448760', '467930', '469480', '095340', '950170', '067290', '035900', '318000', '024840', '024120', '455250', '458320', '464680', '476470', '478390', '486630', '021320', '036670', '044180', '046440', '151860', '035600', '226360', '111870', '060720', '058400', '101000', '122450', '052900', '376190', '061970', '309960', '225190', '060370', '417200', '078020', '476080', '086960', '038340', '160550', '053290', '060250', '104200', '222160', '024940', '218410', '327260', '091340', '419530', '019550', '950110', '036120', '246960', '099220', '036540', '255220', '040610', '049470', '184230', '016250', '048550', '063440', '067160', '289080', '089230', '032540', '022220', '048770', '246690', '317240', '057030', '040300', '051390', '052220', '079940', '078890', '399720', '036620', '198440', '217730', '114190', '094480', '039240', '053950', '011040', '024910', '049720', '014570', '348150', '950190', '098460', '035290', '900280', '215000', '121440', '366030', '014200', '029480', '026910', '421800', '440790', '456490', '465320', '482520', '053270', '066620', '043650', '006050', '060480', '078130', '307750', '035080', '453450', '204020', '402490', '114450', '186230', '900070', '204620', '019660', '053260', '282720', '036190', '049080', '420770', '035460', '308100', '407400', '187790', '286750', '121600', '247660', '039860', '091970', '417010', '405920', '051490', '137080', '190510', '242040', '089600', '293580', '138610', '130580', '036800', '267320', '111710', '091590', '168330', '094860', '253590', '212560', '095660', '042420', '950220', '311390', '085910', '092730', '290660', '306620', '153460', '007390', '033640', '330860', '089140', '389650', '137940', '396270', '348210', '225570', '217270', '104620', '194700', '285490', '145170', '106520', '376930', '142280', '234690', '054050', '069140', '040160', '332290', '348340', '060260', '123840', '012340', '214870', '270870', '144960', '085670', '064260', '340360', '039560', '154040', '032190', '323350', '068240', '020400', '008830', '048470', '004780', '017650', '007720', '389260', '317850', '290670', '078140', '065150', '036480', '027830', '104040', '129920', '438220', '442310', '457390', '457630', '471050', '478780', '020180', '045390', '108380', '007680', '048910', '005710', '290380', '120240', '003310', '078600', '096350', '140520', '131220', '010170', '054670', '023910', '021040', '021045', '067080', '298540', '032860', '393890', '299170', '224060', '043090', '213420', '317330', '077360', '090410', '263600', '194480', '263800', '206560', '261200', '067990', '006620', '100130', '005160', '075970', '086450', '099410', '033500', '025950', '088130', '041930', '060380', '079960', '228340', '088910', '094170', '013120', '109860', '032960', '023790', '005290', '025900', '131970', '073190', '030350', '203650', '223250', '060570', '362990', '217620', '016670', '187870', '110990', '263690', '214680', '347850', '263720', '376300', '109740', '196490', '066900', '127120', '092070', '039840', '219550', '310870', '104460', '079810', '113810', '043360', '197140', '068930', '033130', '105740', '263020', '290550', '066670', '187220', '383930', '131180', '315640', '223310', '317120', '462510', '042510', '232680', '418420', '300120', '171120', '388790', '347700', '214260', '200350', '171010', '084650', '217500', '038390', '294140', '443250', '228670', '228850', '412350', '199550', '281740', '277810', '215100', '090360', '108490', '900260', '067730', '071280', '328130', '038060', '141080', '058470', '016100', '012700', '302550', '073 ...

# %%
tickers = pykrx.stock.get_market_ticker_list('20241010')
print(len(tickers), tickers)
# Out:
# 958 ['095570', '006840', '027410', '282330', '138930', '001460', '001465', '001040', '079160', '00104K', '000120', '011150', '011155', '001045', '097950', '097955', '000480', '000590', '012030', '016610', '005830', '000990', '139130', '001530', '000210', '000215', '375500', '37550L', '37550K', '007340', '004840', '155660', '069730', '017860', '017940', '365550', '383220', '007700', '114090', '078930', '006360', '001250', '007070', '078935', '012630', '039570', '089470', '294870', '009540', '267250', '267270', '443060', '071970', '010620', '322000', '042670', '267260', '329180', '097230', '014790', '003580', '204320', '060980', '011200', '035000', '002460', '487570', '298050', '003560', '175330', '234080', '001060', '001067', '001065', '096760', '105560', '432320', '002380', '344820', '009070', '009440', '119650', '092220', '003620', '016380', '001390', '033180', '015590', '001940', '025000', '092230', '000040', '044450', '030200', '033780', '058850', '058860', '093050', '003550', '034220', '051900', '051905', '373220', '003555', '032640', '011070', '066570', '066575', '037560', '051910', '051915', '079550', '006260', '010120', '000680', '229640', '108320', '001120', '108670', '108675', '383800', '38380K', '023150', '035420', '181710', '400760', '005940', '005945', '338100', '034310', '030190', '008260', '004250', '004255', '456040', '010060', '178920', '005490', '010950', '010955', '034120', '005090', '001380', '004060', '001770', '002360', '009160', '033530', '123700', '025530', '034730', '011790', '018670', '001740', '006120', '006125', '210980', '395400', '302440', '326030', '402340', '361610', '100090', '03473K', '096770', '096775', '475150', '001510', '001515', '285130', '28513K', '017670', '000660', '003570', '064960', '100840', '036530', '005610', '011810', '465770', '077970', '002820', '084870', '002710', '069260', '007980', '002900', '024070', '037270', '000500', '000860', '035250', '011420', '002100', '009450', '267290', '012320', '000050', '214390', '012610', '009140', '013580', '012200', '012205', '002140', '010130', '002240', '009290', '017040', '017900', '037710', '030610', '339770', '007690', '005320', '001140', '002720', '083420', '014530', '014280', '014285', '008870', '001570', '002990', '002995', '011780', '011785', '214330', '001210', '073240', '092440', '000270', '024110', '013700', '004540', '004545', '001260', '008350', '008355', '004270', '003920', '003925', '025860', '005720', '005725', '002350', '002355', '092790', '251270', '090350', '090355', '000320', '000325', '006280', '005250', '005257', '004370', '072710', '058730', '030210', '023590', '145210', '019680', '019685', '006370', '008060', '00806K', '353200', '35320K', '000490', '008110', '005750', '006570', '001680', '001685', '084690', '084695', '128820', '117580', '016710', '003540', '003547', '003545', '009190', '014160', '047040', '009320', '003090', '069620', '000430', '006340', '006345', '003220', '024890', '002880', '000300', '012800', '015230', '001070', '006650', '001440', '084010', '001790', '001795', '001130', '003490', '003495', '005880', '003830', '016090', '069460', '192080', '012510', '004830', '004835', '024900', '145720', '002150', '460850', '460860', '001230', '023450', '004140', '007590', '005960', '005965', '026960', '002210', '102260', '000640', '170900', '028100', '001520', '001527', '084670', '082640', '001525', '008970', '092780', '049770', '018500', '006040', '030720', '014820', '014825', '111380', '163560', '004890', '002690', '000020', '000150', '000157', '454910', '241560', '034020', '000155', '336260', '33626K', '33626L', '016740', '192650', '024090', '003160', '092200', '377190', '013570', '210540', '115390', '032350', '089860', '330590', '000400', '023530', '020150', '280360', '286940', '004000', '004990', '00499K', '005300', '005305', '011170', '071840', '027740', '357430', '001080', '088980', '094800', '138040', '090370', '118000', '017180', '009900', '012690', '005360', '070960', '009680', '009580', '009200', '0339 ...

# %%
tickers = stock.get_index_ticker_list("20241010")

for t in tickers:
  name = stock.get_index_ticker_name(t)
  print(t, name)
# Out:
# 1001 코스피
# 1002 코스피 대형주
# 1003 코스피 중형주
# 1004 코스피 소형주
# 1005 음식료품
# 1006 섬유의복
# 1007 종이목재
# 1008 화학
# 1009 의약품
# 1010 비금속광물
# 1011 철강금속
# 1012 기계
# 1013 전기전자
# 1014 의료정밀
# 1015 운수장비
# 1016 유통업
# 1017 전기가스업
# 1018 건설업
# 1019 운수창고업
# 1020 통신업
# 1021 금융업
# 1024 증권
# 1025 보험
# 1026 서비스업
# 1027 제조업
# 1028 코스피 200
# 1034 코스피 100
# 1035 코스피 50
# 1150 코스피 200 커뮤니케이션서비스
# 1151 코스피 200 건설
# 1152 코스피 200 중공업
# 1153 코스피 200 철강/소재
# 1154 코스피 200 에너지/화학
# 1155 코스피 200 정보기술
# 1156 코스피 200 금융
# 1157 코스피 200 생활소비재
# 1158 코스피 200 경기소비재
# 1159 코스피 200 산업재
# 1160 코스피 200 헬스케어
# 1167 코스피 200 중소형주
# 1182 코스피 200 초대형제외 지수
# 1224 코스피 200 비중상한 30%
# 1227 코스피 200 비중상한 25%
# 1232 코스피 200 비중상한 20%
# 1244 코스피200제외 코스피지수
# 1894 코스피 200 TOP 10

# %%
df = stock.get_market_ohlcv("20240401","20241010","005930")
print(df.head())
# Out:
#                시가     고가     저가     종가       거래량       등락률
# 날짜
# 2024-04-01  83200  83300  82000  82000  20116513 -0.485437
# 2024-04-02  82900  85000  82900  85000  37077944  3.658537
# 2024-04-03  84300  85000  83500  84100  30493347 -1.058824
# 2024-04-04  85200  85500  84300  85300  25248934  1.426873
# 2024-04-05  84500  85000  83800  84500  18883752 -0.937866

# %% [markdown]
# ### 과제
# - 난수 생성으로 sleep 시키기
# - 종목도 같이 출력

# %%
import time
import numpy as np
'''
for ticker in stock.get_market_ticker_list("20201010")[:5]:

  df = stock.get_market_ohlcv("20241009","20241010",ticker)
  df['종목명']
  randint = np.random.randint(1,10)
  time.sleep(randint)
  '''
# Out:
# '\nfor ticker in stock.get_market_ticker_list("20201010")[:5]:\n\n  df = stock.get_market_ohlcv("20241009","20241010",ticker)\n  df[\'종목명\']\n  randint = np.random.randint(1,10)\n  time.sleep(randint)\n  '

# %%
# 답안지

'''
import time
import random
for ticker in stock.get_market_ticker_list("20190225")[:5]:
    df = stock.get_market_ohlcv("20181210", "20181212", ticker)
    종목 = stock.get_market_ticker_name(ticker)
    df['종목명'] = 종목
    print(df.head())
    time.sleep(random.randint(10, 20))
'''
# Out:
# '\nimport time\nimport random\nfor ticker in stock.get_market_ticker_list("20190225")[:5]:\n    df = stock.get_market_ohlcv("20181210", "20181212", ticker)\n    종목 = stock.get_market_ticker_name(ticker)\n    df[\'종목명\'] = 종목\n    print(df.head())\n    time.sleep(random.randint(10, 20))\n'

# %% [markdown]
# # API 데이터 크롤링
#
# 1.   열린 데이터 광장
# 2.   공공데이터 포털

# %%
# 키, 데이터 url은 사이트에서 직접 따오기

SERVICE_KEY = '71527565663130313835635a4d5846'
url = f'http://openapi.seoul.go.kr:8088/{SERVICE_KEY}/json/tbLnOpendataRtmsV/1/5/'

print(url)
# Out:
# http://openapi.seoul.go.kr:8088/71527565663130313835635a4d5846/json/tbLnOpendataRtmsV/1/5/

# %%
import requests
import pandas as pd
import json

req = requests.get(url)
print(req)
# Out:
# <Response [200]>

# %%
type(req)
# Out:
# requests.models.Response

# %%
content = req.json()
content
# Out:
# {'tbLnOpendataRtmsV': {'list_total_count': 2622592,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'RCPT_YR': '2024',
#     'CGG_CD': '11350',
#     'CGG_NM': '노원구',
#     'STDG_CD': '10600',
#     'STDG_NM': '중계동',
#     'LOTNO_SE': '1',
#     'LOTNO_SE_NM': '대지',
#     'MNO': '0505',
#     'SNO': '0000',
#     'BLDG_NM': '롯데(505)',
#     'CTRT_DAY': '20241009',
#     'THING_AMT': '72000',
#     'ARCH_AREA': 72.49,
#     'LAND_AREA': 0.0,
#     'FLR': 14.0,
#     'RGHT_SE': '',
#     'RTRCN_DAY': '20241009',
#     'ARCH_YR': '1989',
#     'BLDG_USG': '아파트',
#     'DCLR_SE': '중개거래',
#     'OPBIZ_RESTAGNT_SGG_NM': '서울 노원구'},
#    {'RCPT_YR': '2024',
#     'CGG_CD': '11230',
#     'CGG_NM': '동대문구',
#     'STDG_CD': '10600',
#     'STDG_NM': '장안동',
#     'LOTNO_SE': '1',
#     'LOTNO_SE_NM': '대지',
#     'MNO': '0385',
#     'SNO': '0002',
#     'BLDG_NM': '리치',
#     'CTRT_DAY': '20241008',
#     'THING_AMT': '28100',
#     'ARCH_AREA': 75.48,
#     'LAND_AREA': 0.0,
#     'FLR': 3.0,
#     'RGHT_SE': '',
#     'RTRCN_DAY': '',
#     'ARCH_YR': '2008',
#     'BLDG_USG': '아파트',
#     'DCLR_SE': '직거래',
#     'OPBIZ_RESTAGNT_SGG_NM': ''},
#    {'RCPT_YR': '2024',
#     'CGG_CD': '11620',
#     'CGG_NM': '관악구',
#     'STDG_CD': '10100',
#     'STDG_NM': '봉천동',
#     'LOTNO_SE': '1',
#     'LOTNO_SE_NM': '대지',
#     'MNO': '0869',
#     'SNO': '0006',
#     'BLDG_NM': '서울대역 마에스트로',
#     'CTRT_DAY': '20241008',
#     'THING_AMT': '15000',
#     'ARCH_AREA': 20.5,
#     'LAND_AREA': 31.64,
#     'FLR': 10.0,
#     'RGHT_SE': '',
#     'RTRCN_DAY': '',
#     'ARCH_YR': '2012',
#     'BLDG_USG': '오피스텔',
#     'DCLR_SE': '중개거래',
#     'OPBIZ_RESTAGNT_SGG_NM': '서울 관악구'},
#    {'RCPT_YR': '2024',
#     'CGG_CD': '11740',
#     'CGG_NM': '강동구',
#     'STDG_CD': '10200',
#     'STDG_NM': '고덕동',
#     'LOTNO_SE': '1',
#     'LOTNO_SE_NM': '대지',
#     'MNO': '0486',
#     'SNO': '0000',
#     'BLDG_NM': '아남1',
#     'CTRT_DAY': '20241008',
#     'THING_AMT': '114000',
#     'ARCH_AREA': 84.91,
#     'LAND_AREA': 0.0,
#     'FLR': 10.0,
#     'RGHT_SE': '',
#     'RTRCN_DAY': '',
#     'ARCH_YR': '1996',
#     'BLDG_USG': '아파트',
#     'DCLR_SE': '중개거래',
#     'OPBIZ_RESTAGNT_SGG_NM': '서울 강동구'},
#    {'RCPT_YR': '2024',
#     'CGG_CD': '11530',
#     'CGG_NM': '구로구',
#     'STDG_CD': '10200',
#     'STDG_NM': '구로동',
#     'LOTNO_SE': '1',
#     'LOTNO_SE_NM': '대지',
#     'MNO': '1256',
#     'SNO': '0000',
#     'BLDG_NM': '구로현대',
#     'CTRT_DAY': '20241008',
#     'THING_AMT': '48000',
#     'ARCH_AREA': 56.49,
#     'LAND_AREA': 0.0,
#     'FLR': 5.0,
#     'RGHT_SE': '',
#     'RTRCN_DAY': '',
#     'ARCH_YR': '1992',
#     'BLDG_USG': '아파트',
#     'DCLR_SE': '중개거래',
#     'OPBIZ_RESTAGNT_SGG_NM': '서울 양천구'}]}}

# %%
res = content['tbLnOpendataRtmsV']['row']
len(res)
# Out:
# 500

# %%
pd.DataFrame(res)
# Out:
#     RCPT_YR CGG_CD CGG_NM STDG_CD STDG_NM LOTNO_SE LOTNO_SE_NM   MNO   SNO  \
# 0      2024  11350    노원구   10600     중계동        1          대지  0505  0000
# 1      2024  11230   동대문구   10600     장안동        1          대지  0385  0002
# 2      2024  11620    관악구   10100     봉천동        1          대지  0869  0006
# 3      2024  11740    강동구   10200     고덕동        1          대지  0486  0000
# 4      2024  11530    구로구   10200     구로동        1          대지  1256  0000
# ..      ...    ...    ...     ...     ...      ...         ...   ...   ...
# 495    2024  11215    광진구   10500     자양동        1          대지  0221  0008
# 496    2024  11380    은평구   10700     응암동        1          대지  0759  0000
# 497    2024  11410   서대문구   11900    북가좌동        1          대지  0369  0020
# 498    2024  11470    양천구   10300     신월동        1          대지  1076  0000
# 499    2024  11440    마포구   10400     도화동        1          대지  0559  0000
#
#             BLDG_NM  ... THING_AMT ARCH_AREA  LAND_AREA   FLR  RGHT_SE  \
# 0           롯데(505)  ...     72000     72.49       0.00  14.0
# 1                리치  ...     28100     75.48       0.00   3.0
# 2        서울대역 마에스트로  ...     15000     20.50      31.64  10.0
# 3               아남1  ...    114000     84.91       0.00  10.0
# 4              구로현대  ...     48000     56.49       0.00   5.0
# ..              ...  ...       ...       ...        ...   ...      ...
# 495           신세계빌라  ...     23000     26.66      14.00   4.0
# 496      백련산힐스테이트1차  ...     83000     84.21       0.00   2.0
# 497            미림주택  ...     68500     43.96      21.00   4.0
# 498  목동센트럴아이파크위브2단지  ...     74000     52.85       0.00   7.0
# 499         마포트라팰리스  ...     97000     80.30     103.52   6.0
#
#     RTRCN_DAY ARCH_YR BLDG_USG DCLR_SE OPBIZ_RESTAGNT_SGG_NM
# 0    20241009    1989      아파트    중개거래                서울 노원구
# 1                2008      아파트     직거래
# 2                2012     오피스텔    중개거래                서울 관악구
# 3                1996      아파트    중개거래                서울 강동구
# 4                1992      아파트    중개거래                서울 양천구
# ..        ...     ...      ...     ...                   ...
# 495              2002    연립다세대    중개거래                서울 광진구
# 496              2011      아파트    중개거래                서울 은평구
# 497              1999    연립다세대    중개거래                서울 은평구
# 498              2020      아파트    중개거래                서울 양천구
# 499              2006     오피스텔    중개거래                서울 마포구
#
# [500 rows x 21 columns]

# %% [markdown]
# ### 반복문을 써서 3000개까지의 데이터를 가져와보기.

# %%
import time
SERVICE_KEY = '71527565663130313835635a4d5846'
#url = f'http://openapi.seoul.go.kr:8088/{SERVICE_KEY}/json/tbLnOpendataRtmsV/{index_start}/{index_last}/'

complete_data = []
complete_data = pd.DataFrame(complete_data)
# 위  코드는 complete_data = None으로 대체가 가능하다.

start_time = time.time()

for idx in range(1,5001,1000):

  index_start = idx
  index_last = idx+999

  url = f'http://openapi.seoul.go.kr:8088/{SERVICE_KEY}/json/tbLnOpendataRtmsV/{index_start}/{index_last}/'
  content = requests.get(url).json()
  res = content['tbLnOpendataRtmsV']['row']
  res_df = pd.DataFrame(res)

  complete_data = pd.concat([complete_data, res_df], axis = 0)

end_time = time.time()
elapsed_time = end_time - start_time
print(f"반복문 실행 시간: {elapsed_time:.2f} 초")
# Out:
# 반복문 실행 시간: 84.26 초

# %%
complete_data.reset_index(drop = True)
complete_data
# Out:
#      RCPT_YR CGG_CD CGG_NM STDG_CD STDG_NM LOTNO_SE LOTNO_SE_NM   MNO   SNO  \
# 0       2024  11350    노원구   10600     중계동        1          대지  0505  0000
# 1       2024  11230   동대문구   10600     장안동        1          대지  0385  0002
# 2       2024  11620    관악구   10100     봉천동        1          대지  0869  0006
# 3       2024  11740    강동구   10200     고덕동        1          대지  0486  0000
# 4       2024  11530    구로구   10200     구로동        1          대지  1256  0000
# ...      ...    ...    ...     ...     ...      ...         ...   ...   ...
# 2995    2024  11260    중랑구   10400      묵동        1          대지  0233  0086
# 2996    2024  11560   영등포구   12600   양평동2가        1          대지  0045  0000
# 2997    2024  11590    동작구   10200     상도동        1          대지  0279  0496
# 2998    2024  11680    강남구   10700     신사동        1          대지  0607  0009
# 2999    2024  11200    성동구   11300     옥수동        1          대지  0528  0000
#
#               BLDG_NM  ... THING_AMT ARCH_AREA  LAND_AREA   FLR  RGHT_SE  \
# 0             롯데(505)  ...     72000     72.49       0.00  14.0
# 1                  리치  ...     28100     75.48       0.00   3.0
# 2          서울대역 마에스트로  ...     15000     20.50      31.64  10.0
# 3                 아남1  ...    114000     84.91       0.00  10.0
# 4                구로현대  ...     48000     56.49       0.00   5.0
# ...               ...  ...       ...       ...        ...   ...      ...
# 2995    골드스타빌(233-86)  ...     25000     26.11      18.00   5.0
# 2996              상록수  ...     60000     59.67       0.00  16.0
# 2997             하나빌라  ...     52000     56.04      33.00   3.0
# 2998     현대맨션(22,23동)  ...    220000    120.35     110.00   2.0
# 2999  옥수파크힐스101동~116동  ...    202000     84.51       0.00   4.0
#
#      RTRCN_DAY ARCH_YR BLDG_USG DCLR_SE OPBIZ_RESTAGNT_SGG_NM
# 0     20241009    1989      아파트    중개거래                서울 노원구
# 1                 2008      아파트     직거래
# 2                 2012     오피스텔    중개거래                서울 관악구
# 3                 1996      아파트    중개거래                서울 강동구
# 4                 1992      아파트    중개거래                서울 양천구
# ...        ...     ...      ...     ...                   ...
# 2995              2017    연립다세대    중개거래                서울 중랑구
# 2996              1999      아파트    중개거래               서울 영등포구
# 2997              2008    연립다세대    중개거래                서울 동작구
# 2998              1984    연립다세대    중개거래        서울 강남구, 서울 용산구
# 2999              2016      아파트    중개거래                서울 성동구
#
# [3000 rows x 21 columns]

# %%
'''
# 모범답안

import requests
import pandas as pd

KEY = '78577a466b6a686a3539434662496e'
result = None
for i in range(1, 4):
  url = f'http://openapi.seoul.go.kr:8088/{KEY}/json/tbLnOpendataRtmsV/{(i-1) * 1000 + 1}/{i*1000}/'
  print(url)
  req = requests.get(url)
  content = req.json()
  data = pd.DataFrame(content['tbLnOpendataRtmsV']['row'])
  result = pd.concat([result, data])

result.info()

'''

# %% [markdown]
# ## xml을 json대신 사용하면...?
# - 원리를 먼저 파악하자!

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

SERVICE_KEY = '71527565663130313835635a4d5846'
url = f'http://openapi.seoul.go.kr:8088/{SERVICE_KEY}/xml/tbLnOpendataRtmsV/1/5/2023/11500/강서구/'
req = requests.get(url)
req
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(req.content, "lxml") # html.parser
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <html>
#  <body>
#   <tblnopendatartmsv>
#    <list_total_count>
#     5095
#    </list_total_count>
#    <result>
#     <code>
#      INFO-000
#     </code>
#     <message>
#      정상 처리되었습니다
#     </message>
#    </result>
#    <row>
#     <rcpt_yr>
#      2023
#     </rcpt_yr>
#     <cgg_cd>
#      11500
#     </cgg_cd>
#     <cgg_nm>
#      강서구
#     </cgg_nm>
#     <stdg_cd>
#      10300
#     </stdg_cd>
#     <stdg_nm>
#      화곡동
#     </stdg_nm>
#     <lotno_se>
#      1
#     </lotno_se>
#     <lotno_se_nm>
#      대지
#     </lotno_se_nm>
#     <mno>
#      1081
#     </mno>
#     <sno>
#      0006
#     </sno>
#     <bldg_nm>
#      드림파크빌
#     </bldg_nm>
#     <ctrt_day>
#      20231230
#     </ctrt_day>
#     <thing_amt>
#      24000
#     </thing_amt>
#     <arch_area>
#      58.26
#     </arch_area>
#     <land_area>
#      33.280000
#     </land_area>
#     <flr>
#      5
#     </flr>
#     <rght_se>
#     </rght_se>
#     <rtrcn_day>
#     </rtrcn_day>
#     <arch_yr>
#      2011
#     </arch_yr>
#     <bldg_usg>
#      연립다세대
#     </bldg_usg>
#     <dclr_se>
#      중개거래
#     </dclr_se>
#     <opbiz_restagnt_sgg_nm>
#      서울 강서구
#     </opbiz_restagnt_sgg_nm>
#    </row>
#    <row>
#     <rcpt_yr>
#      2023
#     </rcpt_yr>
#     <cgg_cd>
#      11500
#     </cgg_cd>
#     <cgg_nm>
#      강서구
#     </cgg_nm>
#     <stdg_cd>
#      10300
#     </stdg_cd>
#     <stdg_nm>
#      화곡동
#     </stdg_nm>
#     <lotno_se>
#      1
#     </lotno_se>
#     <lotno_se_nm>
#      대지
#     </lotno_se_nm>
#     <mno>
#      0151
#     </mno>
#     <sno>
#      0008
#     </sno>
#     <bldg_nm>
#      힐타운(151-8)
#     </bldg_nm>
#     <ctrt_day>
#      20231229
#     </ctrt_day>
#     <thing_amt>
#      18000
#     </thing_amt>
#     <arch_area>
#      46.25
#     </arch_area>
#     <land_area>
#      22.820000
#     </land_area>
#     <flr>
#      3
#     </flr>
#     <rght_se>
#     </rght_se>
#     <rtrcn_day>
#     </rtrcn_day>
#     <arch_yr>
#      2002
#     </arch_yr>
#     <bldg_usg>
#      연립다세대
#     </bldg_usg>
#     <dclr_se>
#      중개거래
#     </dclr_se>
#     <opbiz_restagnt_sgg_nm>
#      서울 강서구
#     </opbiz_restagnt_sgg_nm>
#    </row>
#    <row>
#     <rcpt_yr>
#      2023
#     </rcpt_yr>
#     <cgg_cd>
#      11500
#     </cgg_cd>
#     <cgg_nm>
#      강서구
#     </cgg_nm>
#     <stdg_cd>
#      10300
#     </stdg_cd>
#     <stdg_nm>
#      화곡동
#     </stdg_nm>
#     <lotno_se>
#      1
#     </lotno_se>
#     <lotno_se_nm>
#      대지
#     </lotno_se_nm>
#     <mno>
#      0056
#     </mno>
#     <sno>
#      0594
#     </sno>
#     <bldg_nm>
#      파랑새빌라트(A동)
#     </bldg_nm>
#     <ctrt_day>
#      20231229
#     </ctrt_day>
#     <thing_amt>
#      24400
#     </thing_amt>
#     <arch_area>
#      73.13
#     </arch_area>
#     <land_area>
#      35.550000
#     </land_area>
#     <flr>
#      2
#     </flr>
#     <rght_se>
#     </rght_se>
#     <rtrcn_day>
#     </rtrcn_day>
#     <arch_yr>
#      2000
#     </arch_yr>
#     <bldg_usg>
#      연립다세대
#     </bldg_usg>
#     <dclr_se>
#      중개거래
#     </dclr_se>
#     <opbiz_restagnt_sgg_nm>
#      서울 강서구
#     </opbiz_restagnt_sgg_nm>
#    </row>
#    <row>
#     <rcpt_yr>
#      2023
#     </rcpt_yr>
#     <cgg_cd>
#      11500
#     </cgg_cd>
#     <cgg_nm>
#      강서구
#     </cgg_nm>
#     <stdg_cd>
#      10400
#     </stdg_cd>
#     <stdg_nm>
#      가양동
#     </stdg_nm>
#     <lotno_se>
#      1
#     </lotno_se>
#     <lotno_se_nm>
#      대지
#     </lotno_se_nm>
#     <mno>
#      1460
#     </mno>
#     <sno>
#      0000
#     </sno>
#     <bldg_nm>
#      한강타운
#     </bldg_nm>
#     <ctrt_day>
#      20231229
#     </ctrt_day>
#     <thing_amt>
#      105500
#     </thing_amt>
#     <arch_area>
#      84.99
#     </arch_area>
#     <land_area>
#      0.000000
#     </land_area>
#     <flr>
#      11
#     </flr>
#     <rght_se>
#     </rght_se>
#     <rtrcn_day>
#     </rtrcn_day>
#     <arch_yr>
#      1993
#     </arch_yr>
#     <bldg_usg>
#      아파트
#     </bldg_usg>
#     <dclr_se>
#      중개거래
#     </dclr_se>
#     <opbiz_restagnt_sgg_nm>
#      서울 강서구, 서울 마포구
#     </opbiz_restagnt_sgg_nm>
#    </row>
#    <row>
#     <rcpt_yr>
#      2023
#     </rcpt_yr>
#     <cgg_cd>
#      11500
#     </cgg_cd>
#     <cgg_nm>
#      강서구
#     </cgg_nm>
#     <stdg_cd>
#      10900
#     </stdg_cd>
#     <stdg_nm>
#      방화동
#     </stdg_nm>
#     <lotno_se>
#      1
#     </lotno_se>
#     <lotno_se_nm>
#      대지
#     </lotno_se_nm>
#     <mno>
#      0612
#     </mno>
#     <sno>
#      0000
#     </sno>
#     <bldg_nm>
#      마곡킹덤펜타리움
#     </bldg_nm>
#     <ctrt_day>
#      20231229
#     </ctrt_day>
#     <thing_amt>
#      28000
#     </thing_amt>
#     <arch_area>
#      23.53
#     </arch_area>
#     <land_area>
#      7.940000
#     </land_area>
#     <flr>
#      10
#     </flr>
#     <rght_se>
#     </rght_se>
#     <rtrcn_day>
#     </rtrcn_day>
#     <arch_yr>
#      2021
#     </arch_yr>
#     <bldg_usg>
#      연립다세대
#     </bldg_usg>
#     <dclr_se>
#      중개거래
#     </dclr_se>
#     <opbiz_restagnt_sgg_nm>
#      서울 강서구
#     </opbiz_restagnt_sgg_nm>
#    </row>
#   </tblnopendatartmsv>
#  </body>
# </html>
# <ipython-input-156-67afbbe320e3>:1: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(req.content, "lxml") # html.parser

# %%
years = soup.find_all('rcpt_yr')         # 접수년월
CGG_CDs = soup.find_all('cgg_cd')
len(years), len(CGG_CDs)
# Out:
# (5, 5)

# %%
years = soup.find_all('rcpt_yr')         # 접수년월
CGG_CDs = soup.find_all('cgg_cd')

year_list           = []
sgg_cd_list         = []

for year, cgg_cd in zip(years, CGG_CDs):
  year_list.append(year.get_text())
  sgg_cd_list.append(cgg_cd.get_text())

df = pd.DataFrame({
    "rcpt_yr": year_list,
    "cgg_cd" : sgg_cd_list
})

df
# Out:
#   rcpt_yr cgg_cd
# 0    2023  11500
# 1    2023  11500
# 2    2023  11500
# 3    2023  11500
# 4    2023  11500

# %%
SERVICE_KEY = '71527565663130313835635a4d5846'
url = f'http://apis.data.go.kr/1613000/RTMSDataSvcAptTrade/getRTMSDataSvcAptTrade'
req = requests.get(url)
req
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(req.content, "lxml") # html.parser
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <openapi_serviceresponse>
#    <cmmmsgheader>
#     <errmsg>
#      SERVICE ERROR
#     </errmsg>
#     <returnauthmsg>
#      SERVICE_KEY_IS_NOT_REGISTERED_ERROR
#     </returnauthmsg>
#     <returnreasoncode>
#      30
#     </returnreasoncode>
#    </cmmmsgheader>
#   </openapi_serviceresponse>
#  </body>
# </html>

# %% [markdown]
# ### 사전 제작 코드 활용

# %%
#!pip install xmltodict -qq

# %%
import requests
import json
import xmltodict
import pandas as pd
serviceKey = 'HRYWiTp0KEDDEYYyUQV9msoe%2B2YK6PPbdhjgspJt5p%2F3YskNrgY3nyiVew4VxbwA6m4F5kRUXNZaEa2Z0kPFVg%3D%3D'
pageNo = 1 # 페이지 번호
numOfRows = 500 # 한 페이지 결과수
LAWD_CD = 11500 # 지역코드
DEAL_YMD = 202101 # 계약월
url = f'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?serviceKey={serviceKey}&pageNo={pageNo}&numOfRows={numOfRows}&LAWD_CD={LAWD_CD}&DEAL_YMD={DEAL_YMD}'
req = requests.get(url)
req
# Out:
# <Response [200]>

# %%
req.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>99</resultCode><resultMsg>SERVICE KEY IS NOT REGISTERED ERROR.</resultMsg></header></response>'

# %%
contents = xmltodict.parse(req.text)
contents
# Out:
# {'response': {'header': {'resultCode': '99',
#    'resultMsg': 'SERVICE KEY IS NOT REGISTERED ERROR.'}}}

# %%
data = pd.DataFrame(contents['response']['body']['items']['item'])
data.head()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Columns: 1000 entries, 0 to 999
# dtypes: object(1000)
# memory usage: 23.6+ KB

# %%
data.describe()
# Out:
#                                                       0    \
# count                                                   3
# unique                                                  3
# top     {'RCPT_YR': '2024', 'CGG_CD': '11350', 'CGG_NM...
# freq                                                    1
#
#                                                       1    \
# count                                                   3
# unique                                                  3
# top     {'RCPT_YR': '2024', 'CGG_CD': '11230', 'CGG_NM...
# freq                                                    1
#
#                                                       2    \
# count                                                   3
# unique                                                  3
# top     {'RCPT_YR': '2024', 'CGG_CD': '11620', 'CGG_NM...
# freq                                                    1
#
#                                                       3    \
# count                                                   3
# unique                                                  3
# top     {'RCPT_YR': '2024', 'CGG_CD': '11740', 'CGG_NM...
# freq                                                    1
#
#                                                       4    \
# count                                                   3
# unique                                                  3
# top     {'RCPT_YR': '2024', 'CGG_CD': '11530', 'CGG_NM...
# freq                                                    1
#
#                                                       5    \
# count                                                   3
# unique                                                  3
# top     {'RCPT_YR': '2024', 'CGG_CD': '11260', 'CGG_NM...
# freq                                                    1
#
#                                                       6    \
# count                                                   3
# unique                                                  3
# top     {'RCPT_YR': '2024', 'CGG_CD': '11620', 'CGG_NM...
# freq                                                    1
#
#                                                       7    \
# count                                                   3
# unique                                                  3
# top     {'RCPT_YR': '2024', 'CGG_CD': '11545', 'CGG_NM...
# freq                                                    1
#
#                                                       8    \
# count                                                   3
# unique                                                  3
# top     {'RCPT_YR': '2024', 'CGG_CD': '11290', 'CGG_NM...
# freq                                                    1
#
#                                                       9    ...  \
# count                                                   3  ...
# unique                                                  3  ...
# top     {'RCPT_YR': '2024', 'CGG_CD': '11230', 'CGG_NM...  ...
# freq                                                    1  ...
#
#                                                       990  \
# count                                                   3
# unique                                                  3
# top     {'RCPT_YR': '2024', 'CGG_CD': '11230', 'CGG_NM...
# freq                                                    1
#
#                                                       991  \
# count                                                   3
# unique                                                  3
# top     {'RCPT_YR': '2024', 'CGG_CD': '11230', 'CGG_NM...
# freq                                                    1
#
#                                                       992  \
# count                                                   3
# unique                                                  3
# top     {'RCPT_YR': '2024', 'CGG_CD': '11230', 'CGG_NM...
# freq                                                    1
#
#                                                       993  \
# count                                                   3
# unique                                                  3
# top     {'RCPT_YR': '2024', 'CGG_CD': '11230', 'CGG_NM...
# freq                                                    1
#
#                                                       994  \
# count                                                   3
# unique                                                  3
# top     {'RCPT_YR': '2024', 'CGG_CD': '11230', 'CGG_NM...
# freq                                                    1
#
#                                                       995  \
# count                                                   3
# unique                                                  3
# top     {'RCPT_YR': '2024', 'CGG_CD': '11230', 'CGG_NM...
# freq                                                    1
#
#                                                       996  \
# count                                                   3
# unique                                                  3
# top     {'RCPT_YR': '2024', 'CGG_CD': '11230', 'CGG_NM...
# freq                                                    1
#
#                                                       997  \
# count                                                   3
# unique                                                  3
# top     {'RCPT_YR': '2024', 'CGG_CD': '11230', 'CGG_NM...
# freq                                                    1
#
#                                                       998  \
# count                                                   3
# unique                                                  3
# top     {'RCPT_YR': '2024', 'CGG_CD': '11230', 'CGG_NM...
# freq                                                    1
#
#                                                       999
# count                                                   3
# unique                                                  3
# top     {'RCPT_YR': '2024', 'CGG_CD': '11350', 'CGG_NM...
# freq                                                    1
#
# [4 rows x 1000 columns]

# %% [markdown]
# # 개인공부_오픈API데이터 가져오기
#
# - 전국 휴게소 푸드메뉴 현황 조회 서비스
# - https://data.ex.co.kr/openapi/basicinfo/openApiInfoM?apiId=0502
# - ***맛있겠다*...**

# %%
import requests
import json
import xmltodict
import pandas as pd

SERVICE_KEY = '0170719555'
NumRows = 500
PageNum = 1
url = f"https://data.ex.co.kr/openapi/restinfo/restBestfoodList?key={SERVICE_KEY}&type=json&numOfRows={NumRows}&pageNo={PageNum}"

content2 = requests.get(url).json()

# %%
data = pd.DataFrame(content2['list'])
data.columns
# Out:
# Index(['pageNo', 'numOfRows', 'stdRestCd', 'stdRestNm', 'lsttmAltrUser',
#        'lsttmAltrDttm', 'svarAddr', 'routeCd', 'routeNm', 'seq', 'foodNm',
#        'foodCost', 'etc', 'recommendyn', 'seasonMenu', 'bestfoodyn',
#        'premiumyn', 'app', 'restCd', 'foodMaterial', 'lastId', 'lastDtime'],
#       dtype='object')

# %%
# drop unusing columns
no_need_cols = ['pageNo', 'numOfRows', 'lsttmAltrUser', 'lsttmAltrDttm', 'app', 'lastId','lastDtime']
data2 = data.copy()
data2 = data2.drop(columns=no_need_cols)
data2.tail(1)
# Out:
#    stdRestCd    stdRestNm         svarAddr routeCd routeNm    seq    foodNm  \
# 98    000001  서울만남(부산)휴게소  서울 서초구 원지동10-16    0010     경부선  13956  소고기짬뽕곱배기
#
#    foodCost   etc recommendyn seasonMenu bestfoodyn premiumyn   restCd  \
# 98    14000  None           N          4          N         N  S000001
#
#    foodMaterial
# 98         None

# %% [markdown]
# ## 반복문을 통해 큰 데이터프레임으로 만들기

# %%
import time

Base_dat = None
no_need_cols = ['pageNo', 'numOfRows', 'lsttmAltrUser', 'lsttmAltrDttm', 'app', 'lastId','lastDtime', 'foodMaterial']

start_time = time.time()

for i in range(1, 10):
  SERVICE_KEY = '0170719555'
  NumRows = 100
  PageNum = i
  url = f"https://data.ex.co.kr/openapi/restinfo/restBestfoodList?key={SERVICE_KEY}&type=json&numOfRows={NumRows}&pageNo={PageNum}"

  content = requests.get(url).json()
  data = pd.DataFrame(content['list'])

  data = data.drop(columns = no_need_cols)
  Base_dat = pd.concat([Base_dat, data], axis = 0)

end_time = time.time()
total_time = end_time - start_time
print(f"반복문 실행 시간: {total_time:.2f} 초")

Base_dat = Base_dat.reset_index(drop = True)
# Out:
# 반복문 실행 시간: 8.69 초

# %%
Base_dat.head(1)
# Out:
#   stdRestCd    stdRestNm         svarAddr routeCd routeNm  seq  foodNm  \
# 0    000001  서울만남(부산)휴게소  서울 서초구 원지동10-16    0010     경부선  272  농심어묵우동
#
#   foodCost                                                etc recommendyn  \
# 0     7000  부산어묵꼬치를 첨가하여 우동만의 시원하고 담백한 맛에 어묵의 식감과 향을 함께 즐길...           N
#
#   seasonMenu bestfoodyn premiumyn   restCd
# 0          4          N         N  S000001
