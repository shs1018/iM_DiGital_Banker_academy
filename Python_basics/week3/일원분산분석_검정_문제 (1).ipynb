# %% [markdown]
# ## 문제
# - 주어진 데이터(data/iris.csv)는 붓꽃의 종, 꽃받침 길이와 너비, 꽃잎의 길이와 너비를 기록한 데이터이다. 이를 이용하여 붓꽃의 종(species)에 따라 꽃받침의 너비(sepal_width) 차이 나는지 일원분산분석을 통해 답을 한다.
# - 가설검정
#     + 귀무가설 : mu1 = mu2 = mu3
#     + 대립가설 : not H0
# - 단, 주어진 데이터가 정규성과 등분산성을 만족한다고 가정한다.
# - 문제 1: versicolor 종의 평균 꽃받침 너비를 구하시오. (반올림하여 소숫점 둘째 자리까지 계산)
# - 문제 2: 위의 가설을 검정하기 위한 검정통계량을 구하시오. (반올림하여 소숫점 둘째 자리까지 계산)
# - 문제 3: 위의 통계량에 대한 p-값을 구하고 (반올림하여 소숫점 넷째 자리까지 계산), 유의수준 0.05하에서 가설검정의 결과를 채택/기각 중 하나로 선택하시오.

# %% [markdown]
# ## 데이터 불러오기

# %%
import seaborn as sns
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 문제 1
# - versicolor 종의 평균 꽃받침 너비를 구하시오. (반올림하여 소숫점 둘째 자리까지 계산)

# %%
df_sp = iris.groupby('species').mean()
mu_versi = df_sp.loc['versicolor','sepal_width'].round(2)
mu_versi
# Out:
# 2.77

# %% [markdown]
# ## 문제 2
# - 위의 가설을 검정하기 위한 검정통계량을 구하시오. (반올림하여 소숫점 둘째 자리까지 계산)
# - statsmodels와 pingouin 둘다 사용 또는 둘 중 하나만 사용

# %%
# !pip install pingouin -qq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.4/204.4 kB 5.4 MB/s eta 0:00:00
# ...

# %%
import pingouin as pg

res = pg.anova(data=iris, dv='sepal_width', between='species')
res['F']
# Out:
# 0    49.16004
# Name: F, dtype: float64

# %% [markdown]
# ## 문제 3.
# - 위의 통계량에 대한 p-값을 구하고 (반올림하여 소숫점 넷째 자리까지 계산), 유의수준 0.05하에서 가설검정의 결과를 채택/기각 중 하나로 선택하시오.

# %%
p = float(res['p-unc'].round(4))
print(p)

if p < 0.05:
  print('null hypothesis denied')
else:
  print('null hypothesis accepted')
# Out:
# 0.0
# null hypothesis denied
# <ipython-input-24-a8da0b38ad44>:1: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   p = float(res['p-unc'].round(4))

# %%
# 코드

# %% [markdown]
# ## 사후검정

# %%
pg.pairwise_tukey(data=iris, dv='sepal_width', between='species')
# Out:
#             A           B  mean(A)  mean(B)   diff        se         T  \
# 0      setosa  versicolor    3.428    2.770  0.658  0.067938  9.685366
# 1      setosa   virginica    3.428    2.974  0.454  0.067938  6.682608
# 2  versicolor   virginica    2.770    2.974 -0.204  0.067938 -3.002758
#
#         p-tukey    hedges
# 0  2.153833e-14  1.876486
# 1  1.360732e-09  1.280172
# 2  8.780206e-03 -0.636233
