# %% [markdown]
# ## 데이터 불러오기
# - Google Drive에서 데이터를 불러오는 코드

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 기술통계량

# %%
import pandas as pd # 데이터 가공 및 데이터 불러오기
import seaborn as sns # 시각화, 통계 시각화를 구현할 수 있는 라이브러리

tips = sns.load_dataset("tips") # 데이터 불러오기
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns

ax = sns.histplot(tips["total_bill"])
ax.set(xlabel ="Total Bill", ylabel = "Frequency")

sns.despine()

# %% [markdown]
# ### The mean, median, trimmed mean

# %%
import numpy as np
np.mean(tips["total_bill"])
tips["total_bill"].mean()
# Out:
# 19.78594262295082

# %%
np.median(tips["total_bill"])
# Out:
# 17.795

# %% [markdown]
# - Trimmed Mean : 이상값이 존재하는 경우 일부 비율 제거 후 평균

# %%
from scipy import stats
stats.trim_mean(tips["total_bill"], 0.2)
# Out:
# 18.23216216216216

# %% [markdown]
# ### Mode
# - 명목척도 데이터셋에는 value_counts() 사용

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
tips['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
tips['day'].value_counts().max()
# Out:
# 87

# %%
tips['day'].value_counts().min()
# Out:
# 19

# %%
tips['day'].mode() # 최빈값의 값을 표시 할 때,
# Out:
# 0    Sat
# Name: day, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %% [markdown]
# ### IQR
# - 50% 범위

# %%
import numpy as np
np.quantile(tips["total_bill"], 0.5)
# Out:
# 17.795

# %%
tips["total_bill"].median()
# Out:
# 17.795

# %%
np.quantile(tips["total_bill"], [0.25, .75])
# Out:
# array([13.3475, 24.1275])

# %%
from scipy import stats
stats.iqr(tips["total_bill"])
# Out:
# 10.779999999999998

# %% [markdown]
# ### 첨도와 왜도

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
url = "/content/drive/MyDrive/Colab Notebooks/iM_alphaco/data_set/skewdata.csv"
df_skew = pd.read_csv(url)
df_skew
# Out:
#         Unnamed: 0     Skew    Values
# 0                1  NegSkew  0.923942
# 1                2  NegSkew  0.881371
# 2                3  NegSkew  0.727231
# 3                4  NegSkew  0.772731
# 4                5  NegSkew  0.978233
# ...            ...      ...       ...
# 299995      299996  PosSkew  0.254564
# 299996      299997  PosSkew  0.094585
# 299997      299998  PosSkew  0.192435
# 299998      299999  PosSkew  0.149764
# 299999      300000  PosSkew  0.106467
#
# [300000 rows x 3 columns]

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

ax1 = sns.histplot(data = df_skew.loc[df_skew['Skew'] == 'PosSkew'], x = 'Values', binwidth = 0.02, ax=axes[0])
ax2 = sns.histplot(data = df_skew.loc[df_skew['Skew'] == 'NoSkew'], x = 'Values', binwidth = 0.02, ax=axes[1])
ax3 = sns.histplot(data = df_skew.loc[df_skew['Skew'] == 'NegSkew'], x = 'Values', binwidth = 0.02, ax=axes[2])

axes[0].set_title("Positive Skew")
axes[1].set_title("No Skew")
axes[2].set_title("Negative Skew")

for ax in axes:
    ax.set(xticklabels=[])
    ax.set(yticklabels=[])
    ax.set(xlabel=None)
    ax.set(ylabel=None)
    ax.tick_params(bottom=False)
    ax.tick_params(left=False)

sns.despine()

# %%
tips["total_bill"].skew(axis = 0, skipna = True) # 왜도
# Out:
# 1.1332130376158205

# %%
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# load some data

file1 = 'https://raw.githubusercontent.com/ethanweed/pythonbook/main/Data/kurtosisdata.csv'
file2 = 'https://raw.githubusercontent.com/ethanweed/pythonbook/main/Data/kurtosisdata_ncurve.csv'

df_kurtosis = pd.read_csv(file1)

# define a normal distribution with a mean of 0 and a standard deviation of 1
mu = 0
sigma = 1
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
y = stats.norm.pdf(x, mu, sigma)

platykurtic = df_kurtosis.loc[df_kurtosis["Kurtosis"] == "Platykurtic"]
mesokurtic = df_kurtosis.loc[df_kurtosis["Kurtosis"] == "Mesokurtic"]
leptokurtic = df_kurtosis.loc[df_kurtosis["Kurtosis"] == "Leptokurtic"]

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

ax1 = sns.histplot(data=platykurtic, x = "Values", binwidth=.5, ax=axes[0])
ax2 = sns.histplot(data=mesokurtic, x = "Values", binwidth=.5,  ax=axes[1])
ax3 = sns.histplot(data=leptokurtic, x = "Values", binwidth=.5, ax=axes[2])

sns.lineplot(x=x,y=y*40000, ax=ax1, color='black')
sns.lineplot(x=x,y=y*40000, ax=ax2, color='black')
sns.lineplot(x=x,y=y*40000, ax=ax3, color='black')


axes[0].set_title("Platykurtic\n\"too flat\"")
axes[1].set_title("Mesokurtic\n\"just right\"")
axes[2].set_title("Leptokurtic\n\"too pointy\"")

for ax in axes:
    ax.set_xlim(-6,6)
    ax.set_ylim(0,25000)
    ax.set(xticklabels=[])
    ax.set(yticklabels=[])
    ax.set(xlabel=None)
    ax.set(ylabel=None)
    ax.tick_params(bottom=False)
    ax.tick_params(left=False)


sns.despine()

# %%
print("Pandas: ", tips["total_bill"].kurtosis())
print("Pandas Fischer bias: ",stats.kurtosis(tips["total_bill"], fisher=True, bias=False))
# Out:
# Pandas:  1.2184840156638854
# Pandas Fischer bias:  1.2184840156638854

# %% [markdown]
# ### 표준편차
# - 평균절대편차 구하기

# %%
from statistics import mean

X = [56, 31, 56, 8, 32]             # 1. 데이터
X_bar = mean(X)                     # 2. 평균
AD = []                             # 3. 각 측정값이 평균으로부터 얼마만큼 떨어져 있는지 구하기 (절대값)
for i in X:                         #
    AD.append(abs((i-X_bar)))
ADD = mean(AD)                      # 4. 절대값들의 평균
print(ADD)
# Out:
# 15.52

# %%
import pandas as pd

data = pd.DataFrame({"X": [56, 31, 56, 8, 32]})
X_mean = data['X'].mean()
data['diff'] = abs(data['X'] - X_mean)
data['diff'].mean()
# Out:
# 15.52

# %% [markdown]
# - 분산 구하기

# %%
data = pd.DataFrame({"X": [56, 31, 56, 8, 32]})
X_mean = data['X'].mean()

v = []
for n in data['X']:
    squared_error = (n-X_mean)**2
    v.append(squared_error)
var = np.mean(v)
var
# Out:
# 324.64

# %%
data = pd.DataFrame({"X": [56, 31, 56, 8, 32]})
X_mean = data['X'].mean()
data['squared_diff'] = (data['X'] - X_mean) ** 2
data['squared_diff'].mean()
# Out:
# 324.64

# %%
# 분산 구하는 메서드
np.var(data['X'])
# Out:
# 324.64

# %% [markdown]
# - 표준편차

# %%
data = pd.DataFrame({"X": [56, 31, 56, 8, 32]})
X_mean = data['X'].mean()
data['squared_diff'] = (data['X'] - X_mean) ** 2
np.sqrt(data['squared_diff'].mean())
# Out:
# 18.017769007288333

# %%
np.std(data['X'])
# Out:
# 18.017769007288333

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ## 추정
# - 모수 추정의 의미
# - 조사를 여러번 할수록 정확도는 높아질 수 밖에 없음
#   + 모수에 가까워질 수 밖에 없음

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats as stats
import math

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

mu = 100
sigma = 15
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
y = stats.norm.pdf(x, mu, sigma)
ax0 = sns.lineplot(x=x,y=y, ax=axes[0])

IQ = np.random.normal(loc=100,scale=15,size=100)
ax1 = sns.histplot(IQ, ax=axes[1])

IQ = np.random.normal(loc=100,scale=15,size=10000)
ax2 = sns.histplot(IQ,ax=axes[2])

labels = ['A', 'B', 'C']
titles = ['Normal Distribution', '100 samples', '10,000 samples']
for i,ax in enumerate(axes):
    ax.set_title(titles[i])
    ax.text(-0.1, 1.15, labels[i], transform=ax.transAxes,
      fontsize=16, fontweight='bold', va='top', ha='right')
    ax.set(xticklabels=[])
    ax.set(yticklabels=[])
    ax.set(ylabel=None)
    ax.tick_params(axis='both',
                   which='both',
                   bottom=False,
                   left=False)

sns.despine()

# %% [markdown]
# ### 중심 극한 정리

# %%
import numpy as np

IQ_1 = np.random.normal(loc=100,scale=15,size=5).astype(int)
print("시물레이션 데이터: ", IQ_1)
print("시물레이션 데이터의 평균: ", np.mean(IQ_1))
# Out:
# 시물레이션 데이터:  [ 98  75 104  86  92]
# 시물레이션 데이터의 평균:  91.0

# %%
IQ_2 = np.random.normal(loc=100,scale=15,size=5).astype(int)
print("시물레이션 데이터: ", IQ_2)
print("시물레이션 데이터의 평균: ", np.mean(IQ_2))
# Out:
# 시물레이션 데이터:  [122  99 110  98 103]
# 시물레이션 데이터의 평균:  106.4

# %%
import pandas as pd
df = pd.DataFrame(
    {'Person 1': np.random.normal(loc=100,scale=15,size=10).astype(int),
     'Person 2': np.random.normal(loc=100,scale=15,size=10).astype(int),
     'Person 3': np.random.normal(loc=100,scale=15,size=10).astype(int),
     'Person 4': np.random.normal(loc=100,scale=15,size=10).astype(int),
     'Person 5': np.random.normal(loc=100,scale=15,size=10).astype(int),
    })

df['Sample Mean']=df.mean(axis=1)
df.index=['Replication '+str(i+1) for i in range(df.shape[0])]
df
# Out:
#                 Person 1  Person 2  Person 3  Person 4  Person 5  Sample Mean
# Replication 1        103       128        91       128        98        109.6
# Replication 2         92        99        73        91       114         93.8
# Replication 3         74       137       101        81        92         97.0
# Replication 4         92       106       112       106       112        105.6
# Replication 5         94       116       104       112       107        106.6
# Replication 6        117        82       101       129        85        102.8
# Replication 7        108        85        89       109        74         93.0
# Replication 8        108        83        83        92        75         88.2
# Replication 9        104       103       112       108       132        111.8
# Replication 10        77        85        98       101        87         89.6

# %% [markdown]
# ### 표본 평균의 표본 분포
# - sampling distribution of the mean
# - Sample을 구한 후, 평균을 구하면 하나의 정규분포를 이루게 됨

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
import numpy as np
import statistics
import math

mu = 100
sigma = 15
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
y = stats.norm.pdf(x, mu, sigma)

sample_means = []
for i in range(1,10000):
    sample_mean = statistics.mean(np.random.normal(loc=100,scale=15,size=5).astype(int))
    sample_means.append(sample_mean)


fig, ax = plt.subplots()
sns.histplot(sample_means, ax=ax)
ax2 = ax.twinx()
sns.lineplot(x=x,y=y, ax=ax2, color='black')

axes=[ax, ax2]
for ax in axes:
    ax.set(yticklabels=[])
    ax.set(ylabel=None)
    ax.set(xlabel='IQ Score')
    ax.tick_params(axis='both',
                    which='both',
                    left=False,
                    right=False)
    ax.spines[['right', 'top']].set_visible(False)

# %% [markdown]
# ### 구간 추정의 의미
# - 구간 추정을 구하는 것 아래 코드와 같이 쉽게 구할 수 있음

# %%
import numpy as np
import scipy.stats as st

data = [12, 12, 13, 13, 15, 16, 17, 22, 23, 25, 26, 27, 28, 28, 29]
st.t.interval(confidence=0.95, df=len(data)-1, loc=np.mean(data), scale=st.sem(data))
# Out:
# (16.75776979778498, 24.042230202215016)

# %% [markdown]
# - 아래 그래프의 의미
# - 모수 추정시, 50번 수행하면 표본의 평균이 모수의 구간에 들어가지 못할 가능성이 5%는 존재한다.
#   + 틀릴 가능성이 5% 존재한다. 95% 신뢰구간
#   + 선거의 예, 신뢰구간 +/- 3%
#     * A 후보 : 45.5% --> 42.5
#     * B 후보 : 33.8% --> 36.8

# %%
from scipy.stats import t, sem
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import random

#set a random number generator for reproducibility
rng = np.random.default_rng(42)

#define simulation parameters
n_experiments = 100
ns = [10, 25]

#prepare labels for the figure panels
labels = ['A', 'B']

# prepare the figure, with two subplots
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=False, sharex=False)
fig.suptitle('Simulated IQ Data')

# simulate the two sets of experiments, and make the figures.
for f, ax in enumerate(axes):

    # collect the upper and lower CI bounds, and the sample means for each experiment
    uppers = []
    lowers = []
    sample_means = []

    # for the x-axis, make a list of incrementing numbers
    x = list(range(0,n_experiments))

    # generate simulated data for each experiment by sampling from a normal distribution
    # with the parameters defined above
    # store the sample means and CI bounds in the lists above
    for i in x:
        simdata = rng.normal(loc=100,scale=15,size=ns[f]).astype(int)
        sample_means.append(statistics.mean(simdata))
        ci = t.interval(confidence=.95, df=len(simdata)-1, loc=np.mean(simdata), scale=sem(simdata))
        uppers.append(ci[1])
        lowers.append(ci[0])


    # find the experiments where the CI did not capture the population mean
    # and mark these with red. Color the others blue.
    too_high = [x[s] for s, val in enumerate(lowers) if val > 100]
    too_low = [x[s] for s, val in enumerate(uppers) if val < 100]
    no_mean = too_high + too_low
    highlight = ['blue']*n_experiments
    for s, val in enumerate(no_mean):
        highlight[val] = 'red'

    # plot the data and format the plots
    sns.pointplot(x=x, y=sample_means, linestyle='none', ax=ax)
    ax.set_ylim([70,130])
    ax.vlines(x=x, ymin=lowers, ymax=uppers, color = highlight)
    ax.axhline(y=100, linestyle = "dashed")
    ax.set_title("Sample Size = " + str(ns[f]))
    ax.set(ylabel=None)
    ax.text(-0.1, 1, labels[f], transform=ax.transAxes,fontsize=16, fontweight='bold', va='top', ha='right')
    ax.tick_params(left=False)
    ax.spines[['top', 'right']].set_visible(False)
    ax.tick_params(axis='both',
                    which='both',
                    left=False,
                    right=False,
                    bottom=False,
                    labelbottom=False)

# %% [markdown]
# ### 구간추정 계산

# %%
import seaborn as sns
data = range(1,25)

# Method 1:
import numpy as np
import scipy.stats as st
from scipy.stats import t

ci_1 = t.interval(confidence=0.95,
                  df=len(data)-1,
                  loc=np.mean(data),
                  scale=sem(data))


# Method 2:
# https://www.statsmodels.org/stable/index.html
import statsmodels.stats.api as sms
ci_2 = sms.DescrStatsW(data).tconfint_mean()

# Compare the methods
print("Method 1: ", ci_1)
print("Method 2: ", ci_2)
# Out:
# Method 1:  (9.514149929408497, 15.485850070591503)
# Method 2:  (9.514149929408497, 15.485850070591503)

# %%
import seaborn as sns
tips = sns.load_dataset("tips")

# Method 1:
import numpy as np
import scipy.stats as st
from scipy.stats import t

ci_1 = t.interval(confidence=0.95,
                  df=len(tips['total_bill'])-1,
                  loc=np.mean(tips['total_bill']),
                  scale=sem(tips['total_bill']))


# Method 2:
import statsmodels.stats.api as sms
ci_2 = sms.DescrStatsW(tips['total_bill']).tconfint_mean()

# Compare the methods
print("Method 1: ", ci_1)
print("Method 2: ", ci_2)
# Out:
# Method 1:  (18.663331704358473, 20.908553541543167)
# Method 2:  (18.66333170435847, 20.908553541543164)

# %% [markdown]
# ### 신뢰도 시각화

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset("tips")

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

sns.pointplot(x="time", y="total_bill", hue="smoker", data=tips, ax=axes[0])
sns.pointplot(x="time", y="total_bill", hue="smoker",  errorbar=('ci', 40), data=tips, ax=axes[1])
axes[0].set_title("95% Confidence Interval")
axes[1].set_title("40% Confidence Interval")
sns.despine()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
tips = sns.load_dataset("tips")

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

sns.regplot(x="size", y="tip", data=tips, ax=axes[0])
sns.regplot(x="size", y="tip", data=tips, x_estimator=np.mean, ax=axes[1])

sns.despine()

# %% [markdown]
# ## 평균비교
# - z-검정 vs t검정
# - z검정은 현실에서 사용할 가능성은 없음
#   + why? z검정은 모수의 분산과 표편 등을 이미 알고 있어야 사용가능하기 때문.
#   + 통계 수업에서 t-test 수업을 위한 중간 과정으로 많이 사용됨

# %% [markdown]
# ### z-검정
# - 모수의 평균이 67.5인 것으로 가정한다.
#   + 간단한 질문, 모수의 평균이 67.5인데 왜 검정이 필요한가요? 이미 모수의 평균을 알고 있는데요!!
# - https://ethanweed.github.io/pythonbook/05.02-ttest.html

# %%
import pandas as pd
df = pd.DataFrame({"grades" : [50, 60, 60, 64, 66, 66, 67, 69, 70, 74, 76, 76, 77, 79, 79, 79, 81, 82, 82, 89]})
df.head()
# Out:
#    grades
# 0      50
# 1      60
# 2      60
# 3      64
# 4      66

# %%
df['grades'].mean()
# Out:
# 72.3

# %% [markdown]
# - 모수의 표준편차는 9.5로 알고 있다.
#
# - H0 : mu = mubar(72.5)
#
#   H1 : mu != mubar(72.5)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats as stats

mu = 67.5
sigma = 9.5
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
y = 100* stats.norm.pdf(x, mu, sigma)

fig, ax = plt.subplots()
ax1 = sns.histplot(df['grades'])
#등급별로 나눈 히스토그램

ax2 = sns.lineplot(x=x,y=y, color='red')
#전체 모집단 기준의 CI 그래프

plt.ylim(bottom=-1)

#외부 margin 안보이게 처리.
ax1.set_frame_on(False)
ax1.axes.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# #### 가설 설정
# - 귀무가설 : 모수의 평균은 67.5일 것이다.
# - 대립가설 : 표본의 평균은 67.5가 아닐 것이다.
# - 조건 : 모수의 표준편차는 9.5라는 것을 알고 있다.
#   + 모수의 표준편차를 알고 있고, 평균도 알고 있는데, 왜 굳이 검정을 하느냐!!

# %% [markdown]
# #### z-score 구하기
# - 공식에 의거하여 z-score를 구한다.

# %%
import math
sample_mean = df['grades'].mean()
sd_true = 9.5
mu_null = 67.5
N = len(df['grades'])
sem_true = sd_true / math.sqrt(N)
z_score = (sample_mean - mu_null) / sem_true
z_score # 통계량
# Out:
# 2.259605535157681

# %%
from statistics import NormalDist

lower_area = NormalDist().cdf(-z_score)
upper_area = lower_area
p_value = lower_area + upper_area
p_value
# Out:
# 0.023845743764939864

# %% [markdown]
# ### t-검정 (One-Sample t-test)
# - z검정과의 차이점
#   + 자유도 N-1
#   + 모집단의 표준편차를 모름
# - 가설설정
#   + 귀무가설 : 표본의 평균은 모평균과 같다.
#   + 대립가설 : 표본의 평균은 모평균과 다르다.

# %%
N = len(df['grades'])
degfree = N-1
sample_mean = df['grades'].mean()
print('Sample mean:', sample_mean)
print('Degrees of freedom:', degfree)
# Out:
# Sample mean: 72.3
# Degrees of freedom: 19

# %%
from scipy.stats import ttest_1samp
t, p = ttest_1samp(a = df['grades'], popmean = 67.5)
t, p
# Out:
# (2.25471286700693, 0.03614521878144544)

# %%
from scipy import stats

confidence_level = 0.95
degrees_freedom = len(df['grades'])-1
sample_mean = df['grades'].mean()
sample_standard_error = df['grades'].sem()

confidence_interval = stats.t.interval(confidence_level, degrees_freedom, sample_mean, sample_standard_error) #t-test의 신뢰구간 구하기
confidence_interval
# Out:
# (67.84421513791415, 76.75578486208585)

# %%
ci = stats.ttest_1samp(df['grades'], popmean=mu_null).confidence_interval()
ci
# Out:
# ConfidenceInterval(low=67.84421513791415, high=76.75578486208585)

# %% [markdown]
# ### t-검정 (Independent t-test)
# - 두가지 확인
#   + 각 데이터의 정규성 검정
#   + 두 그룹간의 등분산성 검정

# %%
import seaborn as sns
import pandas as pd

tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## 시각화
# - 범주가 2개인 것을 찾아야 한다. -> sex, smoker, time 확인
# - 시나리오
#   + 성별에 따른 평균차이
#   + 흡연 여부에 따른 평균차이
#   + 시간대에 따른 평균차이
# - 데이터가 연속형, 히스토그램을 그려야 한다.
# - tip을 그린다.

# %%
tips.apply(lambda x : x.unique())
# Out:
# total_bill    [16.99, 10.34, 21.01, 23.68, 24.59, 25.29, 8.7...
# tip           [1.01, 1.66, 3.5, 3.31, 3.61, 4.71, 2.0, 3.12,...
# sex           ['Female', 'Male']
# Categories (2, object): ['M...
# smoker        ['No', 'Yes']
# Categories (2, object): ['Yes', ...
# day           ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, o...
# time          ['Dinner', 'Lunch']
# Categories (2, object): ['...
# size                                         [2, 3, 4, 1, 6, 5]
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sex = tips.loc[tips['sex'] == "Male"]['tip']
sex2 = tips.loc[tips['sex'] != "Male"]['tip']

smoker = tips.loc[tips['smoker'] == "No"]['tip']
smoker2 = tips.loc[tips['smoker'] != "No"]['tip']

time = tips.loc[tips['time'] == "Dinner"]['tip']
time2 = tips.loc[tips['time'] != "Dinner"]['tip']

# %%
fix, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
sns.histplot(smoker, ax = ax[0])
sns.histplot(smoker2, ax = ax[1], color = 'orange')
plt.show()

# %%
#데이터의 표준화

smoker_norm = smoker.apply(lambda x: (x - smoker.mean()) / smoker.std())
smoker2_norm = smoker2.apply(lambda x: (x - smoker2.mean()) / smoker2.std())

fix, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))
sns.histplot(smoker_norm, ax = ax[0])
sns.histplot(smoker2_norm, ax = ax[1], color = 'orange')
plt.show()

# %%
from scipy.stats import ttest_1samp

mu = tips["tip"].mean()

t,p = ttest_1samp(smoker, popmean = mu)
t,p
# Out:
# (-0.057322624946865984, 0.954364486577824)

# %%
from scipy.stats import ttest_1samp

t, p = ttest_1samp(a = df['grades'], popmean = 67.5)
t, p

#귀무가설 기각 (검정통계량이 기각역 안에 있으며, p값이 유의수준 0.05보다 작음.)
# Out:
# (2.25471286700693, 0.03614521878144544)

# %%
ttest_1samp(a = df['grades'], popmean = 67.5).confidence_interval()
# Out:
# ConfidenceInterval(low=67.84421513791415, high=76.75578486208585)

# %%
tips_summary = pd.DataFrame(
    {'Smoker': ['Smoker_Yes','Smoker_No'],
     'mean': [tips.loc[tips['smoker'] == 'Yes']['tip'].mean().round(2),
             tips.loc[tips['smoker'] == 'No']['tip'].mean().round(2)],
     'std dev': [tips.loc[tips['smoker'] == 'Yes']['tip'].std(),
                tips.loc[tips['smoker'] == 'No']['tip'].std()],
     'N': [len(tips.loc[tips['smoker'] == 'Yes']),
           len(tips.loc[tips['smoker'] == 'No'])]
    })

tips_summary
# Out:
#        Smoker  mean   std dev    N
# 0  Smoker_Yes  3.01  1.401468   93
# 1   Smoker_No  2.99  1.377190  151

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(1, 2, figsize=(15, 5))
smoker_yes = pd.DataFrame(tips.loc[tips['smoker'] == 'Yes']['tip'])
smoker_no = pd.DataFrame(tips.loc[tips['smoker'] == 'No']['tip'])

sns.histplot(smoker_yes['tip'], ax = axes[0])
sns.histplot(smoker_no['tip'], ax = axes[1])

axes[0].set_title('Smoker Yes')
axes[1].set_title('Smoker No')

sns.despine()

plt.show()

#이 데이터를 표준화 시키면 좀 정규분포 같아질까?

# %% [markdown]
# #### Shapiro-Wilk 검정
# - 가설검정
#   + 귀무가설 : 데이터는 정규분포이다.
#   + 대립가설 : 데이터는 정규분포를 이루고 있지 않다.

# %%
# 정규분포를 이루는 데이터
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from scipy.stats import probplot
from scipy.stats import shapiro

np.random.seed(42)
normal_data = np.random.normal(size=100)

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

probplot(normal_data, dist="norm", plot = axes[0]);
sns.histplot(normal_data, axes=axes[1]);

titles = ['QQ plot', 'Histogram']
for i, ax in enumerate(axes):
    ax.spines[['right', 'top']].set_visible(False)
    ax.set_title(titles[i])

plt.show()
shapiro(normal_data)
# Out:
# ShapiroResult(statistic=0.9898833815158516, pvalue=0.6551676754214818)

# %%
# 정규분포를 이루지 못하는 데이터
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from scipy.stats import probplot
from scipy.stats import shapiro

np.random.seed(42)
normal_data = smoker_yes['tip']

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

probplot(normal_data, dist="norm", plot = axes[0]);
sns.histplot(normal_data, axes=axes[1]);

titles = ['QQ plot', 'Histogram']
for i, ax in enumerate(axes):
    ax.spines[['right', 'top']].set_visible(False)
    ax.set_title(titles[i])

plt.show()
shapiro(normal_data)
# Out:
# ShapiroResult(statistic=0.8788249661085323, pvalue=3.612564299352561e-07)

# %% [markdown]
# - 여기서 중요한 것, 그럼에도 불구하고 중심극한정리에 의해 정규성이 있다고 봄

# %%
tips['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %% [markdown]
# #### levene 검정 - 등분산성 검정
# - 가설검정
#   + 귀무가설 : 두 집단의 분산이 같다
#   + 대립가설 : 두 집단의 분산이 다르다

# %%
from scipy.stats import levene
stat, p = levene(smoker_yes['tip'], smoker_no['tip'])

print('Levene statistic:', stat)
print('p-value:', p)
# Out:
# Levene statistic: 0.02051159105706963
# p-value: 0.8862366542563406

# %% [markdown]
# - 시각화

# %%
fig, axes = plt.subplots(1, 1)
sns.pointplot(x = 'smoker', y = 'tip', data = tips)
sns.despine()

# %%
from scipy import stats

t,p = stats.levene(smoker, smoker2)
t,p #귀무가설이 매우 강력하게 채택될 증거가 있다. 따라서 두 데이터의 분산은 같다.
# Out:
# (0.02051159105706963, 0.8862366542563406)

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

sns.boxplot(x = 'smoker', y = 'tip', data = tips, ax = ax[0])
sns.boxplot(x = 'day', y = 'tip', data = tips, ax = ax[1])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# #### 가설검정
# - 귀무가설 : 두 그룹의 평균은 같다
# - 대립가설 : 두 그룹의 평균은 다르다

# %%
from scipy import stats
t_stat, p_val = stats.ttest_ind(smoker_yes['tip'], smoker_no['tip'], equal_var=True)

# Output the results
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: 0.09222805186888201
# P-value: 0.9265931522244976

# %% [markdown]
# ### t-검정 (Paired t-test)
# - 가상 테이블 생성
#
# - 절차
#   + 정규성 검정
#   + 귀무가설: 데이터는 정규분포를 따른다.
#   + 대립가설: Not H0
#   + 단, 표본이 30개 이상이면 CLT덕분에 검증할 필요가 없다.
#   + 여기서의 데이터는 Diff값을 의미한다.

# %%
import pandas as pd
import numpy as np

np.random.seed(42)

exam1_scores = np.random.uniform(50, 100, 20)
exam2_scores = exam1_scores + np.random.normal(0, 10, 20)

df = pd.DataFrame({
    'Student_ID': range(1, 21),
    'Exam1_Score': exam1_scores,
    'Exam2_Score': exam2_scores
})

df['Exam1_Score'] = df['Exam1_Score'].astype('int64')
df['Exam2_Score'] = df['Exam2_Score'].astype('int64')
df['diff'] = df['Exam2_Score'] - df['Exam1_Score']

df.head(3)
# Out:
#    Student_ID  Exam1_Score  Exam2_Score  diff
# 0           1           68           58   -10
# 1           2           97          100     3
# 2           3           86           77    -9

# %%
df.shape
# CLT를 만족하지 못한다 -> 정규성 검정을 먼저 진행해야 한다!!
# Out:
# (20, 4)

# %% [markdown]
# #### Shapiro-Wilk 검정
# - 가설검정
#   + 귀무가설 : 데이터는 정규분포이다.
#   + 대립가설 : 데이터는 정규분포를 이루고 있지 않다.
# - 여기에서의 데이터는 diff 컬럼을 의미

# %%
np.random.seed(42)
normal_data = df['diff']

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

probplot(normal_data, dist="norm", plot = axes[0]);
sns.histplot(normal_data, axes=axes[1]);

titles = ['QQ plot', 'Histogram']
for i, ax in enumerate(axes):
    ax.spines[['right', 'top']].set_visible(False)
    ax.set_title(titles[i])

plt.show()
shapiro(normal_data)

# p값이 0.14 - 귀무가설을 채택한다.
# Out:
# ShapiroResult(statistic=0.9267928086509175, pvalue=0.13394043618879037)

# %% [markdown]
# #### 가설검정
# - 귀무가설 : After/Before 평균 점수의 차이는 0이다
# - 대립가설 : After/Before 평균 점수의 차이는 0이 아니다

# %%
from scipy import stats

t, p = stats.ttest_rel(df['Exam1_Score'], df['Exam2_Score'])
print(t, p)

# 귀무가설 채택 - 교육이 유의미하지 않다.
# Out:
# 1.343652804294727 0.19488870621876497

# %%
from scipy.stats import shapiro, ttest_rel

differences = df['Exam2_Score'] - df['Exam1_Score']
shapiro_stat, shapiro_p = shapiro(differences)

if shapiro_p > 0.05:
    t_stat, p_val = ttest_rel(df['Exam1_Score'], df['Exam2_Score'])
else:
    t_stat, p_val = None, None

shapiro_stat, shapiro_p, t_stat, p_val
# Out:
# (0.9267928086509175,
#  0.13394043618879037,
#  1.343652804294727,
#  0.19488870621876497)

# %%
# Creating a difference plot using the object-oriented approach with fig, ax
fig, ax = plt.subplots(figsize=(10, 6))

# Plotting the differences
ax.bar(df['Student_ID'], df['diff'], color='lightgreen')

# Adding labels and title using the object-oriented approach
ax.set_title('Difference in Scores Between Exam 1 and Exam 2')
ax.set_xlabel('Student ID')
ax.set_ylabel('Score Difference (Exam 2 - Exam 1)')
ax.axhline(0, color='gray', linewidth=0.8)  # Add a line at zero for reference
ax.set_xticks(df['Student_ID'])

# Display the plot with grid
ax.grid(axis='y')

plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

sns.pointplot(data=df.loc[:, ['Student_ID', 'Exam1_Score', 'Exam2_Score']].set_index("Student_ID"), ax = ax1)
sns.scatterplot(data = df, x='Exam1_Score', y='Exam2_Score', ax = ax2)

ax2.plot(ax2.get_xlim(), ax2.get_ylim(), ls="--", c=".3")

#ax1.set_ylim(40,80)
#ax1.set_xlim(40,80)
#ax1.set_ylim(40,80)

sns.histplot(data = df, x='diff')

ax1.title.set_text('A')
ax2.title.set_text('B')
ax3.title.set_text('C')

sns.despine()

plt.show()

# %% [markdown]
# # 분산분석(ANOVA)
# - 데이터 불러오기
# - t검정을 이미 알고 있다고 가정함.
# - 회귀분석과 그 원리가 유사하다.

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips["day"].value_counts() #팁을 어느 날에 평균적으로 가장 많이 주는가? -> 3개 이상의 그룹 내에서.
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %% [markdown]
# ## Pingouin

# %%
# pingiuin 사용해서 ANOVA하기
! pip install pingouin -qq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.4/204.4 kB 7.1 MB/s eta 0:00:00

# %%
import pingouin as pg

# Load an example dataset comparing pain threshold as a function of hair color
df = pg.read_dataset('anova')

# 1. This is a between subject design, so the first step is to test for equality of variances 등분산성 검정
pg.homoscedasticity(data=df, dv='Pain threshold', group='Hair color')
# Out:
#                W      pval  equal_var
# levene  0.392743  0.760016       True

# %%
# 2. If the groups have equal variances, we can use a regular one-way ANOVA
pg.anova(data=df, dv='Pain threshold', between='Hair color')
# Out:
#        Source  ddof1  ddof2         F     p-unc       np2
# 0  Hair color      3     15  6.791407  0.004114  0.575962

# %%
# 3. If there is a main effect, we can proceed to post-hoc Tukey test
pg.pairwise_tukey(data=df, dv='Pain threshold', between='Hair color')
# Out:
#                A               B  mean(A)  mean(B)  diff        se         T  \
# 0     Dark Blond   Dark Brunette     51.2     37.4  13.8  5.168623  2.669957
# 1     Dark Blond     Light Blond     51.2     59.2  -8.0  5.168623 -1.547801
# 2     Dark Blond  Light Brunette     51.2     42.5   8.7  5.482153  1.586968
# 3  Dark Brunette     Light Blond     37.4     59.2 -21.8  5.168623 -4.217758
# 4  Dark Brunette  Light Brunette     37.4     42.5  -5.1  5.482153 -0.930291
# 5    Light Blond  Light Brunette     59.2     42.5  16.7  5.482153  3.046249
#
#     p-tukey    hedges
# 0  0.074068  1.413596
# 1  0.435577 -0.810661
# 2  0.414728  0.982361
# 3  0.003708 -2.336811
# 4  0.789321 -0.626769
# 5  0.036647  2.015280

# %%
df.head()
# Out:
#    Subject   Hair color  Pain threshold
# 0        1  Light Blond              62
# 1        2  Light Blond              60
# 2        3  Light Blond              71
# 3        4  Light Blond              55
# 4        5  Light Blond              48

# %% [markdown]
# ## tips 데이터에 적용하기
# - H0: mu.sun = mu.sat = mu.thur
# - H1L not H0

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 다시 tips 데이터로 돌아가자.

tips2 = tips.loc[:, ['tip', 'day']].loc(axis=0)[tips['day'].isin(['Sun', 'Sat', 'Thur'])].reset_index()
tips2.head()
# Out:
#    index   tip  day
# 0      0  1.01  Sun
# 1      1  1.66  Sun
# 2      2  3.50  Sun
# 3      3  3.31  Sun
# 4      4  3.61  Sun

# %%
# 등분산성 검정
pg.homoscedasticity(data=tips2, dv='tip', group='day')
# Out:
#                W     pval  equal_var
# levene  0.452896  0.63637       True

# %%
# one-way ANOVA
pg.anova(data=tips2, dv='tip', between='day')
# Out:
#   Source  ddof1  ddof2         F     p-unc       np2
# 0    day      2    222  2.056236  0.130364  0.018188

# %%
#투키 검정
pg.pairwise_tukey(data=tips2, dv='tip', between='day')
# Out:
#       A    B   mean(A)   mean(B)      diff        se         T   p-tukey  \
# 0  Thur  Sat  2.771452  2.993103 -0.221652  0.233179 -0.950565  0.608894
# 1  Thur  Sun  2.771452  3.255132 -0.483680  0.240098 -2.014510  0.111077
# 2   Sat  Sun  2.993103  3.255132 -0.262028  0.220282 -1.189512  0.460663
#
#      hedges
# 0 -0.148857
# 1 -0.388762
# 2 -0.178644

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/iM_alphaco/data_set/anova.csv")
df.head()
# Out:
#    Subject   Hair color  Pain threshold
# 0        1  Light Blond              62
# 1        2  Light Blond              60
# 2        3  Light Blond              71
# 3        4  Light Blond              55
# 4        5  Light Blond              48

# %%
df.groupby('Hair color')['Pain threshold'].agg(['mean', 'std'])
# Out:
#                 mean       std
# Hair color
# Dark Blond      51.2  9.284396
# Dark Brunette   37.4  8.324662
# Light Blond     59.2  8.526429
# Light Brunette  42.5  5.446712

# %%
fig = sns.pointplot(x='Hair color', y = 'Pain threshold', data = df)
sns.despine()

# %% [markdown]
# #### Shapiro-Wilk 검정
# - 가설검정
#   + 귀무가설 : 데이터는 정규분포이다.
#   + 대립가설 : 데이터는 정규분포를 이루고 있지 않다.
# - 여기에서의 데이터는 각 그룹의 데이터를 의미

# %%
stat, p = shapiro(df[df['Hair color'] == 'Light Blond']['Pain threshold'])
print('Shapiro-Wilk Test for Light Blond:', p)
# Out:
# Shapiro-Wilk Test for Light Blond: 0.9831813867288481

# %%
stat, p = shapiro(df[df['Hair color'] == 'Dark Blond']['Pain threshold'])
print('Shapiro-Wilk Test for Light Blond:', p)
# Out:
# Shapiro-Wilk Test for Light Blond: 0.664456894876551

# %%
stat, p = shapiro(df[df['Hair color'] == 'Light Brunette']['Pain threshold'])
print('Shapiro-Wilk Test for Light Blond:', p)
# Out:
# Shapiro-Wilk Test for Light Blond: 0.5979735301441645

# %%
stat, p = shapiro(df[df['Hair color'] == 'Dark Brunette']['Pain threshold'])
print('Shapiro-Wilk Test for Light Blond:', p)
# Out:
# Shapiro-Wilk Test for Light Blond: 0.324129063473281

# %% [markdown]
# #### levene 검정

# %%
stat, p = levene(df[df['Hair color'] == 'Light Blond']['Pain threshold'],
                 df[df['Hair color'] == 'Dark Blond']['Pain threshold'],
                 df[df['Hair color'] == 'Light Brunette']['Pain threshold'],
                 df[df['Hair color'] == 'Dark Brunette']['Pain threshold'])
print('Levene’s Test:', p)

# %% [markdown]
# #### 가설검정

# %%
import pandas as pd
from scipy.stats import shapiro, levene, f_oneway
import statsmodels.api as sm
from statsmodels.formula.api import ols

f_stat, p_value = f_oneway(df[df['Hair color'] == 'Light Blond']['Pain threshold'],
                 df[df['Hair color'] == 'Dark Blond']['Pain threshold'],
                 df[df['Hair color'] == 'Light Brunette']['Pain threshold'],
                 df[df['Hair color'] == 'Dark Brunette']['Pain threshold'])
print('F-Statistic:', f_stat, 'P-value:', p_value)

# %%
model = ols('Q("Pain threshold") ~ C(Q("Hair color"))', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)

# %% [markdown]
# #### 잔차의 정규성 검정

# %%
import seaborn as sns
from scipy.stats import shapiro

res = model.resid
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

probplot(res, dist="norm", plot = axes[0]);
sns.histplot(res, axes=axes[1]);

titles = ['QQ plot', 'Histogram']
for i, ax in enumerate(axes):
    ax.spines[['right', 'top']].set_visible(False)
    ax.set_title(titles[i])

plt.show()
shapiro(res)

# %% [markdown]
# #### 사후검정
# - 귀무가설을 기각할 때만 사후검정 실시

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import statsmodels.api as sm

tukey_results = pairwise_tukeyhsd(endog=df['Pain threshold'],    # Data
                                  groups=df['Hair color'],      # Groups
                                  alpha=0.05)                   # Significance level

# Print results
print(tukey_results)

# %%
fig = sns.pointplot(x='Hair color', y = 'Pain threshold', data = df)
sns.despine()

# %% [markdown]
# ## pingouin
# - 실무에서 쓰는 걸 강력 추천
# - 링크 : https://pingouin-stats.org/build/html/index.html

# %%
# !pip install pingouin

# %%
import pingouin
pingouin.__version__

# %%
import pingouin as pg

# Load an example dataset comparing pain threshold as a function of hair color
df = pg.read_dataset('anova')

# 1. This is a between subject design, so the first step is to test for equality of variances
pg.homoscedasticity(data=df, dv='Pain threshold', group='Hair color')

# %%
# 2. If the groups have equal variances, we can use a regular one-way ANOVA
pg.anova(data=df, dv='Pain threshold', between='Hair color')

# %%
# 3. If there is a main effect, we can proceed to post-hoc Tukey test
pg.pairwise_tukey(data=df, dv='Pain threshold', between='Hair color')

# %% [markdown]
# # 가설검정
# - One-sample t-test (일표본)    |
# - Paired t-test (대응표본)      |
# - independent t-test (독립표본) |
# - 정규성 검정                   |
# - 등분산성 검정                 |

# %%
import pingouin as pg

df = pg.read_dataset('anova')

# 등분산성 검정
pg.homoscedasticity(data=tips, dv='tip', group='size')

pg.welch_anova(data=tips, dv='tip', between='size')

result = pg.pairwise_gameshowell(data=tips, dv='tip', between='size')
result['가설검정결과'] = result['pval'].apply(lambda p : '귀무가설 기각' if p < 0.05 else '귀무가설 채택')

def make_pretty(s):
    color = 'background-color: red' if s['가설검정결과'] == '귀무가설 기각' else 'background-color: green'
    return [color] * len(s)

styler_res = result.style.apply(make_pretty, axis = 1)
styler_res
# Out:
# <style type="text/css">
# #T_5d60d_row0_col0, #T_5d60d_row0_col1, #T_5d60d_row0_col2, #T_5d60d_row0_col3, #T_5d60d_row0_col4, #T_5d60d_row0_col5, #T_5d60d_row0_col6, #T_5d60d_row0_col7, #T_5d60d_row0_col8, #T_5d60d_row0_col9, #T_5d60d_row0_col10, #T_5d60d_row3_col0, #T_5d60d_row3_col1, #T_5d60d_row3_col2, #T_5d60d_row3_col3, #T_5d60d_row3_col4, #T_5d60d_row3_col5, #T_5d60d_row3_col6, #T_5d60d_row3_col7, #T_5d60d_row3_col8, #T_5d60d_row3_col9, #T_5d60d_row3_col10, #T_5d60d_row7_col0, #T_5d60d_row7_col1, #T_5d60d_row7_col2, #T_5d60d_row7_col3, #T_5d60d_row7_col4, #T_5d60d_row7_col5, #T_5d60d_row7_col6, #T_5d60d_row7_col7, #T_5d60d_row7_col8, #T_5d60d_row7_col9, #T_5d60d_row7_col10, #T_5d60d_row8_col0, #T_5d60d_row8_col1, #T_5d60d_row8_col2, #T_5d60d_row8_col3, #T_5d60d_row8_col4, #T_5d60d_row8_col5, #T_5d60d_row8_col6, #T_5d60d_row8_col7, #T_5d60d_row8_col8, #T_5d60d_row8_col9, #T_5d60d_row8_col10, #T_5d60d_row9_col0, #T_5d60d_row9_col1, #T_5d60d_row9_col2, #T_5d60d_row9_col3, #T_5d60d_row9_col4, #T_5d60d_row9_col5, #T_5d60d_row9_col6, #T_5d60d_row9_col7, #T_5d60d_row9_col8, #T_5d60d_row9_col9, #T_5d60d_row9_col10, #T_5d60d_row10_col0, #T_5d60d_row10_col1, #T_5d60d_row10_col2, #T_5d60d_row10_col3, #T_5d60d_row10_col4, #T_5d60d_row10_col5, #T_5d60d_row10_col6, #T_5d60d_row10_col7, #T_5d60d_row10_col8, #T_5d60d_row10_col9, #T_5d60d_row10_col10, #T_5d60d_row11_col0, #T_5d60d_row11_col1, #T_5d60d_row11_col2, #T_5d60d_row11_col3, #T_5d60d_row11_col4, #T_5d60d_row11_col5, #T_5d60d_row11_col6, #T_5d60d_row11_col7, #T_5d60d_row11_col8, #T_5d60d_row11_col9, #T_5d60d_row11_col10, #T_5d60d_row12_col0, #T_5d60d_row12_col1, #T_5d60d_row12_col2, #T_5d60d_row12_col3, #T_5d60d_row12_col4, #T_5d60d_row12_col5, #T_5d60d_row12_col6, #T_5d60d_row12_col7, #T_5d60d_row12_col8, #T_5d60d_row12_col9, #T_5d60d_row12_col10, #T_5d60d_row13_col0, #T_5d60d_row13_col1, #T_5d60d_row13_col2, #T_5d60d_row13_col3, #T_5d60d_row13_col4, #T_5d60d_row13_col5, #T_5d60d_row13_col6, #T_5d60d_row13_col7, #T_5d60d_row13_col8, #T_5d60d_row13_col9, #T_5d60d_row13_col10, #T_5d60d_row14_col0, #T_5d60d_row14_col1, #T_5d60d_row14_col2, #T_5d60d_row14_col3, #T_5d60d_row14_col4, #T_5d60d_row14_col5, #T_5d60d_row14_col6, #T_5d60d_row14_col7, #T_5d60d_row14_col8, #T_5d60d_row14_col9, #T_5d60d_row14_col10 {
#   background-color: green;
# }
# #T_5d60d_row1_col0, #T_5d60d_row1_col1, #T_5d60d_row1_col2, #T_5d60d_row1_col3, #T_5d60d_row1_col4, #T_5d60d_row1_col5, #T_5d60d_row1_col6, #T_5d60d_row1_col7, #T_5d60d_row1_col8, #T_5d60d_row1_col9, #T_5d60d_row1_col10, #T_5d60d_row2_col0, #T_5d60d_row2_col1, #T_5d60d_row2_col2, #T_5d60d_row2_col3, #T_5d60d_row2_col4, #T_5d60d_row2_col5, #T_5d60d_row2_col6, #T_5d60d_row2_col7, #T_5d60d_row2_col8, #T_5d60d_row2_col9, #T_5d60d_row2_col10, #T_5d60d_row4_col0, #T_5d60d_row4_col1, #T_5d60d_row4_col2, #T_5d60d_row4_col3, #T_5d60d_row4_col4, #T_5d60d_row4_col5, #T_5d60d_row4_col6, #T_5d60d_row4_col7, #T_5d60d_row4_col8, #T_5d60d_row4_col9, #T_5d60d_row4_col10, #T_5d60d_row5_col0, #T_5d60d_row5_col1, #T_5d60d_row5_col2, #T_5d60d_row5_col3, #T_5d60d_row5_col4, #T_5d60d_row5_col5, #T_5d60d_row5_col6, #T_5d60d_row5_col7, #T_5d60d_row5_col8, #T_5d60d_row5_col9, #T_5d60d_row5_col10, #T_5d60d_row6_col0, #T_5d60d_row6_col1, #T_5d60d_row6_col2, #T_5d60d_row6_col3, #T_5d60d_row6_col4, #T_5d60d_row6_col5, #T_5d60d_row6_col6, #T_5d60d_row6_col7, #T_5d60d_row6_col8, #T_5d60d_row6_col9, #T_5d60d_row6_col10 {
#   background-color: red;
# }
# </style>
# <table id="T_5d60d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d60d_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_5d60d_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_5d60d_level0_col2" class="col_heading level0 col2" >mean(A)</th>
#       <th id="T_5d60d_level0_col3" class="col_heading level0 col3" >mean(B)</th>
#       <th id="T_5d60d_level0_col4" class="col_heading level0 col4" >diff</th>
#       <th id="T_5d60d_level0_col5" class="col_heading level0 col5" >se</th>
#       <th id="T_5d60d_level0_col6" class="col_heading level0 col6" >T</th>
#       <th id="T_5d60d_level0_col7" class="col_heading level0 col7" >df</th>
#       <th id="T_5d60d_level0_col8" class="col_heading level0 col8" >pval</th>
#       <th id="T_5d60d_level0_col9" class="col_heading level0 col9" >hedges</th>
#       <th id="T_5d60d_level0_col10" class="col_heading level0 col10" >가설검정결과</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d60d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5d60d_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_5d60d_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_5d60d_row0_col2" class="data row0 col2" >1.437500</td>
#       <td id="T_5d60d_row0_col3" class="data row0 col3" >2.582308</td>
#       <td id="T_5d60d_row0_col4" class="data row0 col4" >-1.144808</td>
#       <td id="T_5d60d_row0_col5" class="data row0 col5" >0.265265</td>
#       <td id="T_5d60d_row0_col6" class="data row0 col6" >-4.315720</td>
#       <td id="T_5d60d_row0_col7" class="data row0 col7" >3.609998</td>
#       <td id="T_5d60d_row0_col8" class="data row0 col8" >0.079082</td>
#       <td id="T_5d60d_row0_col9" class="data row0 col9" >-1.164289</td>
#       <td id="T_5d60d_row0_col10" class="data row0 col10" >귀무가설 채택</td>
#     </tr>
#     <tr>
#       <th id="T_5d60d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5d60d_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_5d60d_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_5d60d_row1_col2" class="data row1 col2" >1.437500</td>
#       <td id="T_5d60d_row1_col3" class="data row1 col3" >3.393158</td>
#       <td id="T_5d60d_row1_col4" class="data row1 col4" >-1.955658</td>
#       <td id="T_5d60d_row1_col5" class="data row1 col5" >0.357720</td>
#       <td id="T_5d60d_row1_col6" class="data row1 col6" >-5.467004</td>
#       <td id="T_5d60d_row1_col7" class="data row1 col7" >11.053619</td>
#       <td id="T_5d60d_row1_col8" class="data row1 col8" >0.001993</td>
#       <td id="T_5d60d_row1_col9" class="data row1 col9" >-1.275588</td>
#       <td id="T_5d60d_row1_col10" class="data row1 col10" >귀무가설 기각</td>
#     </tr>
#     <tr>
#       <th id="T_5d60d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5d60d_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_5d60d_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_5d60d_row2_col2" class="data row2 col2" >1.437500</td>
#       <td id="T_5d60d_row2_col3" class="data row2 col3" >4.135405</td>
#       <td id="T_5d60d_row2_col4" class="data row2 col4" >-2.697905</td>
#       <td id="T_5d60d_row2_col5" class="data row2 col5" >0.369987</td>
#       <td id="T_5d60d_row2_col6" class="data row2 col6" >-7.291883</td>
#       <td id="T_5d60d_row2_col7" class="data row2 col7" >12.342012</td>
#       <td id="T_5d60d_row2_col8" class="data row2 col8" >0.000094</td>
#       <td id="T_5d60d_row2_col9" class="data row2 col9" >-1.671787</td>
#       <td id="T_5d60d_row2_col10" class="data row2 col10" >귀무가설 기각</td>
#     </tr>
#     <tr>
#       <th id="T_5d60d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5d60d_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_5d60d_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_5d60d_row3_col2" class="data row3 col2" >1.437500</td>
#       <td id="T_5d60d_row3_col3" class="data row3 col3" >4.028000</td>
#       <td id="T_5d60d_row3_col4" class="data row3 col4" >-2.590500</td>
#       <td id="T_5d60d_row3_col5" class="data row3 col5" >0.692043</td>
#       <td id="T_5d60d_row3_col6" class="data row3 col6" >-3.743264</td>
#       <td id="T_5d60d_row3_col7" class="data row3 col7" >5.167951</td>
#       <td id="T_5d60d_row3_col8" class="data row3 col8" >0.077624</td>
#       <td id="T_5d60d_row3_col9" class="data row3 col9" >-2.023428</td>
#       <td id="T_5d60d_row3_col10" class="data row3 col10" >귀무가설 채택</td>
#     </tr>
#     <tr>
#       <th id="T_5d60d_level0_row4" class="row_heading level0 row4" >4</th>

# %% [markdown]
# # 상관분석

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## 공분산
# - 관계의 강도는 알려주지 못한다.

# %%
df = iris.loc[:9, ["sepal_width", 'petal_length']]
sepal_w_mean = df['sepal_width'].mean()
petal_l_mean = df['petal_length'].mean()

df['sepal_diff'] = df['sepal_width'] - sepal_w_mean
df['petal_diff'] = df['petal_length'] - petal_l_mean
df['multiple'] = df['sepal_diff'] * df['petal_diff']

print(f"sum of diffs: {df['multiple'].sum()}")
print(f"covariance: {df['multiple'].sum() / len(df)}")
#양의 방향성이 보인다.
# Out:
# sum of diffs: 0.15499999999999994
# covariance: 0.015499999999999995

# %%
df.cov(ddof = 0)
# Out:
#               sepal_width  petal_length  sepal_diff  petal_diff  multiple
# sepal_width       0.08490       0.01550     0.08490     0.01550  0.007040
# petal_length      0.01550       0.01050     0.01550     0.01050  0.003320
# sepal_diff        0.08490       0.01550     0.08490     0.01550  0.007040
# petal_diff        0.01550       0.01050     0.01550     0.01050  0.003320
# multiple          0.00704       0.00332     0.00704     0.00332  0.002085

# %%
iris.iloc[:,:4].cov(ddof = 0)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      0.681122    -0.042151      1.265820     0.512829
# sepal_width      -0.042151     0.188713     -0.327459    -0.120828
# petal_length      1.265820    -0.327459      3.095503     1.286972
# petal_width       0.512829    -0.120828      1.286972     0.577133

# %%
#상관계수 구하기

iris.iloc[:,:4].corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

sns.scatterplot(x = 'sepal_width', y = 'sepal_length', data = iris, ax = ax[0])
sns.scatterplot(x = 'petal_width', y = 'sepal_length', data = iris, ax = ax[0])
sns.scatterplot(x = 'petal_length', y = 'sepal_length', data = iris, ax = ax[0])
plt.show()

# %%
df['sepal_diff'] = df['sepal_width'] - sepal_w_mean
df['petal_diff'] = df['petal_length'] - petal_l_mean
df['multiple'] = df['sepal_diff'] * df['petal_diff']
df['sepal_squared'] = df['sepal_diff'] ** 2
df['petal_squared'] = df['petal_diff'] ** 2

cov_value = df['multiple'].sum()/(len(df))
sepal_squared_std = np.sqrt(np.mean(df['sepal_squared']))
petal_squared_std = np.sqrt(np.mean(df['petal_squared']))
print("편차의 합:", df['multiple'].sum())
print("공분산 :", cov_value)
print("sepal_squared 표준편차:", sepal_squared_std)
print("petal_squared 표준편차:", petal_squared_std)
print("상관계수:", cov_value / (sepal_squared_std * petal_squared_std))
# Out:
# 편차의 합: 0.15499999999999994
# 공분산 : 0.015499999999999995
# sepal_squared 표준편차: 0.2913760456866693
# petal_squared 표준편차: 0.10246950765959598
# 상관계수: 0.5191384588617989

# %% [markdown]
# # 회귀분석

# %%
from matplotlib import pyplot as plt
import seaborn as sns

fig, ax = plt.subplots()

ax = sns.scatterplot(data = tips,
                x = 'total_bill',
                y = 'tip')

ax.set(title = 'total bill and tip', ylabel = 'tip', xlabel='total_bill')
sns.despine()

# %%
from matplotlib import pyplot as plt
import seaborn as sns

sns.lmplot(data = tips,
                x = 'total_bill',
                y = 'tip')
sns.despine()

# %%
import statsmodels.api as sm

X = tips['total_bill']
y = tips['tip']

X = sm.add_constant(X)
model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    tip   R-squared:                       0.457
# Model:                            OLS   Adj. R-squared:                  0.454
# Method:                 Least Squares   F-statistic:                     203.4
# Date:                Tue, 08 Oct 2024   Prob (F-statistic):           6.69e-34
# Time:                        06:21:01   Log-Likelihood:                -350.54
# No. Observations:                 244   AIC:                             705.1
# Df Residuals:                     242   BIC:                             712.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9203      0.160      5.761      0.000       0.606       1.235
# total_bill     0.1050      0.007     14.260      0.000       0.091       0.120
# ==============================================================================
# Omnibus:                       20.185   Durbin-Watson:                   2.151
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.750
# Skew:                           0.443   Prob(JB):                     6.35e-09
# Kurtosis:                       4.711   Cond. No.                         53.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # 회귀식 가정 검토
#
# ## 잔차의 정규성
#
# - H0: ~N()
# - H1: not H0

# %%
from scipy import stats
from scipy.stats import probplot

res = model.resid
fig, ax = plt.subplots(1,2,figsize = (15,5))

probplot(res, dist = 'norm', plot = ax[0]) # 잘 맞나?
sns.histplot(res, ax = ax[1]) # 정규분포를 따르는가?

plt.show()
shapiro(res)

# p값도 이상함, 정규분포를 따르지 않는다 !
# 다만 CLT의 가정으로 정규분포를 따른다고 가정할 수 있다.
# Out:
# ShapiroResult(statistic=0.9672804064016668, pvalue=2.17137985424342e-05)

# %% [markdown]
# ## 잔차의 등분산성
# - 등분산성이 만족되지 않는다면
#   + 이상치를 제거한다
#   + 변수에 로그변환을 취한다.

# %%
from statsmodels.stats.diagnostic import het_white
from statsmodels.compat import lzip

X = tips['total_bill']
y = tips['tip']
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()

predictions = model.predict(X)
residuals = y - predictions

plt.scatter(predictions, residuals)
plt.axhline(0, linestyle='--', color='red')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs. Predicted Values')
plt.show()

# Optionally, use Levene's test to statistically test homoscedasticity
stat, p = levene(y, predictions)
print('Levene\'s Test p-value:', p)

#The test
white_test = het_white(model.resid,  model.model.exog)

#Zipping the array with labels
names = ['Lagrange multiplier statistic', 'p-value','f-value', 'f p-value']
lzip(names,white_test)

'''
분산이 무작위적이지 않고 퍼지는 모양을 보인다 -> 등분산성을 띈다고 파악할 증거가 없다!
따라서 이상치 제거 또는 로그 변환등의 조치를 취해 주어야 한다.
'''
# Out:
# Levene's Test p-value: 4.702940565257078e-06
# [('Lagrange multiplier statistic', 59.94872593718973),
#  ('p-value', 9.600626274967907e-14),
#  ('f-value', 39.24896207437348),
#  ('f p-value', 1.7565265345405124e-15)]

# %%
from statsmodels.stats.diagnostic import het_white
from statsmodels.compat import lzip

X = iris['sepal_length']
y = iris['petal_length']
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()

predictions = model.predict(X)
residuals = y - predictions

plt.scatter(predictions, residuals)
plt.axhline(0, linestyle='--', color='red')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs. Predicted Values')
plt.show()

# Optionally, use Levene's test to statistically test homoscedasticity
stat, p = levene(y, predictions)
print('Levene\'s Test p-value:', p)

#The test
white_test = het_white(model.resid,  model.model.exog)

#Zipping the array with labels
names = ['Lagrange multiplier statistic', 'p-value','f-value', 'f p-value']
lzip(names,white_test)
# Out:
# Levene's Test p-value: 0.060961829396679774
# [('Lagrange multiplier statistic', 9.029819021724322),
#  ('p-value', 0.010944595449030392),
#  ('f-value', 4.7080289852150825),
#  ('f p-value', 0.010426675807646725)]

# %% [markdown]
# ### 로그 변환

# %%
from statsmodels.stats.diagnostic import het_white
from statsmodels.compat import lzip
import numpy as np

Q1 = tips['tip'].quantile(0.25)
Q3 = tips['tip'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

filtered_tips_sample = tips[(tips['tip'] >= lower_bound) & (tips['tip'] <= upper_bound)] #왜 필터링 하는건지?

X = filtered_tips_sample['total_bill']
y = np.log(filtered_tips_sample['tip']) #실제 로그 변환은 이 코드에서 이루어진다.

X = sm.add_constant(X)
model = sm.OLS(y, X).fit()

predictions = model.predict(X)
residuals = y - predictions

plt.scatter(predictions, residuals)
plt.axhline(0, linestyle='--', color='red')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs. Predicted Values')
plt.show()

white_test = het_white(model.resid,  model.model.exog)
names = ['Lagrange multiplier statistic', 'p-value','f-value', 'f p-value']
lzip(names, white_test)
# Out:
# [('Lagrange multiplier statistic', 3.629199874311633),
#  ('p-value', 0.16290306681983274),
#  ('f-value', 1.8195346395978056),
#  ('f p-value', 0.16440673241588843)]

# %% [markdown]
# # 다중선형회귀

# %%
import statsmodels.formula.api as smf
formular = "sepal_length ~ sepal_width + petal_length + petal_width"
model = smf.ols(formular, data = iris).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           sepal_length   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.856
# Method:                 Least Squares   F-statistic:                     295.5
# Date:                Tue, 08 Oct 2024   Prob (F-statistic):           8.59e-62
# Time:                        06:45:20   Log-Likelihood:                -37.321
# No. Observations:                 150   AIC:                             82.64
# Df Residuals:                     146   BIC:                             94.69
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        1.8560      0.251      7.401      0.000       1.360       2.352
# sepal_width      0.6508      0.067      9.765      0.000       0.519       0.783
# petal_length     0.7091      0.057     12.502      0.000       0.597       0.821
# petal_width     -0.5565      0.128     -4.363      0.000      -0.809      -0.304
# ==============================================================================
# Omnibus:                        0.345   Durbin-Watson:                   2.060
# Prob(Omnibus):                  0.842   Jarque-Bera (JB):                0.504
# Skew:                           0.007   Prob(JB):                        0.777
# Kurtosis:                       2.716   Cond. No.                         54.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - 전진소거법, 후진소거법 등 독립변수를 지울 때는 p값이 가장 높은 순서대로 빼야 한다.
# - 다중 회귀이기 때문에 어떤 변수를 사용하느냐에 따라 그 결과가 천차만별로 바뀐다.
# - 단, 파이썬에선 없다... 이부분만큼은 **R을 쓰는 게 차라리 낫다.**

# %% [markdown]
# # 카이제곱검정
# - 적합도 검정
# - 독립성 검정

# %%
tips['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
chi_scores = tips['day'].value_counts().apply(lambda x: (x - mean(tips['day'].value_counts())) ** 2 / mean(tips['day'].value_counts()))
chi_scores.sum()
#chisq의 통계량
# Out:
# 43.704918032786885

# %%
x, p = stats.chisquare(tips['day'].value_counts())
print(x, p)

if p < 0.05:
  print("귀무가설 기각: 관측된 데이터는 기대값 균등분포를 따르지 않는다.")
else:
  print("귀무가설 채택: 관측된 데이터는 기대값 균등분포를 따른다.")
# Out:
# 43.704918032786885 1.7434891890557612e-09
# 귀무가설 기각: 관측된 데이터는 기대값 균등분포를 따르지 않는다.

# %% [markdown]
# ## 독립성 검정
# - 시나리오: 성별에 따른 흡연 여부가 상관이 있는가?
# - 행렬을 뚝딱 만드는 crosstab()을 활용하자.

# %%
c_table = pd.crosstab(tips['sex'], tips['smoker'])
c_table
# Out:
# smoker  Yes  No
# sex
# Male     60  97
# Female   33  54

# %%
t, p, dof, expected = stats.chi2_contingency(c_table)
print(t,'\n',p,'\n',dof,'\n',expected)
# Out:
# 0.0
#  1.0
#  1
#  [[59.84016393 97.15983607]
#  [33.15983607 53.84016393]]
