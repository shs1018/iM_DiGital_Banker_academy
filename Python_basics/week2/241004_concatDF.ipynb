# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # os로 데이터 정리하기

# %%
from pandas import *
import os

#먼저 저장할 데이터를 만들자...
data = {
    "종목명": ["3R", "3SOFT", "ACTS"],
    "현재가": [1510, 1790, 1185],
    "등락률": [7.36, 1.65, 1.28],
}

data = DataFrame(data)
print(data)
# Out:
#      종목명   현재가   등락률
# 0     3R  1510  7.36
# 1  3SOFT  1790  1.65
# 2   ACTS  1185  1.28

# %%
'''
if not os.path.isdir('abc'):    #현재 디렉토리에 abc가 없다면...
    os.mkdir("abc")             #현재 디텍토리에 abc폴더를 만들어라!!

data.to_csv("abc/data.csv", index = False)
data.to_excel("abc/data.xlsx", index = False)
'''
# Out:
# '\nif not os.path.isdir(\'abc\'):    #현재 디렉토리에 abc가 없다면...\n    os.mkdir("abc")             #현재 디텍토리에 abc폴더를 만들어라!!\n\ndata.to_csv("abc/data.csv", index = False)\ndata.to_excel("abc/data.xlsx", index = False)\n'

# %% [markdown]
# # Concat
# - 데이터프레임을 행/열로 이어붙이는 Goat 함수

# %%
from pandas import DataFrame
import pandas as pd

# 첫번째 데이터프레임
data = {
    '종가': [113000, 111500],
    '거래량': [555850, 282163]
}
index = ["2019-06-21", "2019-06-20"]
df1 = DataFrame(data, index=index)

# 두번째 데이터프레임
data = {
    '종가': [110000, 483689],
    '거래량': [109000, 791946]
}
index = ["2019-06-19", "2019-06-18"]
df2 = DataFrame(data, index=index)

# %%
res = concat([df2,df1], axis = 1)
print(res)
# Out:
#                   종가       거래량        종가       거래량
# 2019-06-19  110000.0  109000.0       NaN       NaN
# 2019-06-18  483689.0  791946.0       NaN       NaN
# 2019-06-21       NaN       NaN  113000.0  555850.0
# 2019-06-20       NaN       NaN  111500.0  282163.0

# %%
res = concat([df2,df1], axis = 0)
print(res)
# Out:
#                 종가     거래량
# 2019-06-19  110000  109000
# 2019-06-18  483689  791946
# 2019-06-21  113000  555850
# 2019-06-20  111500  282163

# %%
# 두번째 데이터프레임
data = {
    '종가2': [110000, 483689],
    '거래량2': [109000, 791946]
}
index = ["2019-06-19", "2019-06-18"]
df2 = DataFrame(data, index=index)

res2 = concat([df2,df1], axis = 0)
print(res2)
# Out:
#                  종가2      거래량2        종가       거래량
# 2019-06-19  110000.0  109000.0       NaN       NaN
# 2019-06-18  483689.0  791946.0       NaN       NaN
# 2019-06-21       NaN       NaN  113000.0  555850.0
# 2019-06-20       NaN       NaN  111500.0  282163.0

# %% [markdown]
# # Merge

# %%
from pandas import DataFrame
import pandas as pd

# 첫 번째 데이터프레임
data = [
    ["전기전자", "005930", "삼성전자", 74400],
    ["화학", "051910", "LG화학", 896000],
    ["전기전자", "000660", "SK하이닉스", 101500]
]

columns = ["업종", "종목코드", "종목명", "현재가"]
df1 = DataFrame(data=data, columns=columns)

# 두 번째 데이터프레임
data = [
    ["은행", 2.92],
    ["보험", 0.37],
    ["화학", 0.06],
    ["전기전자", -2.43]
]

columns = ["업종", "등락률"]
df2 = DataFrame(data=data, columns=columns)

# %%
res_dat = pd.merge(left = df1, right = df2, on = '업종')
res_dat
# Out:
#      업종    종목코드     종목명     현재가   등락률
# 0  전기전자  005930    삼성전자   74400 -2.43
# 1    화학  051910    LG화학  896000  0.06
# 2  전기전자  000660  SK하이닉스  101500 -2.43

# %%
res_dat2 = pd.merge(left = df1, right = df2, on = '업종', how = 'left')
res_dat2
# Out:
#      업종    종목코드     종목명     현재가   등락률
# 0  전기전자  005930    삼성전자   74400 -2.43
# 1    화학  051910    LG화학  896000  0.06
# 2  전기전자  000660  SK하이닉스  101500 -2.43

# %%
res_dat3 = pd.merge(left = df1, right = df2, on = '업종', how = 'right')
res_dat3
# Out:
#      업종    종목코드     종목명       현재가   등락률
# 0    은행     NaN     NaN       NaN  2.92
# 1    보험     NaN     NaN       NaN  0.37
# 2    화학  051910    LG화학  896000.0  0.06
# 3  전기전자  005930    삼성전자   74400.0 -2.43
# 4  전기전자  000660  SK하이닉스  101500.0 -2.43

# %%
res_dat4 = pd.merge(left = df1, right = df2, on = '업종', how = 'outer')
res_dat4
# Out:
#      업종    종목코드     종목명       현재가   등락률
# 0    보험     NaN     NaN       NaN  0.37
# 1    은행     NaN     NaN       NaN  2.92
# 2  전기전자  005930    삼성전자   74400.0 -2.43
# 3  전기전자  000660  SK하이닉스  101500.0 -2.43
# 4    화학  051910    LG화학  896000.0  0.06

# %% [markdown]
# # join

# %%
# 첫 번째 데이터프레임
data = [
    ["전기전자", "005930", "삼성전자", 74400],
    ["화학", "051910", "LG화학", 896000],
    ["핀테크", "000660", "LG CNS", 101500]
]

columns = ["업종", "종목코드", "종목명", "현재가"]
df1 = DataFrame(data=data, columns=columns)
df1 = df1.set_index('업종')

# 두 번째 데이터프레임
data = [
    ["은행", 2.92],
    ["보험", 0.37],
    ["화학", 0.06],
    ["전기전자", -2.43]
]

columns = ["업종", "등락률"]
df2 = DataFrame(data=data, columns=columns)
df2 = df2.set_index('업종')

# %%
df1.join(df2, how = 'right')
# Out:
#         종목코드   종목명       현재가   등락률
# 업종
# 은행       NaN   NaN       NaN  2.92
# 보험       NaN   NaN       NaN  0.37
# 화학    051910  LG화학  896000.0  0.06
# 전기전자  005930  삼성전자   74400.0 -2.43

# %% [markdown]
# # test
# - 연도별로 그룹바이 연산 및 시가총액의 평균

# %%
data = [
    ["2017", "삼성", 500],
    ["2017", "LG", 300],
    ["2017", "SK하이닉스", 200],
    ["2018", "삼성", 600],
    ["2018", "LG", 400],
    ["2018", "SK하이닉스", 300],
]

columns = ["연도", "회사", "시가총액"]
df = DataFrame(data=data, columns=columns)
df
# Out:
#      연도      회사  시가총액
# 0  2017      삼성   500
# 1  2017      LG   300
# 2  2017  SK하이닉스   200
# 3  2018      삼성   600
# 4  2018      LG   400
# 5  2018  SK하이닉스   300

# %%
dat = df.groupby('연도')['시가총액'].mean().to_frame()
dat.columns = ['시가총액 평균']
dat
# Out:
#          시가총액 평균
# 연도
# 2017  333.333333
# 2018  433.333333

# %%
df.join(dat)
# Out:
#      연도      회사  시가총액  시가총액 평균
# 0  2017      삼성   500      NaN
# 1  2017      LG   300      NaN
# 2  2017  SK하이닉스   200      NaN
# 3  2018      삼성   600      NaN
# 4  2018      LG   400      NaN
# 5  2018  SK하이닉스   300      NaN

# %%
res_dat = df.join(dat, on = '연도')
res_dat
# Out:
#      연도      회사  시가총액     시가총액 평균
# 0  2017      삼성   500  333.333333
# 1  2017      LG   300  333.333333
# 2  2017  SK하이닉스   200  333.333333
# 3  2018      삼성   600  433.333333
# 4  2018      LG   400  433.333333
# 5  2018  SK하이닉스   300  433.333333

# %%
import numpy as np

res_dat['규모'] = np.where(res_dat['시가총액'] > res_dat['시가총액 평균'], '대형주', '중소형주')
res_dat
# Out:
#      연도      회사  시가총액     시가총액 평균    규모
# 0  2017      삼성   500  333.333333   대형주
# 1  2017      LG   300  333.333333  중소형주
# 2  2017  SK하이닉스   200  333.333333  중소형주
# 3  2018      삼성   600  433.333333   대형주
# 4  2018      LG   400  433.333333  중소형주
# 5  2018  SK하이닉스   300  433.333333  중소형주

# %% [markdown]
# # 멀티인덱스

# %%
from pandas import DataFrame
import pandas as pd

data = [
    ["영업이익", "컨센서스", 1000, 1200],
    ["영업이익", "잠정치", 900, 1400],
    ["당기순이익", "컨센서스", 800, 900],
    ["당기순이익", "잠정치", 700, 800]
]

df = DataFrame(data=data)
df = df.set_index([0, 1])
df
# Out:
#                2     3
# 0     1
# 영업이익  컨센서스  1000  1200
#       잠정치    900  1400
# 당기순이익 컨센서스   800   900
#       잠정치    700   800

# %%
df.loc[('영업이익', '잠정치'),:]
# Out:
# 2     900
# 3    1400
# Name: (영업이익, 잠정치), dtype: int64

# %%
df.reset_index()
# Out:
#        0     1     2     3
# 0   영업이익  컨센서스  1000  1200
# 1   영업이익   잠정치   900  1400
# 2  당기순이익  컨센서스   800   900
# 3  당기순이익   잠정치   700   800

# %%
import seaborn as sns

tips = sns.load_dataset("tips")
res = tips .groupby(['sex', 'smoker','day'])[['total_bill', 'tip']].mean()

res
# Out:
# <ipython-input-71-1ea189b8c20c>:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   res = tips .groupby(['sex', 'smoker','day'])[['total_bill', 'tip']].mean()
#                     total_bill       tip
# sex    smoker day
# Male   Yes    Thur   19.171000  3.058000
#               Fri    20.452500  2.741250
#               Sat    21.837778  2.879259
#               Sun    26.141333  3.521333
#        No     Thur   18.486500  2.941500
#               Fri    17.475000  2.500000
#               Sat    19.929063  3.256563
#               Sun    20.403256  3.115349
# Female Yes    Thur   19.218571  2.990000
#               Fri    12.654286  2.682857
#               Sat    20.266667  2.868667
#               Sun    16.540000  3.500000
#        No     Thur   16.014400  2.459600
# ...

# %%
tips = sns.load_dataset("tips")
result = tips.groupby(['sex', 'smoker', 'day'])[['total_bill', 'tip']].mean().reset_index()
result.loc[result['day'] == 'Fri', :]
# Out:
# <ipython-input-75-86f7830cf96f>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   result = tips.groupby(['sex', 'smoker', 'day'])[['total_bill', 'tip']].mean().reset_index()
#        sex smoker  day  total_bill       tip
# 1     Male    Yes  Fri   20.452500  2.741250
# 5     Male     No  Fri   17.475000  2.500000
# 9   Female    Yes  Fri   12.654286  2.682857
# 13  Female     No  Fri   19.365000  3.125000

# %%
lvl_0 = ['영업이익', '당기순이익']
lvl_1 = ['컨센서스', '잠정치']

idx = index = pd.MultiIndex.from_product([lvl_0, lvl_1])
idx

#데이터 프레임을 다시 만들어야 한다!!
# Out:
# MultiIndex([( '영업이익', '컨센서스'),
#             ( '영업이익',  '잠정치'),
#             ('당기순이익', '컨센서스'),
#             ('당기순이익',  '잠정치')],
#            )

# %%
df2 = pd.DataFrame(data = data, index = ['2020/06','2020/09'], columns = idx)
df2['등락률']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-855f578182a5> in <cell line: 1>()
# ----> 1 df2 = pd.DataFrame(data = data, index = ['2020/06','2020/09'], columns = idx)
#       2 df2['등락률']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     857                         dtype,
#     858                     )
# --> 859                     mgr = arrays_to_mgr(
#     860                         arrays,
#     861                         columns,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     117
#     118         # don't force copy because getting jammed in an ndarray anyway
# --> 119         arrays, refs = _homogenize(arrays, index, dtype)
# ...
