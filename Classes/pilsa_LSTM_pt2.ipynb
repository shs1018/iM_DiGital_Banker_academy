# %%
import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
DATA_PATH = "C:/Users/campus3S031/Desktop/iMBank/iM_DiGital_Banker_academy/ML_TS/data/"

train_df = pd.read_csv(DATA_PATH + 'train.csv', index_col=0)
val_df = pd.read_csv(DATA_PATH + 'val.csv', index_col=0)
test_df = pd.read_csv(DATA_PATH + 'test.csv', index_col=0)

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (12285, 5) (3510, 5) (1756, 5)

# %% [markdown]
# # 클래스 먼저

# %%
class DataWindow():
    def __init__(self, 
                 input_width, label_width, shift,
                 train_df = train_df, val_df = val_df, test_df = test_df,
                 label_columns = None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df

        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}

        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift

        self.total_window_size = input_width + shift

        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]

        self.label_start = self.total_window_size - self.label_width

        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]

    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]

        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis = -1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])

        return inputs, labels
    
    def plot(self, model= None, plot_col = 'traffic_volume', max_subplots = 3):
        inputs, labels = self.sample_batch

        plt.figure(figsize = (12,8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))

        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time(h)')

    def make_dataset(self, data):
       data = np.array(data, dtype = np.float32)
       ds = tf.keras.preprocessing.timeseries_dataset_from_array(
          data = data,
          targets = None,
          sequence_length = self.total_window_size,
          sequence_stride = 1,
          shuffle = True,
          batch_size = 32
       )

       ds = ds.map(self.split_to_inputs_labels)
       return ds
    
    @property
    def train(self):
       return self.make_dataset(self.train_df)
    
    @property
    def val(self):
       return self.make_dataset(self.test_df)
    
    @property
    def test(self):
       return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
           result = next(iter(self.train))
           self._sample_batch = result
        return result

# %% [markdown]
# # fit Data

# %%
def compile_and_fit(model, window, patience = 3, max_epochs = 50):
    
    early_stopping = EarlyStopping(monitor = 'val_loss',
                                   patience = patience,
                                   mode = 'min')
    
    model.compile(loss = MeanSquaredError(),
                  optimizer = Adam(),
                  metrics = [MeanAbsoluteError()])
    
    history = model.fit(window.train,
                        epochs = max_epochs,
                        validation_data = window.val,
                        callbacks = [early_stopping])
    
    return history

# %% [markdown]
# # Single_model

# %%
single_step_window = DataWindow(input_width = 1, label_width = 1, shift = 1, label_columns = ['traffic_volume'])
wide_window = DataWindow(input_width = 24, label_width = 24, shift = 1, label_columns = ['traffic_volume'])

# %%
mae_val = [0.083, 0.068, 0.033]
mae_test = [0.081, 0.068, 0.029]

# %%
lstm_model = Sequential([
    LSTM(32, return_sequences = True),
    Dense(units = 1)
])

history = compile_and_fit(lstm_model, wide_window)

val_performance = {}
performance = {}

val_performance['LSTM'] = lstm_model.evaluate(wide_window.val)
performance['LSTM'] = lstm_model.evaluate(wide_window.test, verbose = 0)
# Out:
# Epoch 1/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0421 - mean_absolute_error: 0.1498 - val_loss: 0.0077 - val_mean_absolute_error: 0.0646
# Epoch 2/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0074 - mean_absolute_error: 0.0623 - val_loss: 0.0039 - val_mean_absolute_error: 0.0461
# Epoch 3/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0049 - mean_absolute_error: 0.0501 - val_loss: 0.0031 - val_mean_absolute_error: 0.0400
# Epoch 4/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0041 - mean_absolute_error: 0.0452 - val_loss: 0.0027 - val_mean_absolute_error: 0.0382
# Epoch 5/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0036 - mean_absolute_error: 0.0416 - val_loss: 0.0026 - val_mean_absolute_error: 0.0370
# Epoch 6/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0032 - mean_absolute_error: 0.0390 - val_loss: 0.0021 - val_mean_absolute_error: 0.0324
# Epoch 7/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0368 - val_loss: 0.0020 - val_mean_absolute_error: 0.0308
# Epoch 8/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0027 - mean_absolute_error: 0.0353 - val_loss: 0.0019 - val_mean_absolute_error: 0.0306
# Epoch 9/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0345 - val_loss: 0.0019 - val_mean_absolute_error: 0.0301
# Epoch 10/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0025 - mean_absolute_error: 0.0337 - val_loss: 0.0018 - val_mean_absolute_error: 0.0290
# Epoch 11/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0025 - mean_absolute_error: 0.0331 - val_loss: 0.0018 - val_mean_absolute_error: 0.0292
# Epoch 12/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0327 - val_loss: 0.0017 - val_mean_absolute_error: 0.0288
# Epoch 13/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0322 - val_loss: 0.0017 - val_mean_absolute_error: 0.0282
# Epoch 14/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0023 - mean_absolute_error: 0.0319 - val_loss: 0.0017 - val_mean_absolute_error: 0.0296
# Epoch 15/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0023 - mean_absolute_error: 0.0316 - val_loss: 0.0017 - val_mean_absolute_error: 0.0290
# Epoch 16/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0022 - mean_absolute_error: 0.0311 - val_loss: 0.0016 - val_mean_absolute_error: 0.0280
# Epoch 17/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0022 - mean_absolute_error: 0.0311 - val_loss: 0.0015 - val_mean_absolute_error: 0.0272
# Epoch 18/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0021 - mean_absolute_error: 0.0307 - val_loss: 0.0015 - val_mean_absolute_error: 0.0273
# Epoch 19/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0021 - mean_absolute_error: 0.0302 - val_loss: 0.0014 - val_mean_absolute_error: 0.0264
# Epoch 20/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0021 - mean_absolute_error: 0.0301 - val_loss: 0.0014 - val_mean_absolute_error: 0.0254
# Epoch 21/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0298 - val_loss: 0.0013 - val_mean_absolute_error: 0.0253
# Epoch 22/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0296 - val_loss: 0.0014 - val_mean_absolute_error: 0.0260
# Epoch 23/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0295 - val_loss: 0.0014 - val_mean_absolute_error: 0.0255
# Epoch 24/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0291 - val_loss: 0.0014 - val_mean_absolute_error: 0.0271
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0272

# %% [markdown]
# # Multi_step Model

# %%
multi_window = DataWindow(input_width = 24, label_width = 24, shift = 24, label_columns=['traffic_volume'])

# %%
ms_mae_val = [0.352, 0.347, 0.088, 0.078]
ms_mae_test = [0.347, 0.341, 0.076, 0.064]

# %%
ms_lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros)
])

history = compile_and_fit(ms_lstm_model, multi_window)

ms_val_performance = {}
ms_performance = {}

ms_val_performance['LSTM'] = ms_lstm_model.evaluate(multi_window.val)
ms_val_performance["LSTM"] = ms_lstm_model.evaluate(multi_window.test, verbose = 0)
# Out:
# Epoch 1/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0934 - mean_absolute_error: 0.2302 - val_loss: 0.0183 - val_mean_absolute_error: 0.1010
# Epoch 2/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0184 - mean_absolute_error: 0.0961 - val_loss: 0.0135 - val_mean_absolute_error: 0.0788
# Epoch 3/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0153 - mean_absolute_error: 0.0844 - val_loss: 0.0126 - val_mean_absolute_error: 0.0721
# Epoch 4/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0144 - mean_absolute_error: 0.0803 - val_loss: 0.0122 - val_mean_absolute_error: 0.0708
# Epoch 5/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0139 - mean_absolute_error: 0.0781 - val_loss: 0.0118 - val_mean_absolute_error: 0.0690
# Epoch 6/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0138 - mean_absolute_error: 0.0776 - val_loss: 0.0116 - val_mean_absolute_error: 0.0676
# Epoch 7/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0135 - mean_absolute_error: 0.0762 - val_loss: 0.0114 - val_mean_absolute_error: 0.0660
# Epoch 8/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0132 - mean_absolute_error: 0.0754 - val_loss: 0.0113 - val_mean_absolute_error: 0.0677
# Epoch 9/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0130 - mean_absolute_error: 0.0746 - val_loss: 0.0110 - val_mean_absolute_error: 0.0669
# Epoch 10/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0129 - mean_absolute_error: 0.0740 - val_loss: 0.0119 - val_mean_absolute_error: 0.0655
# Epoch 11/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0128 - mean_absolute_error: 0.0737 - val_loss: 0.0109 - val_mean_absolute_error: 0.0662
# Epoch 12/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0126 - mean_absolute_error: 0.0726 - val_loss: 0.0106 - val_mean_absolute_error: 0.0640
# Epoch 13/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0125 - mean_absolute_error: 0.0726 - val_loss: 0.0109 - val_mean_absolute_error: 0.0621
# Epoch 14/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0123 - mean_absolute_error: 0.0717 - val_loss: 0.0113 - val_mean_absolute_error: 0.0641
# Epoch 15/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0123 - mean_absolute_error: 0.0715 - val_loss: 0.0101 - val_mean_absolute_error: 0.0627
# Epoch 16/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0120 - mean_absolute_error: 0.0708 - val_loss: 0.0097 - val_mean_absolute_error: 0.0628
# Epoch 17/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0119 - mean_absolute_error: 0.0703 - val_loss: 0.0099 - val_mean_absolute_error: 0.0602
# Epoch 18/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0117 - mean_absolute_error: 0.0697 - val_loss: 0.0092 - val_mean_absolute_error: 0.0599
# Epoch 19/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0115 - mean_absolute_error: 0.0691 - val_loss: 0.0093 - val_mean_absolute_error: 0.0584
# Epoch 20/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0114 - mean_absolute_error: 0.0689 - val_loss: 0.0095 - val_mean_absolute_error: 0.0605
# Epoch 21/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0114 - mean_absolute_error: 0.0690 - val_loss: 0.0089 - val_mean_absolute_error: 0.0585
# Epoch 22/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0112 - mean_absolute_error: 0.0683 - val_loss: 0.0089 - val_mean_absolute_error: 0.0592
# Epoch 23/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0111 - mean_absolute_error: 0.0678 - val_loss: 0.0091 - val_mean_absolute_error: 0.0579
# Epoch 24/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0109 - mean_absolute_error: 0.0671 - val_loss: 0.0089 - val_mean_absolute_error: 0.0593
# Epoch 25/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0107 - mean_absolute_error: 0.0663 - val_loss: 0.0096 - val_mean_absolute_error: 0.0583
# Epoch 26/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0108 - mean_absolute_error: 0.0665 - val_loss: 0.0093 - val_mean_absolute_error: 0.0583
# Epoch 27/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0106 - mean_absolute_error: 0.0660 - val_loss: 0.0092 - val_mean_absolute_error: 0.0569
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0094 - mean_absolute_error: 0.0572

# %% [markdown]
# # Multi Output Model

# %%
mo_single_step_window = DataWindow(input_width= 1, label_width = 1, shift = 1, label_columns=['temp','traffic_volume'])
mo_wide_window = DataWindow(input_width=24, label_width=24, shift = 1, label_columns = ['temp', 'traffic_volume'])

# %%
mo_mae_val = [0.048, 0.039, 0.023]
mo_mae_test = [0.047, 0.036, 0.020]

# %%
mo_lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(units = 2)
])

history = compile_and_fit(mo_lstm_model, mo_wide_window)

mo_val_performance = {}
mo_performance = {}

mo_val_performance['LSTM'] = mo_lstm_model.evaluate(mo_wide_window.val)
mo_performance['LSTM'] = mo_lstm_model.evaluate(mo_wide_window.test, verbose = 0)
# Out:
# Epoch 1/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0511 - mean_absolute_error: 0.1589 - val_loss: 0.0102 - val_mean_absolute_error: 0.0658
# Epoch 2/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0076 - mean_absolute_error: 0.0574 - val_loss: 0.0041 - val_mean_absolute_error: 0.0405
# Epoch 3/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0040 - mean_absolute_error: 0.0402 - val_loss: 0.0026 - val_mean_absolute_error: 0.0320
# Epoch 4/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0030 - mean_absolute_error: 0.0348 - val_loss: 0.0020 - val_mean_absolute_error: 0.0285
# Epoch 5/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0026 - mean_absolute_error: 0.0317 - val_loss: 0.0017 - val_mean_absolute_error: 0.0260
# Epoch 6/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0024 - mean_absolute_error: 0.0296 - val_loss: 0.0015 - val_mean_absolute_error: 0.0244
# Epoch 7/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0022 - mean_absolute_error: 0.0281 - val_loss: 0.0014 - val_mean_absolute_error: 0.0228
# Epoch 8/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0021 - mean_absolute_error: 0.0269 - val_loss: 0.0013 - val_mean_absolute_error: 0.0221
# Epoch 9/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0019 - mean_absolute_error: 0.0260 - val_loss: 0.0013 - val_mean_absolute_error: 0.0226
# Epoch 10/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0018 - mean_absolute_error: 0.0250 - val_loss: 0.0012 - val_mean_absolute_error: 0.0211
# Epoch 11/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0017 - mean_absolute_error: 0.0244 - val_loss: 0.0011 - val_mean_absolute_error: 0.0203
# Epoch 12/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0017 - mean_absolute_error: 0.0239 - val_loss: 0.0011 - val_mean_absolute_error: 0.0202
# Epoch 13/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0016 - mean_absolute_error: 0.0235 - val_loss: 0.0011 - val_mean_absolute_error: 0.0198
# Epoch 14/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0016 - mean_absolute_error: 0.0232 - val_loss: 0.0010 - val_mean_absolute_error: 0.0197
# Epoch 15/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0015 - mean_absolute_error: 0.0229 - val_loss: 9.8184e-04 - val_mean_absolute_error: 0.0191
# Epoch 16/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0015 - mean_absolute_error: 0.0226 - val_loss: 9.6192e-04 - val_mean_absolute_error: 0.0189
# Epoch 17/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0015 - mean_absolute_error: 0.0223 - val_loss: 9.6703e-04 - val_mean_absolute_error: 0.0193
# Epoch 18/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0014 - mean_absolute_error: 0.0221 - val_loss: 8.9934e-04 - val_mean_absolute_error: 0.0181
# Epoch 19/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0014 - mean_absolute_error: 0.0220 - val_loss: 9.0365e-04 - val_mean_absolute_error: 0.0185
# Epoch 20/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0014 - mean_absolute_error: 0.0218 - val_loss: 8.7265e-04 - val_mean_absolute_error: 0.0183
# Epoch 21/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0014 - mean_absolute_error: 0.0216 - val_loss: 9.2694e-04 - val_mean_absolute_error: 0.0191
# Epoch 22/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0014 - mean_absolute_error: 0.0216 - val_loss: 8.7842e-04 - val_mean_absolute_error: 0.0186
# Epoch 23/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0013 - mean_absolute_error: 0.0214 - val_loss: 8.7221e-04 - val_mean_absolute_error: 0.0184
# Epoch 24/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0013 - mean_absolute_error: 0.0212 - val_loss: 8.4588e-04 - val_mean_absolute_error: 0.0182
# Epoch 25/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0013 - mean_absolute_error: 0.0212 - val_loss: 8.2045e-04 - val_mean_absolute_error: 0.0179
# Epoch 26/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0013 - mean_absolute_error: 0.0210 - val_loss: 8.0165e-04 - val_mean_absolute_error: 0.0175
# Epoch 27/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0013 - mean_absolute_error: 0.0209 - val_loss: 8.0374e-04 - val_mean_absolute_error: 0.0175
# Epoch 28/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0013 - mean_absolute_error: 0.0208 - val_loss: 7.7991e-04 - val_mean_absolute_error: 0.0173
# Epoch 29/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0013 - mean_absolute_error: 0.0206 - val_loss: 8.0888e-04 - val_mean_absolute_error: 0.0178
# Epoch 30/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0013 - mean_absolute_error: 0.0207 - val_loss: 8.6227e-04 - val_mean_absolute_error: 0.0184
# Epoch 31/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0012 - mean_absolute_error: 0.0206 - val_loss: 7.6981e-04 - val_mean_absolute_error: 0.0173
# Epoch 32/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0012 - mean_absolute_error: 0.0204 - val_loss: 7.9202e-04 - val_mean_absolute_error: 0.0175
# Epoch 33/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0012 - mean_absolute_error: 0.0204 - val_loss: 7.6037e-04 - val_mean_absolute_error: 0.0170
# Epoch 34/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0012 - mean_absolute_error: 0.0202 - val_loss: 7.5735e-04 - val_mean_absolute_error: 0.0170
# Epoch 35/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0203 - val_loss: 7.7444e-04 - val_mean_absolute_error: 0.0175
# Epoch 36/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0012 - mean_absolute_error: 0.0201 - val_loss: 7.5157e-04 - val_mean_absolute_error: 0.0172
# Epoch 37/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0201 - val_loss: 7.3226e-04 - val_mean_absolute_error: 0.0168
# Epoch 38/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0012 - mean_absolute_error: 0.0199 - val_loss: 7.4752e-04 - val_mean_absolute_error: 0.0172
# Epoch 39/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0012 - mean_absolute_error: 0.0199 - val_loss: 7.7243e-04 - val_mean_absolute_error: 0.0175
# Epoch 40/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0012 - mean_absolute_error: 0.0199 - val_loss: 7.5028e-04 - val_mean_absolute_error: 0.0174
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6060e-04 - mean_absolute_error: 0.0175
